# %%
import pandas as pd

# %%
data = pd.read_excel('./sport/double-sports/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Велосипеды / Велосипеды / Туринги / AUTHOR / В...
# 1  Велосипеды / Велосипеды / Горные / BERGAMONT /...
# 2  Велосипеды / Велосипеды / Горные / BERGAMONT /...
# 3  Велосипеды / Велосипеды / Горные / BERGAMONT /...
# 4  Велосипеды / Велосипеды / Горные / BERGAMONT /...
#
#                                             Описание   Цена
# 0  Хромолевый грэвел (gravel) Author RONIN 2019 г...  84000
# 1  Универсальный горный велосипед, который отличн...  43450
# 2  Универсальный горный велосипед, который отличн...  43450
# 3  В 2018 году компания Bergamont решила объедини...  43450
# 4  В 2018 году компания Bergamont решила объедини...  43450

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 3 columns):
# Название    886 non-null object
# Описание    865 non-null object
# Цена        886 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 20.8+ KB

# %%
data.to_excel('./sport/double-sports/data_cleaned.xls', index=False)
data = pd.read_excel('./sport/double-sports/data_cleaned.xls')

# %%
slots = set()
def process(text, ind=0):
    x = text
    
    x = x.strip().lower().split('~')[0]
    x = x.split('/')[:3]
    x = [x_.strip() for x_ in x if len(x_.strip()) > 0]
    slots.update(x)
    
    return text

data['Название'].apply(process)
slots
# Out:
# {'686',
#  'airblaster',
#  'amplifi',
#  'anon',
#  'anteater',
#  'arbor',
#  'bern',
#  'bmx',
#  'bonus gloves',
#  'buff',
#  'burton',
#  'clwr',
#  'cool zone',
#  'dc',
#  'dragon',
#  'flow',
#  'gnu',
#  'head',
#  'howl',
#  'joint',
#  'jones',
#  'lib tech',
#  'lidakis',
#  'lopoma',
#  'losraketos',
#  'merge4',
#  'nandn',
#  'oakley',
#  'only',
#  'prime',
#  'prosurf',
#  'quiksilver',
#  'red',
#  'romp',
#  'roxy',
#  'sims',
#  'spy+',
#  'terror',
#  'thirtytwo',
#  'today',
#  'true spin',
#  'union',
#  'viking',
#  'vonzipper',
#  'балаклавы и бафы',
#  'банданы',
#  'ботинки',
#  'велосипеды',
#  'горные',
#  'городские',
#  'двухподвесы',
#  'детские',
#  'жилетки',
#  'защита',
#  'комбинезоны',
#  'крепления',
#  'крепления и сноуборд trs',
#  'куртки городские',
#  'куртки сноубордические',
#  'маски',
#  'носки',
#  'одежда',
#  'перчатки и варежки',
#  'рюкзаки',
#  'сноубординг',
#  'сноуборды',
#  'стрит',
#  'термобелье',
#  'толстовки',
#  'туринги',
#  'футболки',
#  'фэтбайки',
#  'циклокросс',
#  'чехлы',
#  'шапки',
#  'шлемы',
#  'шоссейные',
#  'штаны сноубордические'}

# %%
len(slots)
# Out:
# 78

# %%
data = pd.read_excel('./sport/gold-standart.com/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Наборы спортивного питания~Комбо-набор Mad God...
# 1  Наборы спортивного питания~Комбо-набор 2 Ligan...
# 2  Наборы спортивного питания~Комбо-набор Ligandr...
# 3  Наборы спортивного питания~Комбо-набор 2 Ligan...
# 4  Наборы спортивного питания~Комбо-набор Ligandr...
#
#                                             Описание      Цена
# 0  MAD DRUGS GOD OF WHEY.Размер порции: 2 мерные ...  2200 руб
# 1  Спортивное питание FrogTechLigandrol (Лигандро...  2890 руб
# 2  Спортивное питание FrogTechIbutamoren (Ибутамо...  3990 руб
# 3  Спортивное питание FrogTechLigandrol (Лигандро...  4990 руб
# 4  Спортивное питание FrogTechIbutamoren (Ибутамо...  4990 руб

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
# Название    1121 non-null object
# Описание    998 non-null object
# Цена        1121 non-null object
# dtypes: object(3)
# memory usage: 26.4+ KB

# %%
def to_num(text):
    return int(''.join(text.replace('руб', '').split()))

# %%
data['Цена'] = data['Цена'].apply(to_num)

# %%
data.to_excel('./sport/gold-standart.com/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./sport/gold-standart.com/data_cleaned.xls')
data.head()
# Out:
#                                             Название  \
# 0  Наборы спортивного питания~Комбо-набор Mad God...
# 1  Наборы спортивного питания~Комбо-набор 2 Ligan...
# 2  Наборы спортивного питания~Комбо-набор Ligandr...
# 3  Наборы спортивного питания~Комбо-набор 2 Ligan...
# 4  Наборы спортивного питания~Комбо-набор Ligandr...
#
#                                             Описание  Цена
# 0  MAD DRUGS GOD OF WHEY.Размер порции: 2 мерные ...  2200
# 1  Спортивное питание FrogTechLigandrol (Лигандро...  2890
# 2  Спортивное питание FrogTechIbutamoren (Ибутамо...  3990
# 3  Спортивное питание FrogTechLigandrol (Лигандро...  4990
# 4  Спортивное питание FrogTechIbutamoren (Ибутамо...  4990

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
# Название    1121 non-null object
# Описание    998 non-null object
# Цена        1121 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 26.4+ KB

# %%
def process_gold(text, ind=0):
    slots.update(text.strip().lower().split('~')[:1])
    
    return text

data['Название'].apply(process_gold)
slots
# Out:
# {'686',
#  'airblaster',
#  'amplifi',
#  'anon',
#  'anteater',
#  'arbor',
#  'bern',
#  'bmx',
#  'bonus gloves',
#  'buff',
#  'burton',
#  'clwr',
#  'cool zone',
#  'dc',
#  'dragon',
#  'flow',
#  'gnu',
#  'head',
#  'howl',
#  'joint',
#  'jones',
#  'lib tech',
#  'lidakis',
#  'lopoma',
#  'losraketos',
#  'merge4',
#  'nandn',
#  'oakley',
#  'only',
#  'prime',
#  'prosurf',
#  'quiksilver',
#  'red',
#  'romp',
#  'roxy',
#  'sims',
#  'spy+',
#  'terror',
#  'thirtytwo',
#  'today',
#  'true spin',
#  'union',
#  'viking',
#  'vonzipper',
#  'аксессуары',
#  'активное долголетие',
#  'аминокислоты',
#  'балаклавы и бафы',
#  'банданы',
#  'ботинки',
#  'бустеры гормона роста',
#  'велосипеды',
#  'витамины и минералы',
#  'гейнеры (белки+углеводы)',
#  'горные',
#  'городские',
#  'готовые напитки',
#  'двухподвесы',
#  'детские',
#  'диетическое питание',
#  'для питомцев',
#  'жилетки',
#  'жиросжигатели',
#  'защита',
#  'комбинезоны',
#  'креатин',
#  'крепления',
#  'крепления и сноуборд trs',
#  'куртки городские',
#  'куртки сноубордические',
#  'маски',
#  'наборы спортивного питания',
#  'нитробустеры',
#  'носки',
#  'ночные восстановители',
#  'одежда',
#  'одежда женская',
#  'одежда мужская',
#  'перчатки и варежки',
#  'посттренировочные комплексы и восстановители',
#  'предтренировочные комплексы',
#  'протеины',
#  'рюкзаки',
#  'сноубординг',
#  'сноуборды',
#  'специальные препараты',
#  'спортивный перекус',
#  'стрит',
#  'термобелье',
#  'тестобустеры',
#  'толстовки',
#  'туринги',
#  'углеводы',
#  'футболки',
#  'фэтбайки',
#  'хондропротекторы (глюкозамин, хондроитин)',
#  'циклокросс',
#  'чехлы',
#  'шапки',
#  'шлемы',
#  'шоссейные',
#  'штаны сноубордические',
#  'энергетики'}

# %%
data = pd.read_excel('./sport/pro-bike/data.xls')
data.head()
# Out:
#                                             Название  Описание         Цена
# 0  Велосипеды~Горный велосипед~Alpine Bike 1000S ...       NaN  11 490 pуб.
# 1  Велосипеды~Детский велосипед~Alpine Bike F1 (2...       NaN  20 490 pуб.
# 2  Велосипеды~Горный велосипед~Stels Navigator 66...       NaN  17 400 pуб.
# 3  Велосипеды~Дорожный велосипед~Schwinn Alu 7 Wo...       NaN  19 500 pуб.
# 4  Велосипеды~Детский велосипед~Schwinn Baywood 2...       NaN  10 700 pуб.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15228 entries, 0 to 15227
# Data columns (total 3 columns):
# Название    15228 non-null object
# Описание    0 non-null float64
# Цена        10981 non-null object
# dtypes: float64(1), object(2)
# memory usage: 357.0+ KB

# %%
data = data.dropna(subset=['Цена'])

# %%
def to_num_gold(text):
    return int(''.join(text.replace('pуб.', '').split()))

# %%
data['Цена'] = data['Цена'].apply(to_num_gold)

# %%
data.head()
# Out:
#                                             Название  Описание   Цена
# 0  Велосипеды~Горный велосипед~Alpine Bike 1000S ...       NaN  11490
# 1  Велосипеды~Детский велосипед~Alpine Bike F1 (2...       NaN  20490
# 2  Велосипеды~Горный велосипед~Stels Navigator 66...       NaN  17400
# 3  Велосипеды~Дорожный велосипед~Schwinn Alu 7 Wo...       NaN  19500
# 4  Велосипеды~Детский велосипед~Schwinn Baywood 2...       NaN  10700

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10981 entries, 0 to 15227
# Data columns (total 3 columns):
# Название    10981 non-null object
# Описание    0 non-null float64
# Цена        10981 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 343.2+ KB

# %%
data.to_excel('./sport/pro-bike/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./sport/pro-bike/data_cleaned.xls')
data.head()
# Out:
#                                             Название  Описание   Цена
# 0  Велосипеды~Горный велосипед~Alpine Bike 1000S ...       NaN  11490
# 1  Велосипеды~Детский велосипед~Alpine Bike F1 (2...       NaN  20490
# 2  Велосипеды~Горный велосипед~Stels Navigator 66...       NaN  17400
# 3  Велосипеды~Дорожный велосипед~Schwinn Alu 7 Wo...       NaN  19500
# 4  Велосипеды~Детский велосипед~Schwinn Baywood 2...       NaN  10700

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10981 entries, 0 to 10980
# Data columns (total 3 columns):
# Название    10981 non-null object
# Описание    0 non-null float64
# Цена        10981 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 257.4+ KB

# %%
def process_bike(text, ind=0):
    slots.update(text.strip().lower().split('~')[:2])
    return text

data['Название'].apply(process_bike)
slots
# Out:
# {'686',
#  'airblaster',
#  'amplifi',
#  'anon',
#  'anteater',
#  'arbor',
#  'bern',
#  'bmx',
#  'bmx велосипед',
#  'bonus gloves',
#  'buff',
#  'burton',
#  'clwr',
#  'cool zone',
#  'dc',
#  'dragon',
#  'flow',
#  'gnu',
#  'head',
#  'howl',
#  'joint',
#  'jones',
#  'lib tech',
#  'lidakis',
#  'lopoma',
#  'losraketos',
#  'merge4',
#  'nandn',
#  'oakley',
#  'only',
#  'prime',
#  'prosurf',
#  'quiksilver',
#  'red',
#  'romp',
#  'roxy',
#  'sims',
#  'spy+',
#  'terror',
#  'thirtytwo',
#  'today',
#  'true spin',
#  'union',
#  'viking',
#  'vonzipper',
#  'аксессуары',
#  'активное долголетие',
#  'аминокислоты',
#  'балаклавы и бафы',
#  'банданы',
#  'ботинки',
#  'бустеры гормона роста',
#  'веломайки',
#  'велосипеды',
#  'витамины и минералы',
#  'гейнеры (белки+углеводы)',
#  'горные',
#  'горный велосипед',
#  'городские',
#  'готовые напитки',
#  'двухподвесы',
#  'детские',
#  'детский велосипед',
#  'диетическое питание',
#  'для питомцев',
#  'дорожный велосипед',
#  'жилетки',
#  'жиросжигатели',
#  'защита',
#  'защитная экипировка',
#  'комбинезоны',
#  'креатин',
#  'крепления',
#  'крепления и сноуборд trs',
#  'куртки городские',
#  'куртки сноубордические',
#  'маски',
#  'наборы спортивного питания',
#  'нитробустеры',
#  'носки',
#  'ночные восстановители',
#  'одежда',
#  'одежда женская',
#  'одежда мужская',
#  'перчатки и варежки',
#  'посттренировочные комплексы и восстановители',
#  'предтренировочные комплексы',
#  'протеины',
#  'рюкзаки',
#  'самокат',
#  'самокаты',
#  'сноубординг',
#  'сноуборды',
#  'специальные препараты',
#  'спортивный перекус',
#  'стрит',
#  'термобелье',
#  'тестобустеры',
#  'толстовки',
#  'туринги',
#  'углеводы',
#  'футболки',
#  'фэтбайки',
#  'хондропротекторы (глюкозамин, хондроитин)',
#  'циклокросс',
#  'чехлы',
#  'шапки',
#  'шлемы',
#  'шоссейные',
#  'шоссейный велосипед',
#  'штаны сноубордические',
#  'электровелосипед',
#  'энергетики'}

# %%
data = pd.read_excel('./sport/tramontana.ru/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Одежда~Брюки~Утепленные брюки~Брюки SIVERA Сул...
# 1  Одежда~Куртки~Мембранные куртки~Куртка The Nor...
# 2  Снаряжение для промышленного альпинизма~Сидушк...
# 3  Альпинизм и скалолазание~Страховочные системы~...
# 4  Снаряжение для промышленного альпинизма~Спуско...
#
#                                             Описание      Цена
# 0  Женские мембранные штаны на синтетическом утеп...   6 440 ₽
# 1  Легкая и компактная куртка для для защиты от н...  17 900 ₽
# 2  Рабочее сиденье PODIUM обеспечивает комфорт пр...  13 700 ₽
# 3  Очень комфортная обвязка для продвинутого лаза...   9 160 ₽
# 4  Самостраховка ASAP’SORBER International исполь...   3 090 ₽

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3605 entries, 0 to 3604
# Data columns (total 3 columns):
# Название    3599 non-null object
# Описание    3487 non-null object
# Цена        3602 non-null object
# dtypes: object(3)
# memory usage: 84.6+ KB

# %%
data = data.dropna(subset=['Цена'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3602 entries, 0 to 3604
# Data columns (total 3 columns):
# Название    3596 non-null object
# Описание    3484 non-null object
# Цена        3602 non-null object
# dtypes: object(3)
# memory usage: 112.6+ KB

# %%
def to_num_tramontana(text):
    return int(''.join(str(text).replace('₽', '').split()))

# %%
data['Цена'] = data['Цена'].apply(to_num_tramontana)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3602 entries, 0 to 3604
# Data columns (total 3 columns):
# Название    3596 non-null object
# Описание    3484 non-null object
# Цена        3602 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 112.6+ KB

# %%
data.to_excel('./sport/tramontana.ru/data_cleaned.xls', index=False)
data = pd.read_excel('./sport/tramontana.ru/data_cleaned.xls')
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3602 entries, 0 to 3601
# Data columns (total 3 columns):
# Название    3596 non-null object
# Описание    3484 non-null object
# Цена        3602 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 84.5+ KB

# %%
def process_tramontana(text, ind=0):
    slots.update(str(text).strip().lower().split('~')[:2])
    return text

data['Название'].apply(process_tramontana)
slots
# Out:
# {'686',
#  'airblaster',
#  'amplifi',
#  'anon',
#  'anteater',
#  'arbor',
#  'bern',
#  'bmx',
#  'bmx велосипед',
#  'bonus gloves',
#  'buff',
#  'burton',
#  'clwr',
#  'cool zone',
#  'dc',
#  'dragon',
#  'flow',
#  'gnu',
#  'head',
#  'howl',
#  'joint',
#  'jones',
#  'lib tech',
#  'lidakis',
#  'lopoma',
#  'losraketos',
#  'merge4',
#  'nan',
#  'nandn',
#  'nite ize. steelie',
#  'oakley',
#  'only',
#  'prime',
#  'prosurf',
#  'quiksilver',
#  'red',
#  'romp',
#  'roxy',
#  'sims',
#  'spy+',
#  'terror',
#  'thirtytwo',
#  'thule',
#  'today',
#  'true spin',
#  'union',
#  'viking',
#  'vonzipper',
#  'аксессуары',
#  'активное долголетие',
#  'альпинизм и скалолазание',
#  'аминокислоты',
#  'балаклавы и бафы',
#  'банданы',
#  'бахилы, гамаши',
#  'блоки-ролики и полиспасты',
#  'ботинки',
#  'брюки',
#  'бустеры гормона роста',
#  'веломайки',
#  'велосипеды',
#  'веревки и стропы',
#  'веревки, шнуры, стропы',
#  'витамины и минералы',
#  'газовое оборудование',
#  'гамаки',
#  'гейнеры (белки+углеводы)',
#  'горнолыжное снаряжение',
#  'горные',
#  'горный велосипед',
#  'городская обувь',
#  'городские',
#  'готовые напитки',
#  'двухподвесы',
#  'детские',
#  'детский велосипед',
#  'диетическое питание',
#  'для питомцев',
#  'дорожный велосипед',
#  'еда',
#  'жилетки',
#  'жилеты',
#  'жиросжигатели',
#  'зажимы',
#  'зажимы для промышленного альпинизма',
#  'зацепы и фингерборды',
#  'защита',
#  'защита для промышленного альпинизма',
#  'защитная экипировка',
#  'зимняя обувь',
#  'инструмент',
#  'ито',
#  'карабины',
#  'карабины и коннекторы',
#  'каски спортивные',
#  'клифа 5.14 с подколен. петлёй правая',
#  'коврики. подушки. полотенца',
#  'комбинезоны',
#  'креатин',
#  'крепления',
#  'крепления и сноуборд trs',
#  'кроссовки',
#  'куртки',
#  'куртки городские',
#  'куртки сноубордические',
#  'ледовое снаряжение',
#  'магнезия спортивная',
#  'маски',
#  'маты',
#  'мебель',
#  'мешочки для магнезии',
#  'молотки',
#  'наборы спортивного питания',
#  'нитробустеры',
#  'носки',
#  'ночные восстановители',
#  'оборудование для организации страховки',
#  'обувь',
#  'обувь для альпинизма и спортивного туризма',
#  'одежда',
#  'одежда женская',
#  'одежда мужская',
#  'оттяжки',
#  'очки',
#  'перчатки и варежки',
#  'петли',
#  'петли, самостраховки, стремена',
#  'печатная продукция',
#  'платья и юбки',
#  'подарочные сертификаты',
#  'посттренировочные комплексы и восстановители',
#  'посуда',
#  'походное снаряжение',
#  'предтренировочные комплексы',
#  'привязи',
#  'протеины',
#  'разгрузки',
#  'рубашки, толстовки, свитера',
#  'рюкзаки',
#  'самокат',
#  'самокаты',
#  'самостраховки и амортизаторы рывка',
#  'сандалии',
#  'сидушки для промышленного альпинизма',
#  'скальные туфли',
#  'слэклайны',
#  'снаряжение для арбористики',
#  'снаряжение для промышленного альпинизма',
#  'сноубординг',
#  'сноуборды',
#  'спальные мешки',
#  'специальные препараты',
#  'спортивный перекус',
#  'спусковые и страховочные устройства',
#  'страховочные системы',
#  'стремена. лесенки',
#  'стрит',
#  'такелажные звенья для промышленного альпинизма',
#  'термобелье',
#  'тестобустеры',
#  'толстовки',
#  'точки страховки',
#  'треккинговая обувь',
#  'треккинговые палки',
#  'туринги',
#  'туристические палатки',
#  'углеводы',
#  'украшения',
#  'фильтры',
#  'фонари',
#  'фонари для промышленного альпинизма',
#  'футболки',
#  'фэтбайки',
#  'хондропротекторы (глюкозамин, хондроитин)',
#  'циклокросс',
#  'чехлы',
#  'шапки',
#  'шлемы',
#  'шоссейные',
#  'шоссейный велосипед',
#  'штаны сноубордические',
#  'электровелосипед',
#  'электроника',
#  'энергетики'}

# %%
#iHerb
data = pd.read_excel('./sport/iHerb.com/data.xls')
data.head()
# Out:
#                                             Название  Описание     Цена
# 0  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽403.98
# 1  Бренды А-Я~ Now Foods~ ~ Категории~ Пищевые до...       NaN  ₽645.70
# 2  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽538.64
# 3  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽471.31
# 4  Бренды А-Я~ ChildLife~ ~ Категории~ Для малыше...       NaN  ₽406.68

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17161 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17157 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null object
# dtypes: float64(1), object(2)
# memory usage: 402.3+ KB

# %%
data = data.dropna(subset=['Цена'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17098 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null object
# dtypes: float64(1), object(2)
# memory usage: 534.3+ KB

# %%
def to_num_iherb(text):
    return int(float(''.join(text.replace('₽','').replace(',','').split())))

# %%
data['Цена'] = data['Цена'].apply(to_num_iherb)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17098 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 534.3+ KB

# %%
data.to_excel('./sport/iHerb.com/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./sport/iHerb.com/data_cleaned.xls')
data.head()
# Out:
#                                             Название  Описание  Цена
# 0  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   403
# 1  Бренды А-Я~ Now Foods~ ~ Категории~ Пищевые до...       NaN   645
# 2  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   538
# 3  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   471
# 4  Бренды А-Я~ ChildLife~ ~ Категории~ Для малыше...       NaN   406

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17098 entries, 0 to 17097
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 400.8+ KB

# %%
def process_iherb(text, ind=0):
    slots.update(text.strip().lower().split('~')[1:4])
    return text

data['Название'].apply(process_iherb)
slots
# Out:
# {'самокат',
#  ' similasan',
#  'кроссовки',
#  'jones',
#  'flow',
#  ' seasnax',
#  'наборы спортивного питания',
#  ' absorbaid',
#  ' my magic mud',
#  ' закуски',
#  'страховочные системы',
#  ' ovega-3',
#  'аксессуары',
#  ' зелень и суперпродукты',
#  ' naturade',
#  ' all good products',
#  'lidakis',
#  ' c.c. pollen',
#  ' prince of peace',
#  ' tierra mia organics',
#  ' great lakes gelatin co.',
#  'молотки',
#  ' снотворные',
#  'циклокросс',
#  ' домашняя утварь',
#  ' summer infant',
#  ' thai deodorant stone',
#  ' smartypants',
#  ' ecobags',
#  ' kashi',
#  'шоссейные',
#  " lenny & larry's",
#  ' kabrita',
#  ' veglife',
#  'megafood, детская ежедневная добавка для иммунной системы kids daily immune, без подсластителей, 66 г (2.3 унц.)',
#  ' swerve',
#  ' аминокислоты',
#  ' if you care',
#  'комбинезоны',
#  ' big tree farms',
#  ' halo',
#  'чехлы',
#  ' acure',
#  ' fire cider',
#  ' stash tea',
#  ' oakmont labs',
#  ' harney & sons',
#  ' kevala',
#  ' nutrex hawaii',
#  ' бакалейные товары',
#  ' manukaguard',
#  'точки страховки',
#  ' батончики',
#  ' wellesse premium liquid supplements',
#  ' puppy cake',
#  ' ddrops',
#  ' спортивные добавки',
#  ' ягоды аристотелии чилийская',
#  'электроника',
#  'толстовки',
#  ' childlife',
#  ' essential living foods',
#  ' johnson & johnson',
#  ' i play inc.',
#  ' earth rated',
#  'оборудование для организации страховки',
#  ' eucerin',
#  'веревки, шнуры, стропы',
#  ' pure advantage',
#  ' balance bar ',
#  " annie's homegrown",
#  ' attitude',
#  ' jovial',
#  ' lifetime vitamins',
#  ' california gold nutrition, cgn',
#  ' vital essentials',
#  ' emerald health bioceuticals, inc',
#  ' almondina ',
#  ' hello',
#  ' протеин',
#  ' wedderspoon',
#  ' natural dynamix (ndx)',
#  ' iherb goods',
#  ' bragg',
#  ' safari',
#  'жилеты',
#  'спусковые и страховочные устройства',
#  ' relacore',
#  ' reviva labs',
#  'платья и юбки',
#  " bob's red mill",
#  ' alkalife',
#  ' hot kid',
#  ' rebody safslim',
#  'веломайки',
#  'протеины',
#  'готовые напитки',
#  ' wilderness poets llc',
#  ' artisana',
#  'фильтры',
#  'buff',
#  ' port trading co.',
#  ' восстановление после тренировки',
#  ' heimish',
#  'solgar, celadrin, 525mg, 60 softgels',
#  ' popchips',
#  ' protocol for life balance',
#  ' solaray',
#  ' blistex',
#  ' the honest kitchen',
#  ' fifty 50',
#  ' diamond herpanacine associates',
#  ' ctd sports',
#  ' зубная нить',
#  ' youtheory',
#  ' nordic naturals professional',
#  'петли, самостраховки, стремена',
#  ' leven rose',
#  " barry's tea",
#  ' life source basics (wgp beta glucan)',
#  ' mrs. dash',
#  ' крекеры',
#  ' blender bottle',
#  ' fish-oil, omegas, sports',
#  ' vita logic',
#  ' earnest eats ',
#  ' мелатонин',
#  ' sprout living',
#  ' best naturals',
#  ' sun potion',
#  ' строители мышц',
#  ' advanced orthomolecular research aor',
#  ' продукты для выпечки, мука и смеси',
#  ' sonne’s organic foods',
#  ' orgain',
#  ' rsp nutrition',
#  ' tooth tissues',
#  ' new nordic us inc',
#  " barlean's",
#  ' healthsmart foods, inc.',
#  'коврики. подушки. полотенца',
#  ' kettle & fire',
#  ' cobra labs',
#  ' препараты с глюкозамином',
#  ' vitafusion',
#  ' prevagen (quincy-bioscience)',
#  ' препараты для памяти и когнитивных функций',
#  ' pines international',
#  ' селен',
#  'бустеры гормона роста',
#  'red',
#  ' креатин, спорт',
#  ' mestemacher',
#  ' dear, klairs',
#  " nature's plus",
#  ' flapjacked',
#  'amplifi',
#  ' houston enzymes',
#  ' genexa llc',
#  ' nature republic',
#  ' natural sport',
#  " hyland's",
#  ' indiumease',
#  ' metabolic maintenance',
#  ' allvia',
#  ' scandinavian formulas',
#  ' якорцы стелющиеся',
#  ' дом',
#  ' naturvet',
#  'городская обувь',
#  ' deva',
#  ' dukan diet',
#  ' sejoyia',
#  'сандалии',
#  ' батончики для перекуса',
#  ' royal tropics',
#  ' novex biotech',
#  ' wise essentials',
#  ' hyperbiotics',
#  'romp',
#  " lily's sweets",
#  'true spin',
#  ' frownies',
#  ' the missing link',
#  ' sinol',
#  ' res-q',
#  ' aurora nutrascience',
#  ' real aloe inc.',
#  ' one brands',
#  ' варенье',
#  'велосипеды',
#  ' labrada nutrition',
#  ' zint',
#  ' beyond fresh',
#  ' meyenberg goat milk',
#  ' pure protein',
#  " george's aloe vera",
#  ' upspring',
#  ' coromega',
#  ' neilmed',
#  ' бульоны и мясные отвары',
#  ' aquaphor',
#  ' genceutic naturals',
#  ' kind bars',
#  ' maine coast sea vegetables',
#  ' surf-sweets',
#  ' etude house',
#  ' ecodiscoveries',
#  ' silicium laboratories llc',
#  'посуда',
#  ' visine',
#  ' real health',
#  ' кешью',
#  ' yum-vs',
#  ' airborne',
#  'туристические палатки',
#  'зажимы для промышленного альпинизма',
#  ' ener-c',
#  ' sage spirit',
#  ' weleda',
#  ' life enhancement',
#  ' garden of life',
#  ' coconut secret',
#  'брюки',
#  ' магний',
#  ' cat dancer',
#  ' eidon mineral supplements',
#  ' maximum human performance, llc',
#  ' vital proteins',
#  'new chapter, сила костей, будь здоров, 120 таблеток',
#  ' антиоксиданты',
#  ' dietworks',
#  ' чага',
#  ' протеиновые смеси',
#  ' кордицепс',
#  'queen helene, скраб с мятным джулепом, 6 унций (170 г)',
#  ' skratch labs',
#  'горнолыжное снаряжение',
#  ' cleanwell',
#  " schmidt's naturals",
#  ' dr. woods',
#  ' appliednutrition',
#  ' miracle care',
#  ' nutrition now',
#  'bern',
#  ' bionaturae',
#  ' диетические средства',
#  'today',
#  'газовое оборудование',
#  ' pb2 foods',
#  'разгрузки',
#  ' xyloburst',
#  ' evlution nutrition',
#  ' категории',
#  'howl',
#  ' sundown naturals',
#  ' pacifica',
#  ' redcon1',
#  ' смеси аминокислот',
#  ' life-flo',
#  'петли',
#  ' рейши',
#  ' historical remedies',
#  ' zma',
#  ' country comfort',
#  ' chimes',
#  ' california olive ranch',
#  'обувь для альпинизма и спортивного туризма',
#  ' davinci laboratories of vermont',
#  ' everyday shea',
#  ' aveeno',
#  " mommy's bliss",
#  ' growing naturals',
#  ' simple mills',
#  'viking',
#  ' andalou naturals',
#  ' g9skin',
#  ' life extension',
#  'специальные препараты',
#  ' грибы',
#  ' biotivia',
#  'union',
#  ' tinkyada',
#  'куртки',
#  ' dr. dunner, usa',
#  ' асаи',
#  ' коэнзим q10 (coq10)',
#  ' biogaia',
#  ' b-fresh inc.',
#  ' облегчение симптомов рефлюкса',
#  ' nuk',
#  ' physicians formula',
#  'снаряжение для арбористики',
#  ' boericke & tafel',
#  ' kroeger herb co',
#  ' neutrogena',
#  ' rainbow light',
#  'крепления',
#  ' vet organics',
#  ' добавки для приема перед тренировкой',
#  ' iforce nutrition ',
#  ' renew life',
#  'гейнеры (белки+углеводы)',
#  ' зелень',
#  ' torie & howard',
#  ' allmax nutrition',
#  ' terrasoul superfoods',
#  'now foods, жидкое кокосовое масло, чистое ректифицированное, 473 мл',
#  ' pixi beauty',
#  ' hero nutritional products',
#  ' healthy origins',
#  ' витамин с',
#  ' petal fresh',
#  ' mt. capra',
#  ' bodylogix',
#  'now foods, гелевые капсулы с целадрином, 350 мг, 90 гелевых капсул',
#  ' abkit',
#  ' azo',
#  ' quantum health',
#  ' arm & hammer',
#  ' onnit',
#  ' modern products',
#  ' hi tech pharmaceuticals',
#  ' zand',
#  ' badger company',
#  'жиросжигатели',
#  ' neosporin',
#  ' reese',
#  ' goorganic',
#  " nature's one",
#  ' health thru nutrition',
#  ' клк (конъюгированная линолевая кислота)',
#  " nature's herbs",
#  ' масла, спреды и пресервы',
#  ' brothers-all-natural',
#  ' brainstrong',
#  ' method',
#  'энергетики',
#  ' dynamic health',
#  ' nugo nutrition',
#  ' giovanni',
#  ' bluebonnet nutrition',
#  ' kal',
#  ' miracle noodle',
#  " nature's best, isopure",
#  ' phion balance',
#  " d'adamo personalized nutrition",
#  ' earth balance ',
#  ' ancient secrets, lotus brand inc.',
#  ' rhythm superfoods',
#  ' equal exchange ',
#  ' a.c. grace company',
#  'thule',
#  ' tpcs',
#  " michael's naturopathic",
#  ' body fortress',
#  ' grape seed extract',
#  ' evolution of smooth',
#  " charlie's soap, inc.",
#  ' ancient harvest',
#  ' buckley',
#  ' формулы с оксидом азота',
#  ' musclemaxx',
#  ' margarite cosmetics',
#  ' lansinoh',
#  ' himalania',
#  ' травы',
#  ' pure planet',
#  ' vibrant health',
#  ' aroma naturals',
#  'защита',
#  ' made in nature',
#  ' vital planet',
#  'sims',
#  ' alba botanica',
#  'защитная экипировка',
#  ' peanut butter & co.',
#  ' семена чиа',
#  ' all one, nutritech',
#  ' buried treasure',
#  ' quest nutrition',
#  ' bach',
#  'стрит',
#  ' riley’s organics',
#  ' herbal answers, inc',
#  ' aloha bay',
#  'dc',
#  ' viesun',
#  ' мужские мультивитамины',
#  ' незаменимые жирные кислоты, комбинации омега 3-6-9',
#  ' ulubulu',
#  'quiksilver',
#  ' flintstones',
#  ' sunwarrior',
#  ' ',
#  ' daily wellness company',
#  " jack n' jill",
#  ' goddess garden',
#  ' spectrum essentials',
#  ' reaal',
#  ' гейнеры',
#  ' traditional medicinals',
#  ' dandy blend',
#  ' nordic naturals',
#  ' master supplements',
#  ' afterspa',
#  ' met-rx',
#  ' buff bake',
#  ' гидроксиметилбутират',
#  ' champion nutrition',
#  ' mushroom wisdom',
#  ' starwest botanicals',
#  ' alta health',
#  ' rishi tea',
#  " earth's best",
#  ' one-a-day',
#  ' бетагидроксибутиратные соли',
#  ' maximum international',
#  ' препараты для жкт',
#  ' amazing grass',
#  ' суп и бульон',
#  ' sunfood',
#  ' beauty without cruelty',
#  ' jennies gluten free bakery',
#  " o'keeffe's",
#  ' sotru',
#  ' huy fong foods inc.',
#  ' fungi perfecti ',
#  ' actipet',
#  ' какао',
#  ' mustela',
#  " nature's baby organics",
#  ' azelique',
#  ' scivation',
#  ' mad hippie skin care products',
#  ' manuka health',
#  ' goco',
#  ' уход за телом',
#  ' snp',
#  'инструмент',
#  ' naka herbs & vitamins ltd',
#  ' средства для душа и ухода',
#  'сидушки для промышленного альпинизма',
#  'слэклайны',
#  ' ip-6 international',
#  ' lily of the desert',
#  ' flora',
#  ' natural sources',
#  'рюкзаки',
#  " earth's bounty ( matrix health ) ",
#  ' nutrabio labs',
#  ' earth mama',
#  ' finn crisp',
#  ' гидратация и электролиты',
#  'треккинговые палки',
#  'bmx велосипед',
#  ' физалис',
#  " heather's tummy care",
#  ' j r watkins',
#  ' earth science',
#  'крепления и сноуборд trs',
#  " nature's gate",
#  ' kelapo',
#  ' toms of maine',
#  ' каму-каму',
#  ' хром',
#  ' sambucol',
#  ' seapoint farms',
#  ' l-цитруллин',
#  ' doggie sudz',
#  ' schiff',
#  ' savesta',
#  ' world organic',
#  'клифа 5.14 с подколен. петлёй правая',
#  ' для малышей и детей постарше',
#  ' cetaphil',
#  ' twinlab',
#  ' vetri-science',
#  'штаны сноубордические',
#  'мешочки для магнезии',
#  ' мультивитамины',
#  ' estroven',
#  'lopoma',
#  ' bucked up',
#  'фонари для промышленного альпинизма',
#  ' living clay',
#  ' протеин казеиновый',
#  ' natrabio',
#  ' питомцы',
#  'креатин',
#  ' nuby',
#  ' l-карнитин',
#  ' sky organics',
#  ' art naturals',
#  'vonzipper',
#  'перчатки и варежки',
#  ' cardiovascular research ltd.',
#  ' растительный белок',
#  'привязи',
#  ' e.l.f. cosmetics',
#  ' fini modena',
#  ' yerba prima',
#  ' шелковица',
#  ' tony moly',
#  'dragon',
#  ' optimox corporation',
#  ' biosil by natural factors',
#  ' well wisdom',
#  ' liddell',
#  ' витамин d',
#  'lib tech',
#  'joint',
#  ' кокосовая мука',
#  ' irwin naturals',
#  ' lifeseasons ',
#  ' femarelle',
#  ' futurebiotics',
#  ' ecover',
#  'стремена. лесенки',
#  ' корица',
#  ' тертое какао',
#  'туринги',
#  ' nutricology',
#  'nandn',
#  ' mediheal',
#  ' aztec secret',
#  ' gostak',
#  ' europharma, terry naturally',
#  " mane 'n tail",
#  ' the ginger people',
#  ' солнцезащитные средства для малышей',
#  ' oxylife',
#  ' для мытья посуды',
#  'therabreath, добавка для воды "свежее дыхание", для собак и кошек, умеренный аромат, 16 жид. унций (473 мл)',
#  " molly's suds",
#  ' maxim hygiene products',
#  ' auromere',
#  'мебель',
#  ' frontier natural products',
#  ' flower essence services',
#  ' kolorex',
#  ' nu-pore',
#  ' herb pharm',
#  ' препараты для беременных и родивших женщин',
#  ' jeffrey james botanicals',
#  'now foods, решения, кокосовое масло, 7 жидк. унц. (207 мл)',
#  ' avalon organics',
#  ' plum organics',
#  ' bioglan',
#  ' nutramax',
#  ' humann',
#  ' sai baba',
#  ' витамины и минералы для питомцев',
#  ' suncoatgirl',
#  ' bn labs',
#  ' aerobic life',
#  ' band aid',
#  ' everyday coconut',
#  ' align',
#  ' bar keepers friend',
#  ' macrolife naturals',
#  ' соль',
#  ' carlson labs',
#  ' чай',
#  ' himalaya',
#  ' abracadabra, abra therapeutics',
#  ' alvera',
#  ' st. ives',
#  ' кальций',
#  ' спортивное питание',
#  ' fearn natural food',
#  ' living intentions',
#  'спальные мешки',
#  ' пробиотики',
#  ' nescafé',
#  'protocol for life balance, bone support formula, 180 capsules',
#  ' novaforme',
#  ' endangered species chocolate',
#  'самокаты',
#  ' фрукты и овощи',
#  ' препараты для волос, кожи и ногтей',
#  ' golden flower',
#  ' l-глютамин',
#  " michelle's miracle",
#  ' bausch & lomb',
#  ' nla for her',
#  ' petalive',
#  ' кости и суставы',
#  ' herbatint (antica herbavita)',
#  ' микроэлементы',
#  ' de la cruz',
#  ' mizon',
#  ' carrington farms',
#  ' st. dalfour',
#  ' zhou nutrition',
#  ' травы и специи',
#  'балаклавы и бафы',
#  ' cat-man-doo',
#  ' лукума',
#  ' sea tangle noodle company',
#  " wiley's finest",
#  ' naturalcare',
#  ' oregons wild harvest',
#  'украшения',
#  " dr. harvey's",
#  'ночные восстановители',
#  ' naturally vitamins',
#  ' bio-strath',
#  'одежда мужская',
#  ' walden farms',
#  ' caribbean solutions',
#  'обувь',
#  'термобелье',
#  ' coral llc',
#  'thirtytwo',
#  ' klamath',
#  'подарочные сертификаты',
#  ' seventh generation',
#  ' think',
#  ' lumineux oral essentials',
#  " o'donnell formulas",
#  ' panda licorice',
#  ' rejuvicare',
#  ' bioadvantex pharma',
#  ' teras whey',
#  ' миндаль',
#  ' nuco',
#  ' twinings',
#  ' nurturme',
#  " snyder's",
#  ' ароматерапия и эфирные масла',
#  ' terra origin',
#  ' спортивные батончики, печенье, пирожные',
#  " honey i'm home",
#  ' bcaa',
#  ' i heart keenwah',
#  " dr. brown's",
#  ' the saem',
#  ' montana big sky ',
#  ' aleva naturals',
#  ' beco pets',
#  'одежда',
#  ' heritage store',
#  ' wiseways herbals, llc',
#  ' complimed',
#  ' holika holika',
#  ' purity products',
#  ' honey gardens',
#  ' universal nutrition',
#  ' hobe labs',
#  'anteater',
#  'bonus gloves',
#  ' yogourmet',
#  ' enjoy life foods',
#  ' чай с ромашкой',
#  'еда',
#  ' furious formulations',
#  ' neuroscience',
#  ' ojio',
#  ' healthy times',
#  ' zahler',
#  ' boiron',
#  ' уход за питомцами',
#  ' пищеварительные ферменты',
#  'блоки-ролики и полиспасты',
#  ' allimax',
#  ' грибные смеси',
#  ' swisse',
#  ' cococare',
#  ' edward & sons',
#  ' протеиновые батончики',
#  'печатная продукция',
#  ' oxyfresh',
#  ' celtic sea salt',
#  ' pure vegan',
#  ' кокосовый сахар',
#  ' kyolic',
#  'посттренировочные комплексы и восстановители',
#  'ботинки',
#  ' kalaya calandri',
#  'углеводы',
#  ' mri',
#  ' жиросжигатели',
#  ' baby banana',
#  ' country archer jerky',
#  ' primal kitchen',
#  ' i and love and you',
#  ' natracare',
#  ' health and wisdom inc.',
#  'маски',
#  " nature's secret",
#  ' organic india',
#  ' real foods',
#  ' гинкго билоба',
#  ' cosrx',
#  ' arthur andrew medical',
#  ' spectrum culinary',
#  ' mrs. meyers clean day',
#  ' superior source',
#  ' health plus inc.',
#  'снаряжение для промышленного альпинизма',
#  ' t-rq',
#  ' vitanica',
#  ' earthtone foods',
#  ' natrol',
#  ' bio kleen',
#  ' greens first',
#  ' smith & vandiver',
#  ' mount hagen',
#  " garden of eatin'",
#  ' thompson',
#  ' clean machine',
#  ' thorne research',
#  ' liverite',
#  ' zenwise health',
#  ' herbs for kids',
#  ' radius',
#  'куртки городские',
#  ' grandpas',
#  ' minami nutrition',
#  ' california natural',
#  'gnu',
#  'футболки',
#  ' dang foods llc',
#  ' citracal',
#  ' maranatha',
#  'arbor',
#  ' чай маття',
#  ' therabreath',
#  ' the face shop',
#  ' nasopure',
#  ' muscletech',
#  ' гарциния камбоджийская',
#  ' kericure',
#  ' graminex',
#  ' crystal body deodorant',
#  ' rocco & roxie',
#  'сноуборды',
#  ' детские мультивитамины',
#  ' econugenics',
#  " doctor's best",
#  'альпинизм и скалолазание',
#  'queen helene, скраб с овсяными хлопьями и медом, 6 унций (170 г)',
#  ' benton',
#  ' the natural dentist',
#  ' sovereign silver',
#  ' neocell',
#  'детские',
#  ' organyc',
#  ' motherlove',
#  ' hydroxycut',
#  ' клюква',
#  'prime',
#  ' emerita',
#  ' лососевое масло',
#  " uncle lee's tea",
#  " nature's wild organic ",
#  ' aura cacia',
#  ' gat',
#  ' andean dream ',
#  ' global healthcare',
#  ' ooh snap!',
#  ' cerave',
#  ' средства для ухода за детскими домашними вещами',
#  ' nubian heritage',
#  ' bionorica',
#  ' пренатальные витамины',
#  ' чеснок, специи',
#  ' xlear',
#  ' crystal star',
#  ' musclepharm natural',
#  ' prelief',
#  " men's health",
#  ' plantfusion',
#  ' травы и гомеопатия',
#  'одежда женская',
#  ' ast sports science',
#  ' shikai',
#  ' mild by nature',
#  " nature's life",
#  ' женские мультивитамины',
#  ' honees',
#  ' full circle home llc',
#  ' natural path silver wings',
#  ' greens world',
#  'anon',
#  ' nutra biogenesis',
#  ' nutribiotic',
#  ' gummiking',
#  ' american health',
#  'каски спортивные',
#  ' american biosciences',
#  ' nutralife',
#  ' ultra enterprises',
#  ' лосьон',
#  ' sierra bees',
#  ' kaged muscle',
#  ' quality of life labs',
#  ' harmonic innerprizes',
#  " women's health",
#  ' country life',
#  ' mori-nu',
#  ' culturelle',
#  ' north american herb & spice co.',
#  ' organic traditions',
#  ' biochem',
#  ' мицеллярный казеиновый протеин',
#  ' morningstar minerals',
#  ' eating evolved',
#  ' rapidfire',
#  ' the synergy company',
#  ' fitmiss',
#  ' designer protein',
#  ' шампунь',
#  'prosurf',
#  ' health warrior, inc.',
#  ' gaea',
#  ' prolab',
#  ' madre labs',
#  ' dickinson brands',
#  ' sports research',
#  ' cascadian farm',
#  'для питомцев',
#  'диетическое питание',
#  ' herbion',
#  'оттяжки',
#  ' better life',
#  ' american biotech labs',
#  ' organic valley',
#  'треккинговая обувь',
#  ' уход за животными',
#  ' foodscience',
#  ' plant therapy',
#  ' wobenzym n',
#  ' medinatura',
#  ' rapunzel',
#  'new chapter, эстротон, 60 вегетарианских капсул',
#  ' symbiotics',
#  'new chapter, bone strength take care, 270 таблеток',
#  'terror',
#  ' черника',
#  ' pure bites',
#  ' бутылки, шейкеры и вода',
#  ' 21st century',
#  ' petnc natural care',
#  ' metamucil',
#  " nature's answer",
#  ' yumearth',
#  ' wisdom natural',
#  ' a vogel',
#  ' fairhaven health',
#  'clwr',
#  ' femme',
#  ' бузина',
#  'нитробустеры',
#  'сноубординг',
#  ' zantrex',
#  ' homeolab usa',
#  ' bio tech pharmacal, inc',
#  ' adora',
#  ' earth therapeutics',
#  ' twist',
#  'acure, brilliantly brightening, скраб для лица, 4 ж. унц. (118 мл)',
#  ' osteo bi-flex',
#  ' citrus magic',
#  ' pero',
#  ' заменители пищи',
#  ' amazing herbs',
#  ' fungiology',
#  ' somersaults',
#  ' тестостерон',
#  ' костный бульон',
#  ' eclectic institute',
#  ' stridex',
#  ' vegansmart',
#  " nellie's",
#  ' green foods corporation',
#  ' la tourangelle',
#  ' stewart',
#  ' vitamin friends',
#  ' сон',
#  ' innate response formulas',
#  ' real techniques by sam and nic',
#  ' health direct',
#  'детский велосипед',
#  ' arrowhead mills',
#  ' glorybee',
#  ' greensations',
#  ' bergin fruit and nut company',
#  ' olbas therapeutic',
#  ' greenpeach',
#  ' ягоды годжи',
#  ' amish origins',
#  'шлемы',
#  ' препараты для щитовидной железы',
#  ' диета и контроль веса',
#  ' enzymedica',
#  ' brush buddies',
#  ' petaction plus',
#  ' orajel',
#  ' trace minerals research',
#  ' divine health',
#  ' biotta',
#  'losraketos',
#  ' olympian labs inc.',
#  'burton',
#  ' mrm',
#  ' cocomels',
#  ' dr. axe / ancient nutrition',
#  'горные',
#  ' rainbow research',
#  " naturally it's clean",
#  ' sunbiotics',
#  " nature's path",
#  ' san nutrition',
#  ' jarrow formulas',
#  ' celestial seasonings',
#  ' sheamoisture',
#  ' здоровый образ жизни',
#  " nature's bounty",
#  ' missha',
#  " earth's care",
#  ' carmex',
#  'хондропротекторы (глюкозамин, хондроитин)',
#  ' vaxa international',
#  ' grab green',
#  ' julian bakery',
#  'витамины и минералы',
#  ' ark naturals',
#  ' gaspari nutrition',
#  ' sibu beauty',
#  ' clear products',
#  ' live clean',
#  'активное долголетие',
#  ' ascenta',
#  ' glutino',
#  ' usn',
#  'cool zone',
#  ' desitin',
#  'шоссейный велосипед',
#  ' kettle foods',
#  ' перец',
#  'bmx',
#  ' stoneridge orchards',
#  ' yeouth',
#  ' restore',
#  ' lakanto',
#  ' advance physician formulas, inc.',
#  'зимняя обувь',
#  ' now foods',
#  ' y.s. eco bee farms',
#  ' laird superfood',
#  ' peakfresh usa',
#  ' pioneer nutritional formulas',
#  ' biotech',
#  ' primaforce',
#  ' eden foods',
#  ' omg! organic meets good',
#  ' four sigmatic',
#  ' organic excellence',
#  ' мультиминеральные препараты',
#  ' naturanectar',
#  ' funfresh foods',
#  ' garden greens',
#  ' clif bar',
#  ' back to nature ',
#  ' enzymatic therapy',
#  ' the first years',
#  ' alkazone',
#  ' eat cleaner',
#  ' boogie wipes',
#  ' pure essence',
#  ' home health',
#  ' natralia',
#  ' ola loa',
#  ' holistic blend',
#  ' ryvita',
#  ' earthrise',
#  ' greens plus',
#  ' coombs family farms',
#  ' орви, кашель и грипп',
#  'natural vitality, calm specifics, для детей, питьевая смесь для успокоения и концентрации, натуральные ягоды, 4 унции (113 г)',
#  ' уход за волосами',
#  ' pedialyte',
#  ' волосы, кожа и ногти',
#  ' омега-7',
#  'горный велосипед',
#  ' смеси зелени и суперпродуктов',
#  ' зеленый чай, продукты',
#  'ито',
#  ' white egret personal care',
#  ' ecotools',
#  " ella's kitchen",
#  ' queen helene',
#  ' пищеварение',
#  'only',
#  'тестобустеры',
#  'карабины и коннекторы',
#  ' co - e1',
#  'куртки сноубордические',
#  ...}

# %%
slots = [s.strip() for s in slots if len(s.strip()) < 24]
slots = set(slots)
slots
# Out:
# {'',
#  'big tree farms',
#  'maximum international',
#  'самокат',
#  'finn crisp',
#  'отдельные масла',
#  'кроссовки',
#  'evolution of smooth',
#  'горный велосипед',
#  'jones',
#  'royal tropics',
#  'sunshine',
#  'flow',
#  'allimax',
#  'emerita',
#  'ито',
#  'flapjacked',
#  'aerobic life',
#  "lily's sweets",
#  'brothers-all-natural',
#  "george's aloe vera",
#  'anteater',
#  'bioray inc.',
#  'sai baba',
#  'bonus gloves',
#  'only',
#  'art naturals',
#  'co - e1',
#  'life extension',
#  'real foods',
#  'pure planet',
#  'natrol',
#  'divine health',
#  'abkit',
#  'ecodiscoveries',
#  'тестобустеры',
#  'орехи и семена',
#  'черника',
#  'real health',
#  'еда',
#  'naturalcare',
#  'карабины и коннекторы',
#  'owyn',
#  'страховочные системы',
#  'диетические средства',
#  "lenny & larry's",
#  'imperial elixir',
#  'lifeseasons',
#  'аксессуары',
#  'life enhancement',
#  'optimox corporation',
#  'бузина',
#  'куртки сноубордические',
#  'sprout organic',
#  'real purity',
#  'суп и бульон',
#  'youtheory',
#  'american biotech labs',
#  'upspring',
#  'brainstrong',
#  'complimed',
#  'лосьон',
#  'ayr',
#  'hello',
#  'greenpeach',
#  'natierra',
#  'жиросжигатели',
#  'lidakis',
#  'daily wellness company',
#  'organyc',
#  'aquaphor',
#  'reviva labs',
#  'global healthcare',
#  'печатная продукция',
#  'naturanectar',
#  'philips avent',
#  'домашняя утварь',
#  'longreen corporation',
#  'super nutrition',
#  'молотки',
#  'соль',
#  'протеиновые батончики',
#  'appliednutrition',
#  'herbs for kids',
#  'purely inspired',
#  'natralia',
#  'циклокросс',
#  'california olive ranch',
#  "mommy's bliss",
#  'энергетики',
#  'ботинки',
#  'mediheal',
#  'crown prince natural',
#  'zarbees',
#  'alta health',
#  'avalon organics',
#  'olbas therapeutic',
#  'stewart',
#  'six star',
#  'яблочный уксус',
#  'twinings',
#  'пробиотики для детей',
#  'mri',
#  'creative bioscience',
#  'master supplements',
#  'пробиотики',
#  'углеводы',
#  'зеленый чай, продукты',
#  'interplexus inc.',
#  'viesun',
#  'neuroscience',
#  "hyland's",
#  'шоссейные',
#  'mustela',
#  'yogi tea',
#  'johnson & johnson',
#  'dandy blend',
#  'маски',
#  'мед и подсластители',
#  'meyenberg goat milk',
#  "nature's life",
#  'ultima replenisher',
#  'xlear',
#  'manukaguard',
#  'зубная нить',
#  'pero',
#  'lundberg',
#  "nature's gate",
#  'hot kid',
#  'citracal',
#  'earthrise',
#  'hyperbiotics',
#  'green foods corporation',
#  'gerber',
#  'wiseways herbals, llc',
#  'harmonic innerprizes',
#  'pure indian foods',
#  'novaforme',
#  'bionaturae',
#  'maca magic',
#  'шампунь',
#  'herbal answers, inc',
#  'prelief',
#  'снотворные',
#  'thule',
#  'tea tree therapy',
#  'solgar',
#  'seabuckwonders',
#  'petalive',
#  'culturelle',
#  'комбинезоны',
#  'foodscience',
#  'plant therapy',
#  'kikkoman',
#  'шапки',
#  'greensations',
#  'quality of life labs',
#  "uncle lee's tea",
#  'pet naturals of vermont',
#  'rishi tea',
#  'pure advantage',
#  'ryvita',
#  'eclectic institute',
#  'earth rated',
#  'рыбий жир омега-3',
#  'чехлы',
#  'травы и гомеопатия',
#  'fifty 50',
#  'boogie wipes',
#  'health support',
#  'align',
#  'ctd sports',
#  'general mills',
#  'ascenta',
#  'prosupps',
#  "bob's red mill",
#  'thai deodorant stone',
#  'bragg',
#  'смеси аминокислот',
#  'hi tech pharmaceuticals',
#  'yum-vs',
#  'aztec secret',
#  'sunbiotics',
#  'restore',
#  'омега-7',
#  'squip',
#  'bellybar',
#  'ultra enterprises',
#  'препараты для жкт',
#  'gaia herbs',
#  'natural factors',
#  'yumearth',
#  'actipet',
#  'точки страховки',
#  'innisfree',
#  'biobag',
#  'куртки городские',
#  'the face shop',
#  'isvara organics',
#  'doggie sudz',
#  'электроника',
#  'толстовки',
#  'simply organic',
#  'jamie eason',
#  "michael's naturopathic",
#  'the natural dentist',
#  'scivation',
#  'чага',
#  'dang foods llc',
#  'the honest kitchen',
#  'kettle & fire',
#  'beyond fresh',
#  'защита',
#  'аминокислоты',
#  'gnu',
#  'футболки',
#  'missha',
#  'derma e',
#  "otto's naturals",
#  'olympian labs inc.',
#  'gaea',
#  'sports research',
#  'sims',
#  'acure',
#  'coconut secret',
#  'cat dancer',
#  "jack n' jill",
#  'the synergy company',
#  'primal kitchen',
#  'какао',
#  'защитная экипировка',
#  'уход за телом',
#  'дорожный велосипед',
#  'fire cider',
#  'bio kleen',
#  'greens world',
#  'веревки, шнуры, стропы',
#  'coromega',
#  'all one, nutritech',
#  'fairhaven health',
#  'zand',
#  'костный бульон',
#  'grenade',
#  'petaction plus',
#  'arbor',
#  'городские',
#  'earth science',
#  'bar keepers friend',
#  'vegansmart',
#  'mount hagen',
#  'california natural',
#  'корица',
#  "molly's suds",
#  'therabreath',
#  'brush buddies',
#  'wilderness poets llc',
#  'boiron, single remedies',
#  'spectrum culinary',
#  'зелень и суперпродукты',
#  'goorganic',
#  'clif bar',
#  'desert essence',
#  'safari',
#  'cetaphil',
#  'iherb goods',
#  'real salt',
#  'pure bites',
#  'stash tea',
#  'alkazone',
#  'витамин d',
#  'l-карнитин',
#  'стрит',
#  'new nordic us inc',
#  'original sprout inc',
#  'flora',
#  'спортивный перекус',
#  'gat',
#  'vitanica',
#  'the ginger people',
#  'enjoy life foods',
#  'сывороточный белок',
#  'sage spirit',
#  'prince of peace',
#  'montana big sky',
#  'herbs etc.',
#  'almondina',
#  'для мытья посуды',
#  'dc',
#  'kelapo',
#  'rapunzel',
#  'grab green',
#  'metabolic maintenance',
#  'nla for her',
#  'зелень',
#  'здоровье детей',
#  'tinkyada',
#  'скальные туфли',
#  'heritage store',
#  'quiksilver',
#  'carmex',
#  'bio-kult',
#  'healthsmart foods, inc.',
#  'жилеты',
#  'miracle care',
#  'st. ives',
#  'nutramax',
#  'nuco',
#  'garden greens',
#  'сноуборды',
#  'trace minerals research',
#  'витамины',
#  'закуски',
#  'платья и юбки',
#  'якорцы стелющиеся',
#  'kirkman labs',
#  'atkins',
#  'leven rose',
#  'genexa llc',
#  'kyolic',
#  "nature's herbs",
#  'dietworks',
#  'веломайки',
#  'organic traditions',
#  'foods alive',
#  'allmax nutrition',
#  'buried treasure',
#  'протеины',
#  'a vogel',
#  'готовые напитки',
#  'nuun',
#  'sambucol',
#  'предстательная железа',
#  'cascadian farm',
#  'alkalife',
#  'tierra mia organics',
#  'torie & howard',
#  'железо',
#  'carlson labs',
#  "snyder's",
#  'absorbaid',
#  'carrington farms',
#  'фильтры',
#  'bass brushes',
#  'scandinavian formulas',
#  'cat-man-doo',
#  'adora',
#  'omg! organic meets good',
#  'buff',
#  'julian bakery',
#  'living clay',
#  'cosmedica skincare',
#  'swisse',
#  'ovega-3',
#  'rapidfire',
#  "nature's answer",
#  'rainbow research',
#  'мужские мультивитамины',
#  'plum organics',
#  'растительный белок',
#  'madegood',
#  'lily of the desert',
#  'goddess garden',
#  'vital proteins',
#  'mamma chia',
#  'one brands',
#  "o'keeffe's",
#  'детские',
#  'balanceuticals',
#  'заменители пищи',
#  "dr. tung's",
#  'спортивные добавки',
#  'zahler',
#  'расторопша пятнистая',
#  'кордицепс',
#  'starwest botanicals',
#  'бутылки, шейкеры и вода',
#  'physicians formula',
#  'best naturals',
#  'benton',
#  'sierra bees',
#  'allergy research group',
#  'full circle home llc',
#  'lansinoh',
#  'margarite cosmetics',
#  'the dirt',
#  'чай',
#  'vitamin friends',
#  'earth circle organics',
#  'vaxa international',
#  'prime',
#  'dear, klairs',
#  'panda licorice',
#  'cococare',
#  'масла и спреды',
#  'mrs. meyers clean day',
#  'usn',
#  'nutrition now',
#  'грибы',
#  'terra origin',
#  'graminex',
#  'plantfusion',
#  'orajel',
#  'method',
#  "mane 'n tail",
#  "nature's secret",
#  'асаи',
#  'строители мышц',
#  'alvera',
#  'pure essence',
#  'motherlove',
#  'vega',
#  'dr. dunner, usa',
#  'oakmont labs',
#  'triple leaf tea',
#  'fidobiotics',
#  'mezotrace',
#  'уход за животными',
#  'диета и контроль веса',
#  'zint',
#  "barry's tea",
#  'biotta',
#  'chimes',
#  'everyday shea',
#  'now foods',
#  'thorne research',
#  'allvia',
#  'kashi',
#  'health plus inc.',
#  'dapple',
#  'harney & sons',
#  'nutralife',
#  'eden foods',
#  'pronatura',
#  "men's health",
#  'desitin',
#  'musclemeds',
#  "nature's wild organic",
#  'микроэлементы',
#  'medinatura',
#  'life-flo',
#  'xyloburst',
#  'ледовое снаряжение',
#  'nubian heritage',
#  'коэнзим q10 (coq10)',
#  'пренатальные витамины',
#  'animal essentials',
#  'naturvet',
#  'boericke & tafel',
#  'hobe labs',
#  'батончики для перекуса',
#  'формулы с оксидом азота',
#  'halo',
#  'growing naturals',
#  'инструмент',
#  'neilmed',
#  'macrolife naturals',
#  'лукума',
#  'think',
#  'одежда женская',
#  'country choice organic',
#  'зацепы и фингерборды',
#  'nature made',
#  'solaray',
#  '4th & heart',
#  'whole world botanicals',
#  'swerve',
#  'azo',
#  'iforce nutrition',
#  'уход за питомцами',
#  'musclepharm natural',
#  'man sports',
#  'indiumease',
#  'sunfood',
#  'phillips',
#  'bn labs',
#  'natural sport',
#  'ecover',
#  'aloha bay',
#  'bach',
#  'слэклайны',
#  'sprout living',
#  'caribbean solutions',
#  'pb2 foods',
#  'balance bar',
#  'petnc natural care',
#  'рюкзаки',
#  'lipo naturals',
#  'oakley',
#  'world organic',
#  'fitmiss',
#  'nutiva',
#  'earnest eats',
#  'petitfee',
#  'well wisdom',
#  'anon',
#  'laird superfood',
#  'витамин b',
#  'nuk',
#  'очки',
#  'rainbow light',
#  'vital planet',
#  'каски спортивные',
#  "nature's bounty",
#  'протеин',
#  'креатин, спорт',
#  'gonesh',
#  'sunny green',
#  'canine matrix',
#  'earth mama',
#  'health warrior, inc.',
#  'controlled labs',
#  'the seaweed bath co.',
#  'golden flower',
#  'дом',
#  'biogaia',
#  "heather's tummy care",
#  'nootie',
#  'veggie wash',
#  'vibrant health',
#  'citrus magic',
#  'kalaya calandri',
#  'треккинговые палки',
#  'equal exchange',
#  "nature's best, isopure",
#  'seapoint farms',
#  'neosporin',
#  'celtic sea salt',
#  'bmx велосипед',
#  "nellie's",
#  'manuka health',
#  'thayers',
#  "nairn's inc",
#  'cleanwell',
#  'походное снаряжение',
#  'бустеры гормона роста',
#  'банданы',
#  'wild planet',
#  'red',
#  'sovereign silver',
#  'волосы, кожа и ногти',
#  "nature's way",
#  'celestial seasonings',
#  'etude house',
#  'тертое какао',
#  'smartypants',
#  "annie's homegrown",
#  'terrasoul superfoods',
#  'протеин казеиновый',
#  'san nutrition',
#  'earth therapeutics',
#  'sibu beauty',
#  'кондиционер',
#  'zhou nutrition',
#  'amplifi',
#  'g9skin',
#  'cocomels',
#  'rhythm superfoods',
#  'absolute nutrition',
#  'ener-c',
#  'schiff',
#  "earth's best",
#  'renew life',
#  'черный тмин',
#  'childlife',
#  'vet organics',
#  'nu-pore',
#  'amazon therapeutics',
#  'sky organics',
#  'instanatural',
#  'natracare',
#  'roxy',
#  'skratch labs',
#  'greens first',
#  'gummiking',
#  'nutribiotic',
#  "michelle's miracle",
#  'all good products',
#  'сон',
#  'irwin naturals',
#  'de la cruz',
#  'homeopet',
#  'fini modena',
#  'wise essentials',
#  'umac-core',
#  'prosurf',
#  'weleda',
#  'clean machine',
#  'ecobags',
#  'reaal',
#  "annie's naturals",
#  'jason natural',
#  'nuby',
#  'emerald laboratories',
#  'chocolove',
#  'vita logic',
#  'штаны сноубордические',
#  'teras whey',
#  'yogourmet',
#  'для питомцев',
#  "wiley's finest",
#  'babyganics',
#  'мешочки для магнезии',
#  'band aid',
#  'seventh generation',
#  'andalou naturals',
#  'suncoatgirl',
#  'nasopure',
#  'диетическое питание',
#  'lifetime vitamins',
#  'lopoma',
#  'walden farms',
#  'оттяжки',
#  'living intentions',
#  'thompson',
#  'body fortress',
#  'my magic mud',
#  'детские мультивитамины',
#  'фэтбайки',
#  'amazing grass',
#  'toms of maine',
#  'aveeno',
#  'blistex',
#  'городская обувь',
#  'happy family organics',
#  'the first years',
#  'nurturme',
#  "o'donnell formulas",
#  'лососевое масло',
#  'health and wisdom inc.',
#  'wholesome sweeteners',
#  'антиоксиданты',
#  'bionorica',
#  'y.s. eco bee farms',
#  'pixi beauty',
#  'biotech',
#  'healthy times',
#  'треккинговая обувь',
#  'хром',
#  'сандалии',
#  'almased usa',
#  'country comfort',
#  'kettle foods',
#  'phion balance',
#  'neocell',
#  'протеиновые смеси',
#  "women's health",
#  'romp',
#  'health thru nutrition',
#  'ulubulu',
#  'креатин',
#  'natrabio',
#  'madre labs',
#  'terror',
#  'laneige',
#  'nutrabio labs',
#  'true spin',
#  'чай маття',
#  'enzymatic therapy',
#  'port trading co.',
#  'gostak',
#  'vonzipper',
#  'перчатки и варежки',
#  'грибные смеси',
#  'shea baby',
#  'ancient harvest',
#  'summer infant',
#  'nature republic',
#  'yerba prima',
#  "nature's baby organics",
#  'фрукты и овощи',
#  'valor',
#  'куркума и куркумин',
#  'elizavecca',
#  "nature's one",
#  'osteo bi-flex',
#  'nugo nutrition',
#  'popchips',
#  'велосипеды',
#  'привязи',
#  'femme',
#  'arizona natural',
#  'aroma naturals',
#  'spy+',
#  'paradise herbs',
#  'кальций',
#  'пищевые добавки',
#  'dragon',
#  'pacifica',
#  'рейши',
#  'reese',
#  'grape seed extract',
#  'clwr',
#  "l'il critters",
#  'bioglan',
#  'snp',
#  'vitalah',
#  'rxbar',
#  'novex biotech',
#  'zesty paws',
#  'fit & lean',
#  'futurebiotics',
#  'кокосовая мука',
#  'cerave',
#  'тестостерон',
#  'sun potion',
#  'darford',
#  'g.h. cretors',
#  'sinol',
#  'нитробустеры',
#  'сноубординг',
#  'humphreys',
#  'ancient apothecary',
#  'champion nutrition',
#  'if you care',
#  'lib tech',
#  'holistic blend',
#  'modern products',
#  'физалис',
#  'petal fresh',
#  'probulin',
#  'dickinson brands',
#  'двухподвесы',
#  'castor & pollux',
#  'labrada nutrition',
#  'joint',
#  'earthtone foods',
#  'maranatha',
#  'airblaster',
#  'out of africa',
#  'shake it pup',
#  'i play inc.',
#  'бакалейные товары',
#  'lakanto',
#  'уход за волосами',
#  'hurraw!',
#  'indigo wild',
#  'wellgenix',
#  'mestemacher',
#  'nutricology',
#  'tooth tissues',
#  'himalaya',
#  'peanut butter & co.',
#  'metamucil',
#  'eat cleaner',
#  'sundown naturals',
#  'the missing link',
#  'nunaturals',
#  'zenwise health',
#  'стремена. лесенки',
#  'liddell',
#  'grandpas',
#  'bio tech pharmacal, inc',
#  'tazo teas',
#  'туринги',
#  'mushroom wisdom',
#  'twist',
#  'azelique',
#  'nandn',
#  'oxyfresh',
#  'flintstones',
#  'babo botanicals',
#  'nan',
#  'palmers',
#  'universal nutrition',
#  'посуда',
#  'boiron',
#  'травы и специи',
#  'live clean',
#  'j r watkins',
#  'карабины',
#  'crystal body deodorant',
#  'amazing herbs',
#  'маты',
#  'ridgecrest herbals',
#  'badger company',
#  'селен',
#  'туристические палатки',
#  'andean dream',
#  'mason natural',
#  'oregons wild harvest',
#  'ast sports science',
#  'manuka doctor',
#  'healthforce superfoods',
#  'everyone',
#  'e.l.f. cosmetics',
#  'attitude',
#  'spectrum essentials',
#  'a.c. grace company',
#  'glorybee',
#  'детский велосипед',
#  'pines international',
#  'гамаки',
#  'варенье',
#  'здоровый образ жизни',
#  'жилетки',
#  'ola loa',
#  'rebody safslim',
#  'мебель',
#  'huy fong foods inc.',
#  'pure vegan',
#  'брюки',
#  'leaders',
#  'kava king products inc',
#  "schmidt's naturals",
#  'здоровье и безопасность',
#  'natural balance',
#  'queen helene',
#  'чай с ромашкой',
#  'ecotools',
#  'cobra labs',
#  'bausch & lomb',
#  'three lollies',
#  'шлемы',
#  'rsp nutrition',
#  'nutrex hawaii',
#  'estroven',
#  'arm & hammer',
#  'humann',
#  'bio-oil',
#  'willard',
#  'kericure',
#  'b-fresh inc.',
#  'sahale snacks',
#  'honey gardens',
#  'baby banana',
#  'mild by nature',
#  "earth's care",
#  'houston enzymes',
#  'teeccino',
#  'secret key',
#  'yeouth',
#  'apex',
#  'wisdom natural',
#  'planetary herbals',
#  'losraketos',
#  'kind bars',
#  'burton',
#  'kroeger herb co',
#  'категории',
#  'historical remedies',
#  'body gold',
#  '21st century',
#  "nature's plus",
#  'garden of life',
#  'nordic naturals',
#  'econugenics',
#  'homeolab usa',
#  'premier one',
#  'source naturals',
#  'травы',
#  'sparta nutrition',
#  '686',
#  'горнолыжное снаряжение',
#  'coral llc',
#  'aurora nutrascience',
#  'nescafé',
#  'quantum health',
#  'naturade',
#  'edward & sons',
#  'hyalogic llc',
#  'maxim hygiene products',
#  'organix south',
#  'savesta',
#  'frownies',
#  'glutino',
#  'витамин с',
#  'фонари',
#  "lucy's",
#  'горные',
#  'zollipops',
#  'st. dalfour',
#  'femarelle',
#  'спортивное питание',
#  "ella's kitchen",
#  'bern',
#  'visine',
#  'ricola',
#  'pure protein',
#  'dukan diet',
#  'today',
#  'fungi perfecti',
#  'каму-каму',
#  'american biosciences',
#  'sotru',
#  'smith & vandiver',
#  'the saem',
#  'vital earth minerals',
#  'газовое оборудование',
#  'shikai',
#  'rocco & roxie',
#  'ягоды годжи',
#  'кокосовый сахар',
#  'гарциния камбоджийская',
#  'разгрузки',
#  'hydroxycut',
#  'магнезия спортивная',
#  'dandies',
#  'семена чиа',
#  'coombs family farms',
#  'bucked up',
#  'orgain',
#  'bcaa',
#  'puppy cake',
#  'bluebonnet nutrition',
#  'eating evolved',
#  'mrs. dash',
#  'спальные мешки',
#  'пищеварение',
#  'auromere',
#  "garden of eatin'",
#  'surf-sweets',
#  'howl',
#  'redcon1',
#  'витамин е',
#  'alter eco',
#  'самокаты',
#  'мака',
#  'better life',
#  'made in nature',
#  'батончики',
#  'herbion',
#  'arrowhead mills',
#  'dream water',
#  'магний',
#  'i heart keenwah',
#  'home health',
#  'aleva naturals',
#  'kaged muscle',
#  'fungiology',
#  'ddrops',
#  'витамины и минералы',
#  'seasnax',
#  'wedderspoon',
#  'designer protein',
#  "nature's path",
#  'health direct',
#  'back to nature',
#  'food should taste good',
#  "barbara's bakery",
#  'петли',
#  'ark naturals',
#  'purely elizabeth',
#  'muscletech',
#  'primaforce',
#  'мелатонин',
#  'стимуляторы',
#  'kevala',
#  'relacore',
#  'country archer jerky',
#  'stridex',
#  'seagate',
#  'mt. capra',
#  'miracle noodle',
#  'активное долголетие',
#  'veglife',
#  'prolab',
#  'symbiotics',
#  'thinkthin',
#  'real aloe inc.',
#  'great lakes gelatin co.',
#  'everyday coconut',
#  'nutra biogenesis',
#  'alba botanica',
#  'dr. mercola',
#  'four sigmatic',
#  'go raw',
#  'herb pharm',
#  'funfresh foods',
#  'natural dynamix (ndx)',
#  'cool zone',
#  'зажимы',
#  'liverite',
#  'country life',
#  'ooh snap!',
#  'quest nutrition',
#  'шоссейный велосипед',
#  'giovanni',
#  'onnit',
#  'honees',
#  'reserveage nutrition',
#  'heimish',
#  'балаклавы и бафы',
#  'женские мультивитамины',
#  'twinlab',
#  'advanced clinicals',
#  'vital essentials',
#  'бульоны и мясные отвары',
#  'riley’s organics',
#  'веревки и стропы',
#  'bmx',
#  'nite ize. steelie',
#  'bodylogix',
#  'viking',
#  'мультивитамины',
#  'mizon',
#  'head',
#  'flower essence services',
#  'кешью',
#  'специальные препараты',
#  'beauty without cruelty',
#  ...}

# %%
end_slots = set()
for slot in slots:
    end_slots.update(slot.replace('"','').split(', '))

# %%
end_slots = [slot.strip()  for slot in end_slots if len(slot.strip()) > 0]

# %%
save_slots = pd.Series(list(end_slots))

# %%
save_slots.to_csv('./sport/slots.csv', index=False)

# %%
len(slots)
# Out:
# 1146
