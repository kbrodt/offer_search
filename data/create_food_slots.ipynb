# %%
import pandas as pd

# %%
data = pd.read_excel('./food/auchan/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Детям и мамам~Питание~Пюре~Пюре Semper Овощное...
# 1  Детям и мамам~Питание~Сухие молочные смеси~Мол...
# 2  Детям и мамам~Питание~Пюре~Пюре ФрутоНяня из г...
# 3  Детям и мамам~Питание~Пюре~Пюре Бабушкино луко...
# 4  Детям и мамам~Питание~Пюре~Пюре детское Semper...
#
#                                             Описание Цена
# 0  Детям с 12 месяцев. Пюре Semper Овощное рагу с...  109
# 1  Детям с рождения Молочная смесь Friso Фрисолак...  525
# 2  Детям с 4 месяцев. Пюре ФрутоНяня из груш гипо...   24
# 3  Кукуруза регулирует пищеварительные процессы и...   37
# 4  Детям с 10 месяцев. Пюре Semper Средиземноморс...  145

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4781 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null object
# dtypes: object(3)
# memory usage: 112.1+ KB

# %%
data = data.dropna(subset=['Цена'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null object
# dtypes: object(3)
# memory usage: 149.4+ KB

# %%
def to_num_auchan(text):
    return int(''.join(text.replace(',','').split()))

# %%
data['Цена'] = data['Цена'].apply(to_num_auchan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 149.4+ KB

# %%
data.to_excel('./food/auchan/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./food/auchan/data_cleaned.xls')
data.head()
# Out:
#                                             Название  \
# 0  Детям и мамам~Питание~Пюре~Пюре Semper Овощное...
# 1  Детям и мамам~Питание~Сухие молочные смеси~Мол...
# 2  Детям и мамам~Питание~Пюре~Пюре ФрутоНяня из г...
# 3  Детям и мамам~Питание~Пюре~Пюре Бабушкино луко...
# 4  Детям и мамам~Питание~Пюре~Пюре детское Semper...
#
#                                             Описание  Цена
# 0  Детям с 12 месяцев. Пюре Semper Овощное рагу с...   109
# 1  Детям с рождения Молочная смесь Friso Фрисолак...   525
# 2  Детям с 4 месяцев. Пюре ФрутоНяня из груш гипо...    24
# 3  Кукуруза регулирует пищеварительные процессы и...    37
# 4  Детям с 10 месяцев. Пюре Semper Средиземноморс...   145

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4780 entries, 0 to 4779
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 112.1+ KB

# %%
slots = set()
def process(text, ind=0):
    slots.update(text.strip().lower().split('~')[:3])
    return text

data['Название'].apply(process)
slots
# Out:
# {'аджика «дядя ваня», по-аджарски, 460г',
#  'аджика «пиканта», домашнему, 520г',
#  'азиатская кухня',
#  'ассорти «веселая грядка», с патиссонами, 950г',
#  'ассорти соленое тм «экопродукт», 350 г',
#  'бакалея',
#  'батончик gerber «doremi» злаковый черника-черная смородина с 12 мес 25 гр',
#  'батончик gerber «doremi» злаковый яблоко-виноград с 12 мес 25 гр',
#  'батончик gerber «doremi» фруктовый яблоко-банан с 12 мес 25 гр',
#  'био булгур auchan, 500г',
#  'био крупа ячменная перловая «аривера», 900 г',
#  'био макаронные изделия спиральки с крапивой alce nero, 500 г',
#  'био макароны из твердых сортов пшеницы «ригатони» alce nero, 500 г',
#  'био макароны из твердых сортов пшеницы «спагетони» alce nero, 500 г',
#  'био макароны из твердых сортов пшеницы «фузиллони» alce nero, 500 г',
#  'био макароны ракушки auchan, 500г',
#  'био макароны спиральки auchan, 500г',
#  'био масло кедрового ореха «алтайга», 250мл',
#  'био мякоть томатов alce nero, 500 г',
#  'био мякоть томатов auchan, 400г',
#  'био мякоть томатов и базилика auchan, 400г',
#  'био напиток из овса auchan, 1л',
#  'био напиток соевый с кальцием auchan, 1л',
#  'био напиток соевый с шоколадом auchan, 1л',
#  'био пшеница отборная для проращивания «аривера», 410 г',
#  'био семена льна масличного «аривера» 210 г',
#  'био сок витаминный eos bio, 700 мл',
#  'био сок грушевый eos bio, 700 мл',
#  'био сок морковный auchan, 1л',
#  'био сок садовые фрукты auchan, 1л',
#  'био сок свекольный eos bio, 700 мл',
#  'био сок томатный bioit 0.2л',
#  'био сок томатный eos bio, 700 мл',
#  'био сок яблочно-морковный eos bio, 700 мл',
#  'био соус томатный аррабиат auchan, 200г',
#  'био соус томатный с белыми грибами auchan, 200г',
#  'био соус томатный с оливками auchan, 200г',
#  'био специя auchan, 4 перца, 35 г',
#  'био специя auchan, карри, 42 г',
#  'био специя auchan, кориандр, молотый, 35 г',
#  'био специя auchan, орегано, 15 г',
#  'био специя auchan, чабрец, 18 г',
#  'био специя auchan, черный перец, горошек, 25 г',
#  'био специя карри santa maria, 20 г',
#  'био специя корица молотая santa maria, 17 г',
#  'био специя орегано (душица) santa maria, 4 г',
#  'био специя паприка молотая santa maria,17 г',
#  'био специя перец с лимонным ароматом santa maria, 17 г',
#  'био специя перец черный молотый santa maria, 17 г',
#  'био специя розмарин santa maria, 10 г',
#  'био специя тимьян santa maria,6 г',
#  'био специя черный перец молотый auchan, 40г',
#  'био товары',
#  'био хлебцы из цельнозернового риса с полбой, амарантом и киноа alce nero, 100 г',
#  'био хлебцы кукурузные с королевской пшеницей senatore cappelli, alce nero, 100 г',
#  'био шоколад auchan, молочный, с кокосом, 100 г',
#  'блины «haas», 250г',
#  'быстрое приготовление',
#  'вермишель bonsai, фунчоза, под тайским соусом, острая, 120г',
#  'вода «каждый день», для детского питания, негазированая, 5л',
#  'вода и напитки',
#  'восточные сладости',
#  'гармония prosto, фитнеса, 500г',
#  'глазурь dr. oetker со вкусом лимона, 100 г',
#  'горошек«спело-зрело», зелёный, 400г',
#  'горчица kamis, французкая, 185г',
#  'горчица «махеевъ», готовая, зернистая, туба, 100г',
#  'готовые блюда',
#  'готовые завтраки «любятово», медовые шарики и звездочки, 420г',
#  'готовый завтрак cini minis, c корицей, 250г',
#  'грецкие орехи «семушка», 110г',
#  'гречневый продел «чудо зернышко»  быстроразваривающийся (пропаренный), 700г',
#  'грибные консервы',
#  'десертные пасты и сиропы',
#  'детская одежда',
#  'детское печенье бегемотик бонди с железом 180 г, возраст 5м+',
#  'детское печенье бегемотик бонди с йодом 180 г, возраст 5м+',
#  'детское печенье бегемотик бонди с кальцием 180 г',
#  'детям и мамам',
#  'джем «махеевъ», лимонный, дой-пак с дозатором, 300г',
#  'джем, варенье',
#  'диетическое питание',
#  'для мужчин',
#  'дрожжи «haas», сухие пекарские, 7г',
#  'жевательная резинка chupa chups big babol, банан, 21г (24 шт.)',
#  'жевательная резинка dirol colors xxl асссорти мятных вкусов, без сахара, 19г',
#  'жевательная резинка dirol colors xxl асссорти фруктовых вкусов, без сахара, 19г',
#  'жевательная резинка dirol x-fresh арбузный лед, без сахара, 16г',
#  'жевательная резинка dirol x-fresh мятная свежесть, без сахара, 16г',
#  'жевательная резинка dirol x-fresh мятный лед, без сахара, 16г',
#  'жевательная резинка dirol без сахара со вкусом мяты и тархуна, 13.6г',
#  'жевательная резинка dirol без сахара, клубника черешня, 13.6г',
#  'жевательная резинка dirol, арбузно-дынный коктейль, 13.6г',
#  'жевательная резинка dirol, землянично-банановый смузи, 19г',
#  'жевательная резинка dirol, клубника & черешня, 13г',
#  'жевательная резинка dirol, лайм и маракуйя, 13.6г',
#  'жевательная резинка dirol, манго, 13.6г',
#  'жевательная резинка dirol, ментол, 13,6г',
#  'жевательная резинка dirol, морозная мята, 27г',
#  'жевательная резинка dirol, мята, 13.6г',
#  'жевательная резинка dirol, сладкая мята, 13,6 г',
#  'жевательная резинка mentos pure fresh, мята, 100г',
#  'жевательная резинка mentos pure fresh, тутти фрутти, 54г',
#  'жевательная резинка orbit, сладкая мята, банка, 54,4г',
#  'жевательная резинка orbit, сладкая мята, футбольный мяч, 34г',
#  'завтраки амарантовые di&di, ешь здорово, шоколадные, 220г',
#  'закуска «дядя ваня», по-тоскански, из белой фасоли, моркови и сладкого болгарского перца, 460г',
#  'заправка sen soy, для баклажанов и гибов, 80г',
#  'зеленый кофе «о самом главном» с имбирем, 100г',
#  'зерно для проращивания «сыроед», расторопша, 100г',
#  'зерно для проращивания «сыроед», чиа, 100г',
#  'зефир, пастила, мармелад',
#  'злаковый батончик fitness, шоколад, 23.5г',
#  'икра «пиканта», из кабачков, 520г',
#  'икра «ретро» из кабачков, 510г',
#  'икра «щедрые дары», кабачковая, 450г',
#  'ингредиенты для выпечки',
#  'кабачки «пиканта», печёные в томатном соусе, 520г',
#  'кабачки маринованные с зеленью и чесноком тм «меленъ», 520 г',
#  'капучино «худеем за неделю», жиросжигающий комплекс бейлис, 9 г',
#  'капучино «худеем за неделю», жиросжигающий комплекс, 14 г',
#  'каша «малютка» пшеничная, яблоко-персик, безмолочная, с 6 мес., 200 гр',
#  'каша «малютка», гречневая, с лесными ягодами, молочная, с 6 мес., 200 гр',
#  'каша «малютка», мультизлаковая, банан-малина, молочная, с 6 мес., 200 гр',
#  'каша «малютка», овсяная, безмолочная, с 6 мес., 200 гр',
#  'каша «малютка», рисовая, безмолочная, с 4 мес., 200 гр',
#  'каша «малютка», рисовая, персик-абрикос, молочная, с 6 мес., 200 гр',
#  'каша «умница», 5 злаков, молочная, 200 гр',
#  'каша «умница», 5 злаков, с липой, молочная, 200 гр',
#  'каша «умница», овсянка, молочная, 200 гр',
#  'каша льняная dr.dias, со вкусом абрикоса, 18г',
#  'каши',
#  'кейс «худеем за неделю», очищение организма, 771 г',
#  'кейс «худеем за неделю», снижение веса и холестерина, 602 г',
#  'кекс «фитодар» маковый, готовая мучная смесь, 300 г',
#  'кетчуп «махеевъ», татарский, дой-пак с дозатором, 500г',
#  'кетчуп, томатная паста',
#  'кисель «леовит», витаминный для глаз с лютеином, 18 г',
#  'кисель «леовит», желудочный нейтральный, 100 г',
#  'кисель «леовит», желудочный нейтральный, 20 г',
#  'кисель «леовит», сонный, 100 г',
#  'кисель «леовит», успокаивающий, 100 г',
#  'кисель «худеем за неделю», очищающий, 100 г',
#  'кисель овсяный «стокрос» на натуральном молоке, на фруктозе витаминизированный, 200г',
#  'клетчатка dr.dias, изящная, 170г',
#  'клетчатка dr.dias, льняная с черникой, 170г',
#  'клетчатка dr.dias, соколиный глаз, 170г',
#  'клетчатка «верное средство»,  с семенами чиа, 170г',
#  'клечатка «верное средство», для лёгкости, три злака, 170г',
#  'клечатка питьевая lafitore, пшеничная, здоровая печень, 110г',
#  'клечатка питьевая lafitore, пшеничная, очищающая, 110г',
#  'клечатка питьевая lafitore, пшеничная, стоп аппетит, 110г',
#  'клечатка питьевая lafitore, пшеничная, тонкая телия, 110г',
#  'кокосовое масло nosso coco bio, 200мл',
#  'компот «худеем за неделю», похудин, 18 г',
#  'кондитерские посыпки «русский аппетит», 50 г',
#  'кондитерские украшения\xa0«домашняя кухня» вафельные фигурные, 10 г',
#  'консервация',
#  'конфеты',
#  'конфеты «диадар» молочные на фруктозе, 200г',
#  'конфеты «петродиет» мягкий грильяж, на фруктозе, 200г',
#  'кофе jardin растворимый сублимированный колумбия меделлин 95г. ст/б',
#  'кофе в зернах ambassador platinum, пакет, 1 кг',
#  'кофе для похудения «худеем за неделю», жиросжигающий комплекс амаретто, 25 г',
#  'кофе для похудения «худеем за неделю», жиросжигающий комплекс, 30 г',
#  'кофе, какао',
#  'красота и здоровье',
#  'крем-суп hipp овощной с индейкой с 6 мес 190 гр',
#  'крем-суп hipp овощной с кабачком и индейкой с 6 мес 190 гр',
#  'крем-суп hipp овощной с куриной грудкой с 6 мес 190 гр',
#  'крем-суп hipp овощной с нежной телятиной с 6 мес 190 гр',
#  'кружево кондитерское «домашняя кухня» коричневое, 54мм х 3шт, 12г',
#  'крупа makfa, пшеничная, полтавская, в пакетиках для варки, 400г',
#  'крупа makfa, ячневая, в пакетиках для варки, 400г',
#  'крупа «гарнец», полбяная, полбянка, 400г',
#  'крупа «пассим», гречневая, алтайская, 1,5кг',
#  'крупа «чудо зернышко» пшеничная полтавская №2, 700г',
#  'крупа для проращивания «сыроед», гречневая ядрица, 300г',
#  'крупа для проращивания «сыроед», овёс голозёрный, 300г',
#  'крупы, бобы',
#  'кукуруза bonduelle, молодая, 170г',
#  'кукуруза bonduelle, молодая, 340г',
#  'кукуруза «спело-зрело», сахарная, в зернах, в вакуумной упаковке, 425мл',
#  'кэроб vita brown натуральный растворимый, 100г',
#  'макаронные изделия bioitalia, гнёзда ,500гр',
#  'макаронные изделия bioitalia, перья крупные,500г',
#  'макаронные изделия bioitalia, пёрышки ,500г',
#  'макаронные изделия bioitalia, спирали, c томатом и шпинатом ,500г',
#  'макаронные изделия pastamania, рожки, 430г',
#  'макаронные изделия pastamania, серпантин, 430г',
#  'макаронные изделия «аго-альянс», лапша, 500г',
#  'макаронные изделия «аго-альянс», перья, 450г',
#  'макаронные изделия «аго-альянс», рожки, 450г',
#  'макароны',
#  'макароны barilla, maccheroni, 500 г',
#  'макароны molisana, пружинки, 500г',
#  'макароны каннеллони barilla 250г',
#  'масла растительные',
#  'масла, соусы, заправки',
#  'масло оливковое  bioitalia, нерафинированное с базиликом ,250мл',
#  'масло оливковое bioitalia ,нерафинированное  с апельсином ,250мл',
#  'мастика\xa0«домашняя кухня» сахарная ванильная, помадка, 140 г',
#  'маца sante цельнозерновая, 180г',
#  'мед',
#  'мука и смеси для выпечки',
#  'мякоть «пиканта», протёртая, 500г',
#  'мясные консервы',
#  'натуральная приправа kotanyi, для глинтвейна, 10 пакетов',
#  'натуральная приправа kotanyi, для пунша, 10 пакетов',
#  'новый год',
#  'овощная консервация proshyanfood аппетит, 480г',
#  'овощные консервы',
#  'овощьное ассорти «дядя ваня», огурцы и томаты со свежими специями и ароматным маринадом, 680г',
#  'овсяные отруби nordic 700г.',
#  'овсяные хлопья «клинские экстра», 1кг',
#  'огурцы «спело-зрело», маринованные, целые, 680г',
#  'оладушки «тестовъ», 400г',
#  'оладушки «фитодар», деревенские, 250г',
#  'оливки oliverio, гордаль с косточками, 345г',
#  'орехи, сухофрукты, семечки, грибы',
#  'отруби dr.dias, кукурузная диета, очищающие, 180г',
#  'отруби льняные dr.dias, средний помол, 100г',
#  'отруби органические helsinki mills, овсяные, 500 г',
#  'паста yelli , с белыми грибами, 250г',
#  'перец monolith, печеный, 560г',
#  'перец «царская приправа», душистый, горошек, 50г',
#  'перец белый «королевская коллекция», 25г',
#  'перец бурбонский «королевская коллекция», 20г',
#  'перец чили «хабанеро», 10г',
#  'печень и икра «морская радуга», митная, натуральная, 230г',
#  'печенье gerber «doremi» с витаминами и кальцием с 12 мес 180 гр',
#  'печенье heinz с 5 мес 60 гр',
#  'печенье hipp «первое детское» с 6 мес 150 гр',
#  'печенье детское heinz с 5 мес 160 гр',
#  'печенье детское малышок с железом с 5 мес 200 гр',
#  'печенье детское малышок с кальцием с 5 мес 200 гр',
#  'печенье малышок детское классическое с 5 мес 200 гр',
#  'печенье, вафли, пряники',
#  'питание',
#  'посыпка dr. oetker цветная, шарики, 10 г',
#  'початки кукурузы stollenwerk мелкие 370мл',
#  'приправа kotanyi  для морской рыбы и морепродуктов, 30г',
#  'приправа old el paso, для фахита, барбекю, 24х35г',
#  'приправа базилик «санта-мария», органик, 4г',
#  'прованские травы auchan, 85г',
#  'проверочный раздел all',
#  'продукты',
#  'пропитка для торта «рецепты вкуса» ромовая, 100 г',
#  'пюре',
#  'пюре gerber груша с 4 мес 80 гр',
#  'пюре gerber яблоко с 4 мес 130 гр',
#  'пюре semper груша с 4 мес 125 гр',
#  'пюре «каждый день» картофель с овощами, 125 г. с 7 мес.',
#  'пюре «каждый день» овощи с кроликом, 125 г. с 6 мес.',
#  'пюре тёма говядина с брокколи, морковью и рисом с 6 мес 100 гр',
#  'пюре тёма говядина с кабачками и рисом с 6 мес 100 гр',
#  'пюре тёма говядина с рисом с 8 мес 100 гр',
#  'разрыхлитель теста preston, 12г',
#  'разрыхлитель теста «трапеза», 15г',
#  'растительный аналог желатина kotanyi, агар-агар, 10 г',
#  'рататуй «пиканта», овощной, 520г',
#  'ризотто «пиканта», с овощами и грибами, 550г',
#  'рис «националь», девзира, 800г',
#  'рис «пассим», круглозерный, приморский, 800г',
#  'рис «пассим», пропаренный, тайский, 1,5кг',
#  'рожь для проращивания lafitore, 250г',
#  'рыбные консервы',
#  'сайра monolith, тихоокеанская, натуральная, 250г',
#  'сайра «вкусные консервы», копченые, в масле, 175г',
#  'салат пуста «грин рэй», 720мл',
#  'сахар и сахарозаменители',
#  'сахар, чай, кофе',
#  'свекла bonduelle, на пару, 425мл',
#  'свекла маринованная тм «меленъ», 530 г',
#  'семена чиа «о самом главном», 20 пакетиков, 100г',
#  'сладая mini calorie смесь фруктоза с сукралозой, 250г',
#  'сладости',
#  'смесь «гарнец» основа для пиццы 600г',
#  'смузи «сибирская клетчатка», мята, клубника, чёрная смородина, яблоко и клечатка, 7х12г',
#  'смузи «сибирская клетчатка», яблоко, корица и клечатка, 7х12г',
#  'соевое мясо bona vita со вкусом куриного стейка, 80г',
#  'сок bioitalia, апельсиновый, 200мл',
#  'сок bioitalia, виноградный, 200мл',
#  'сок bioitalia, морковный, 200мл',
#  'сок bioitalia, томат/имбирь/перец, 200мл',
#  'сок bioitalia, яблоко/бергамот, 200мл',
#  'сок bioitalia, яблоко/имбирь/мята, 200мл',
#  'сок bioitalia, яблочный, 200мл',
#  'сок «био» life premium, яблочно-персиковый с добавлением морковного, 1л',
#  'сок агуша яблоко с 4 мес 200 мл',
#  'соки, нектары',
#  'соль, приправы, специи',
#  'сорбит гранулированный dr.dias, 450 г',
#  'соус bioitalia ,томатный по-деревенски ,180г',
#  'соус bioitalia ,томатный с базиликом, 350г',
#  'соус bioitalia, песто, 180 г',
#  'соус blue dragon, кисло-сладкий, 120г',
#  'соус blue dragon, теряки, 120г',
#  'соус good life сливовый, 200мл',
#  'соус heinz чесночный 230г',
#  'соус old el paso, сальса, оригинальный, с кусочками томатов, 12х226г',
#  'соус remia, black jack smokey, bbq, классический, 450мл',
#  'соус remia, smokin jones, bbq, с чесноком, 450мл',
#  'соус remia, sweet dalton, bbq, медовый, 450мл',
#  'соус remia, wild bill, bbq, американский, сливочно-чесночный, 450мл',
#  'соус sen soy, черный перец, 120г',
#  'соус uni-eagle, sriracha, острый, 230г',
#  'соус болгарский «стебель бамбука», 280г',
#  'соус карри «стебель бамбука», 280г',
#  'соус острый перцевый santa maria, 85мл',
#  'соус фруктовый «кинто», ткемали классический (красный), 300г',
#  'соус чили mivimex перцовый, 200 г',
#  'соусы, майонез',
#  'суп gallina blanca, заварной, гороховый по-голландски, с сухариками, 22г',
#  'суп gallina blanca, заварной, сырный по-швейцарски, с сухариками, 23г',
#  'суп гороховый «лидкон» со вкусом копчёностей, 200г',
#  'сухари, сушки, крекеры',
#  'сухие завтраки, каши',
#  'сухие молочные смеси',
#  'сухие смеси и завтраки',
#  'томатный соус rundale,  с жареным чесноком, 400г',
#  'томатный соус rundale, 7 трав, 420г',
#  'томаты «маринадовъ», маринованные, черри, 680г',
#  'томаты «спело-зрело», маринованные, 720мл',
#  'томаты «щедрые дары», в томатном соку, 720г',
#  'торты, пирожные, выпечка',
#  'травяной сбор для похудения dr.dias, коррекция фигуры № 24, 30 шт по 1,5г',
#  'уксус bonsai, рисовый, для суши, 150мл',
#  'фантазия с приправами marabotto, 500г',
#  'фасоль «маринадовъ», из печи, 530г',
#  'фасоль «маринадовъ», с овощами, летняя, 530г',
#  'фруктовые консервы',
#  'фруктоза mini calorie кристалическая в пакетах, 250г',
#  'фундук «семушка», жареный, 250г',
#  'хлебцы dr. korner, рисовые, с молочным шоколадом, 67г',
#  'хлебцы dr. korner, рисовые, с темным шоколадом, 67г',
#  'хлебцы finn crisp multigrain (многозерновые) круглые, 250 г',
#  'хлебцы passioni pane carasau, ломтики, 250г',
#  'хлебцы riso scotti basmati, из красного и черного риса, без глютена, органический продукт, 120г',
#  'хлебцы riso scotti, из риса со злаками и киноа без глютена, органический продукт, 130г',
#  'хлебцы riso scotti, рисовые с турецким горохом и злаками, без глютена, органический продукт, 130г',
#  'хлебцы «delba», с семенами чиа и овсом, 360г',
#  'хлопья fitness пакет, цельная пшеница, 250г',
#  'хлопья fitness, фрукты, ягоды, орехи, 300г',
#  'хлопья nordic  4-х видов зерновых  600г.',
#  'хлопья nordic овсяно-ржаные с отрубями и семенами льна 600г',
#  'хлопья овсяные nordic с овсяными отрубями 600г.',
#  'хлопья пшенные nordic 350г.',
#  'хрен, горчица, уксус, маринад',
#  'хрустящее печенье «вастэко», из полбы без дрожей, 170г',
#  'хрустящее печенье «вастэко», из полбы с кунжутом, 170г',
#  'хрустящие хлебцы «кэнапс» льняные с имбирем и стевией, 70г',
#  'хумус kasih, 70г',
#  'цикорий растворимый «цикорень», классический, 75г',
#  'цикорий растворимый «цикорень», с экстрактом боярышника, 75г',
#  'цикорий растворимый «цикорень», с экстрактом облепихи, 75г',
#  'цикорий сублимированный uliss chicory, 85г',
#  'цикорий, солод и травяные сборы',
#  'чай',
#  'чай «худеем за неделю», \xa0жиросжигающий комплекс, 50 г',
#  'чай «худеем за неделю», очищающий комплекс, 50 г',
#  'чай ассорти curtis dessert tea collection, 30 сашет',
#  'чай ассорти curtis «fantasy garden»  40 пирамидок',
#  'чай для кормящик матерей bebivita, 200 гр',
#  'чай, кофе, сахар',
#  'чеснок маринованный со свеклой тм «экопродукт», 260 г',
#  'чесночная паста «русские закуски», 200г',
#  "чипсы lay's, stax, ребрышки барбекю,картофельные, 110г",
#  "чипсы lay's, рифленые, со вкусом сыра и лука, 80г",
#  'чипсы pringles, картофельные, со вкусом зелёного лука, 165г',
#  'чипсы, снэки, сухарики',
#  'шампиньоны и белые грибы bonduelle, в соусе персилад, 425мл',
#  'шоколад',
#  'яичная лапша passion, с черный трюфелем, 250 г'}

# %%
data = pd.read_excel('./food/foodband/data.xls')
data.head()
# Out:
#                    Название  \
# 0              пицца~Мясная
# 1  пицца~Аппетитная Курочка
# 2           пицца~Маргарита
# 3         пицца~Чикен Алоха
# 4           пицца~Пепперони
#
#                                             Описание  Цена
# 0  Пицца соус, сыр Моцарелла, томат, куриное филе...   695
# 1  Белый соус, куриное филе, лук зелёный, сыр Моц...   575
# 2        Пицца соус, сыр Моцарелла, томат и Пармезан   475
# 3  Пицца соус, сыр моцарелла, куриное филе, анана...   545
# 4               Пицца соус, пепперони, сыр Моцарелла   595

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
# Название    110 non-null object
# Описание    110 non-null object
# Цена        110 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %%
data.to_excel('./food/foodband/data_cleaned.xls', index=False)
data = pd.read_excel('./food/foodband/data_cleaned.xls')
data.head()
# Out:
#                    Название  \
# 0              пицца~Мясная
# 1  пицца~Аппетитная Курочка
# 2           пицца~Маргарита
# 3         пицца~Чикен Алоха
# 4           пицца~Пепперони
#
#                                             Описание  Цена
# 0  Пицца соус, сыр Моцарелла, томат, куриное филе...   695
# 1  Белый соус, куриное филе, лук зелёный, сыр Моц...   575
# 2        Пицца соус, сыр Моцарелла, томат и Пармезан   475
# 3  Пицца соус, сыр моцарелла, куриное филе, анана...   545
# 4               Пицца соус, пепперони, сыр Моцарелла   595

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
# Название    110 non-null object
# Описание    110 non-null object
# Цена        110 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %%
slots_food = set()
def process_food(text, ind=0):
    slots_food.update(text.strip().lower().split('~')[:2])
    return text

data['Название'].apply(process_food)
slots_food
# Out:
# {'bon aqua 0.5л',
#  'burn (бёрн)',
#  'coca cola zero',
#  'coca-cola',
#  'fanta',
#  'fitness',
#  'rich апельсин',
#  'rich вишня',
#  'rich яблоко',
#  'sprite',
#  'аль тоне тунец',
#  'американская классика',
#  'аппетитная курочка',
#  'ассорти острая',
#  'баварская',
#  'вегетарианская (new)',
#  'венецианская',
#  'верона',
#  'ветчирелла',
#  'вок',
#  'гренки чесночные',
#  'греческий салат',
#  'грибная',
#  'деревенская',
#  'десерт',
#  'домашний лимонад',
#  'дракон',
#  'жульен',
#  'закуска',
#  'картофель по-деревенски',
#  'картофель фри',
#  'классика',
#  'королева моря',
#  'куриные крылья барбекю',
#  'куриные крылья баффало',
#  'маргарита',
#  'маринара италиано',
#  'миланская',
#  'мисо суп классический',
#  'мисо суп с лососем',
#  'морс облепиховый',
#  'морс ягодный',
#  'мужская',
#  'мясная',
#  'напиток',
#  'охотничья',
#  'пепперони',
#  'пицца',
#  'пицца bbq',
#  'салат',
#  'салат цезарь с креветками',
#  'салат цезарь с курицей',
#  'сет',
#  'сет для гурманов',
#  'сет для двоих',
#  'сет на выходные',
#  'сет на одного',
#  'сет премиум',
#  'сет с горячими роллами',
#  'сет с лососем',
#  'сет с угрем',
#  'сет сакура',
#  'сет № 2',
#  'сет № 3',
#  'суп',
#  'суприм',
#  'суши',
#  'суши капеллана масаго',
#  'суши лосось',
#  'суши спайс креветка',
#  'суши спайс лосось',
#  'суши спайс угорь',
#  'суши угорь',
#  'сырные ломтики',
#  'такусан сет',
#  'том ям',
#  'торт "блэк джин (шоколадный)"',
#  'торт "тирамису"',
#  'удон с говядиной ньюпай',
#  'удон с курицей в чесночном соусе',
#  'удон с курицей по-пекински',
#  'удон со свининой в чесночном соусе',
#  'удон со свининой ньюпай',
#  'филадельфия',
#  'фруктовая',
#  'харусаме с говядиной ньюпай',
#  'харусаме с креветками том ям',
#  'харусаме с курицей в чесночном соусе',
#  'харусаме с курицей по-пекински',
#  'харусаме со свининой в чесночном соусе',
#  'харусаме со свининой ньюпай',
#  'холодный чай каркаде',
#  'цезарь',
#  'четыре сыра',
#  'чизкейк нью-йорк (карамельный)',
#  'чизкейк нью-йорк (классика)',
#  'чизкейк нью-йорк (клубничный)',
#  'чикен алоха',
#  'яки-соба ньюпай'}

# %%
#iHerb

# %%
slots = pd.Series(list(end_slots))

# %%
slots.to_csv('./food/slots.csv', index=False)

# %%
len(slots)
# Out:
# 190
