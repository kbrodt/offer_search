# %%
import pandas as pd

# %%
data = pd.read_excel('./food/auchan/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Детям и мамам~Питание~Пюре~Пюре Semper Овощное...
# 1  Детям и мамам~Питание~Сухие молочные смеси~Мол...
# 2  Детям и мамам~Питание~Пюре~Пюре ФрутоНяня из г...
# 3  Детям и мамам~Питание~Пюре~Пюре Бабушкино луко...
# 4  Детям и мамам~Питание~Пюре~Пюре детское Semper...
#
#                                             Описание Цена
# 0  Детям с 12 месяцев. Пюре Semper Овощное рагу с...  109
# 1  Детям с рождения Молочная смесь Friso Фрисолак...  525
# 2  Детям с 4 месяцев. Пюре ФрутоНяня из груш гипо...   24
# 3  Кукуруза регулирует пищеварительные процессы и...   37
# 4  Детям с 10 месяцев. Пюре Semper Средиземноморс...  145

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4781 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null object
# dtypes: object(3)
# memory usage: 112.1+ KB

# %%
data = data.dropna(subset=['Цена'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null object
# dtypes: object(3)
# memory usage: 149.4+ KB

# %%
def to_num_auchan(text):
    return int(''.join(text.replace(',','').split()))

# %%
data['Цена'] = data['Цена'].apply(to_num_auchan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4780
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 149.4+ KB

# %%
data.to_excel('./food/auchan/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./food/auchan/data_cleaned.xls')
data.head()
# Out:
#                                             Название  \
# 0  Детям и мамам~Питание~Пюре~Пюре Semper Овощное...
# 1  Детям и мамам~Питание~Сухие молочные смеси~Мол...
# 2  Детям и мамам~Питание~Пюре~Пюре ФрутоНяня из г...
# 3  Детям и мамам~Питание~Пюре~Пюре Бабушкино луко...
# 4  Детям и мамам~Питание~Пюре~Пюре детское Semper...
#
#                                             Описание  Цена
# 0  Детям с 12 месяцев. Пюре Semper Овощное рагу с...   109
# 1  Детям с рождения Молочная смесь Friso Фрисолак...   525
# 2  Детям с 4 месяцев. Пюре ФрутоНяня из груш гипо...    24
# 3  Кукуруза регулирует пищеварительные процессы и...    37
# 4  Детям с 10 месяцев. Пюре Semper Средиземноморс...   145

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4780 entries, 0 to 4779
# Data columns (total 3 columns):
# Название    4780 non-null object
# Описание    4643 non-null object
# Цена        4780 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 112.1+ KB

# %%
slots = set()
def process(text, ind=0):
    slots.update(text.strip().lower().split('~')[:3])
    return text

data['Название'].apply(process)
end_slots = set()
end_slots.update([slot.split(' ')[0] for slot in slots])
slots = end_slots

# %%
data = pd.read_excel('./food/foodband/data.xls')
data.head()
# Out:
#                    Название  \
# 0              пицца~Мясная
# 1  пицца~Аппетитная Курочка
# 2           пицца~Маргарита
# 3         пицца~Чикен Алоха
# 4           пицца~Пепперони
#
#                                             Описание  Цена
# 0  Пицца соус, сыр Моцарелла, томат, куриное филе...   695
# 1  Белый соус, куриное филе, лук зелёный, сыр Моц...   575
# 2        Пицца соус, сыр Моцарелла, томат и Пармезан   475
# 3  Пицца соус, сыр моцарелла, куриное филе, анана...   545
# 4               Пицца соус, пепперони, сыр Моцарелла   595

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
# Название    110 non-null object
# Описание    110 non-null object
# Цена        110 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %%
data.to_excel('./food/foodband/data_cleaned.xls', index=False)
data = pd.read_excel('./food/foodband/data_cleaned.xls')
data.head()
# Out:
#                    Название  \
# 0              пицца~Мясная
# 1  пицца~Аппетитная Курочка
# 2           пицца~Маргарита
# 3         пицца~Чикен Алоха
# 4           пицца~Пепперони
#
#                                             Описание  Цена
# 0  Пицца соус, сыр Моцарелла, томат, куриное филе...   695
# 1  Белый соус, куриное филе, лук зелёный, сыр Моц...   575
# 2        Пицца соус, сыр Моцарелла, томат и Пармезан   475
# 3  Пицца соус, сыр моцарелла, куриное филе, анана...   545
# 4               Пицца соус, пепперони, сыр Моцарелла   595

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
# Название    110 non-null object
# Описание    110 non-null object
# Цена        110 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %%
def process_food(text, ind=0):
    slots.update(text.strip().lower().split('~')[:2])
    return text

data['Название'].apply(process_food)
slots
# Out:
# {'bon aqua 0.5л',
#  'burn (бёрн)',
#  'coca cola zero',
#  'coca-cola',
#  'fanta',
#  'fitness',
#  'rich апельсин',
#  'rich вишня',
#  'rich яблоко',
#  'sprite',
#  'аджика',
#  'азиатская',
#  'аль тоне тунец',
#  'американская классика',
#  'аппетитная курочка',
#  'ассорти',
#  'ассорти острая',
#  'баварская',
#  'бакалея',
#  'батончик',
#  'био',
#  'блины',
#  'быстрое',
#  'вегетарианская (new)',
#  'венецианская',
#  'вермишель',
#  'верона',
#  'ветчирелла',
#  'вода',
#  'вок',
#  'восточные',
#  'гармония',
#  'глазурь',
#  'горошек«спело-зрело»,',
#  'горчица',
#  'готовые',
#  'готовый',
#  'гренки чесночные',
#  'грецкие',
#  'греческий салат',
#  'гречневый',
#  'грибная',
#  'грибные',
#  'деревенская',
#  'десерт',
#  'десертные',
#  'детская',
#  'детское',
#  'детям',
#  'джем',
#  'джем,',
#  'диетическое',
#  'для',
#  'домашний лимонад',
#  'дракон',
#  'дрожжи',
#  'жевательная',
#  'жульен',
#  'завтраки',
#  'закуска',
#  'заправка',
#  'зеленый',
#  'зерно',
#  'зефир,',
#  'злаковый',
#  'икра',
#  'ингредиенты',
#  'кабачки',
#  'капучино',
#  'картофель по-деревенски',
#  'картофель фри',
#  'каша',
#  'каши',
#  'кейс',
#  'кекс',
#  'кетчуп',
#  'кетчуп,',
#  'кисель',
#  'классика',
#  'клетчатка',
#  'клечатка',
#  'кокосовое',
#  'компот',
#  'кондитерские',
#  'консервация',
#  'конфеты',
#  'королева моря',
#  'кофе',
#  'кофе,',
#  'красота',
#  'крем-суп',
#  'кружево',
#  'крупа',
#  'крупы,',
#  'кукуруза',
#  'куриные крылья барбекю',
#  'куриные крылья баффало',
#  'кэроб',
#  'макаронные',
#  'макароны',
#  'маргарита',
#  'маринара италиано',
#  'масла',
#  'масла,',
#  'масло',
#  'мастика\xa0«домашняя',
#  'маца',
#  'мед',
#  'миланская',
#  'мисо суп классический',
#  'мисо суп с лососем',
#  'морс облепиховый',
#  'морс ягодный',
#  'мужская',
#  'мука',
#  'мякоть',
#  'мясная',
#  'мясные',
#  'напиток',
#  'натуральная',
#  'новый',
#  'овощная',
#  'овощные',
#  'овощьное',
#  'овсяные',
#  'огурцы',
#  'оладушки',
#  'оливки',
#  'орехи,',
#  'отруби',
#  'охотничья',
#  'паста',
#  'пепперони',
#  'перец',
#  'печень',
#  'печенье',
#  'печенье,',
#  'питание',
#  'пицца',
#  'пицца bbq',
#  'посыпка',
#  'початки',
#  'приправа',
#  'прованские',
#  'проверочный',
#  'продукты',
#  'пропитка',
#  'пюре',
#  'разрыхлитель',
#  'растительный',
#  'рататуй',
#  'ризотто',
#  'рис',
#  'рожь',
#  'рыбные',
#  'сайра',
#  'салат',
#  'салат цезарь с креветками',
#  'салат цезарь с курицей',
#  'сахар',
#  'сахар,',
#  'свекла',
#  'семена',
#  'сет',
#  'сет для гурманов',
#  'сет для двоих',
#  'сет на выходные',
#  'сет на одного',
#  'сет премиум',
#  'сет с горячими роллами',
#  'сет с лососем',
#  'сет с угрем',
#  'сет сакура',
#  'сет № 2',
#  'сет № 3',
#  'сладая',
#  'сладости',
#  'смесь',
#  'смузи',
#  'соевое',
#  'сок',
#  'соки,',
#  'соль,',
#  'сорбит',
#  'соус',
#  'соусы,',
#  'суп',
#  'суприм',
#  'сухари,',
#  'сухие',
#  'суши',
#  'суши капеллана масаго',
#  'суши лосось',
#  'суши спайс креветка',
#  'суши спайс лосось',
#  'суши спайс угорь',
#  'суши угорь',
#  'сырные ломтики',
#  'такусан сет',
#  'том ям',
#  'томатный',
#  'томаты',
#  'торт "блэк джин (шоколадный)"',
#  'торт "тирамису"',
#  'торты,',
#  'травяной',
#  'удон с говядиной ньюпай',
#  'удон с курицей в чесночном соусе',
#  'удон с курицей по-пекински',
#  'удон со свининой в чесночном соусе',
#  'удон со свининой ньюпай',
#  'уксус',
#  'фантазия',
#  'фасоль',
#  'филадельфия',
#  'фруктовая',
#  'фруктовые',
#  'фруктоза',
#  'фундук',
#  'харусаме с говядиной ньюпай',
#  'харусаме с креветками том ям',
#  'харусаме с курицей в чесночном соусе',
#  'харусаме с курицей по-пекински',
#  'харусаме со свининой в чесночном соусе',
#  'харусаме со свининой ньюпай',
#  'хлебцы',
#  'хлопья',
#  'холодный чай каркаде',
#  'хрен,',
#  'хрустящее',
#  'хрустящие',
#  'хумус',
#  'цезарь',
#  'цикорий',
#  'цикорий,',
#  'чай',
#  'чай,',
#  'чеснок',
#  'чесночная',
#  'четыре сыра',
#  'чизкейк нью-йорк (карамельный)',
#  'чизкейк нью-йорк (классика)',
#  'чизкейк нью-йорк (клубничный)',
#  'чикен алоха',
#  'чипсы',
#  'чипсы,',
#  'шампиньоны',
#  'шоколад',
#  'яичная',
#  'яки-соба ньюпай'}

# %%
#iHerb
data = pd.read_excel('./food/iHerb.com/data.xls')
data.head()
# Out:
#                                             Название  Описание     Цена
# 0  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽403.98
# 1  Бренды А-Я~ Now Foods~ ~ Категории~ Пищевые до...       NaN  ₽645.70
# 2  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽538.64
# 3  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN  ₽471.31
# 4  Бренды А-Я~ ChildLife~ ~ Категории~ Для малыше...       NaN  ₽406.68

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17161 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17157 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null object
# dtypes: float64(1), object(2)
# memory usage: 402.3+ KB

# %%
data = data.dropna(subset=['Цена'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17098 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null object
# dtypes: float64(1), object(2)
# memory usage: 534.3+ KB

# %%
def to_num_iherb(text):
    return int(float(''.join(text.replace('₽','').replace(',','').split())))

# %%
data['Цена'] = data['Цена'].apply(to_num_iherb)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17098 entries, 0 to 17160
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 534.3+ KB

# %%
data.to_excel('./food/iHerb.com/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./food/iHerb.com/data_cleaned.xls')
data.head()
# Out:
#                                             Название  Описание  Цена
# 0  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   403
# 1  Бренды А-Я~ Now Foods~ ~ Категории~ Пищевые до...       NaN   645
# 2  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   538
# 3  Бренды А-Я~ California Gold Nutrition, CGN~ ~ ...       NaN   471
# 4  Бренды А-Я~ ChildLife~ ~ Категории~ Для малыше...       NaN   406

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17098 entries, 0 to 17097
# Data columns (total 3 columns):
# Название    17098 non-null object
# Описание    0 non-null float64
# Цена        17098 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 400.8+ KB

# %%
def process_iherb(text, ind=0):
    slots.update(text.strip().lower().split('~')[1:4])
    return text

data['Название'].apply(process_iherb)
slots
# Out:
# {' manuka doctor',
#  ' mrm',
#  ' батончики',
#  ' avalon organics',
#  ' actipet',
#  ' хром',
#  'кисель',
#  ' nutrition now',
#  ' nasopure',
#  ' gaspari nutrition',
#  ' green foods corporation',
#  " heather's tummy care",
#  ' wise essentials',
#  ' white egret personal care',
#  'каши',
#  ' arrowhead mills',
#  ' alvera',
#  ' earthrise',
#  " jack n' jill",
#  ' safari',
#  ' animal essentials',
#  ' liverite',
#  ' benton',
#  'пропитка',
#  ' crown prince natural',
#  ' tierra mia organics',
#  'смесь',
#  ' oxyfresh',
#  ' i and love and you',
#  ' man sports',
#  ' riley’s organics',
#  ' c.c. pollen',
#  " lily's sweets",
#  " nature's best, isopure",
#  ' wobenzym n',
#  ' band aid',
#  ' all good products',
#  ' cascadian farm',
#  'кейс',
#  ' life-flo',
#  ' alta health',
#  ' зубная нить',
#  'queen helene, скраб с овсяными хлопьями и медом, 6 унций (170 г)',
#  ' healthy origins',
#  'блины',
#  ' гарциния камбоджийская',
#  ' honees',
#  'джем',
#  ' torie & howard',
#  'харусаме с креветками том ям',
#  ' mrs. dash',
#  ' g.h. cretors',
#  ' modern products',
#  ' rocco & roxie',
#  ' eclectic institute',
#  ' спортивные добавки',
#  'консервация',
#  ' ecotools',
#  ' cosrx',
#  'аппетитная курочка',
#  ' the face shop',
#  ' super nutrition',
#  ' bragg',
#  ' california olive ranch',
#  ' vegansmart',
#  ' babyganics',
#  ' alkazone',
#  ' clif bar',
#  'быстрое',
#  ' femme',
#  ' everyday coconut',
#  ' plant therapy',
#  'суши лосось',
#  ' pure bites',
#  ' andean dream ',
#  ' yeouth',
#  ' halo',
#  ' live clean',
#  ' if you care',
#  ' innate response formulas',
#  ' daily wellness company',
#  ' maranatha',
#  ' cat dancer',
#  ' kind bars',
#  ' stridex',
#  ' vega',
#  ' bio nutrition',
#  " mommy's bliss",
#  ' гейнеры',
#  ' xyloburst',
#  ' one brands',
#  ' мужские мультивитамины',
#  ' onnit',
#  ' clear products',
#  ' spectrum culinary',
#  ' волосы, кожа и ногти',
#  ' amazing herbs',
#  ' lifeseasons ',
#  ' nutrabio labs',
#  ' g9skin',
#  ' brothers-all-natural',
#  'удон с курицей в чесночном соусе',
#  ' cocomels',
#  ' himalaya',
#  ' физалис',
#  ' funfresh foods',
#  ' walden farms',
#  ' leaders',
#  ' рыбий жир омега-3',
#  ' swerve',
#  'мякоть',
#  'аджика',
#  'гренки чесночные',
#  ' stewart',
#  ' auromere',
#  ' kettle foods',
#  ' aurora nutrascience',
#  ' biotta',
#  ' omg! organic meets good',
#  ' real purity',
#  ' корица',
#  ' emerald laboratories',
#  ' healthsmart foods, inc.',
#  'перец',
#  'шампиньоны',
#  ' natural dynamix (ndx)',
#  ' cleanwell',
#  ' bio-strath',
#  ' dapple',
#  ' ola loa',
#  'восточные',
#  ' teeccino',
#  'rich яблоко',
#  ' instanatural',
#  " naturally it's clean",
#  ' kaged muscle',
#  ' гидроксиметилбутират',
#  ' масла и спреды',
#  " barlean's",
#  ' lundberg',
#  ' магний',
#  ' pedialyte',
#  ' yumearth',
#  'салат',
#  'сахар,',
#  ' novex biotech',
#  ' manukaguard',
#  ' boiron, single remedies',
#  ' kabrita',
#  'клетчатка',
#  ' coral llc',
#  'овощная',
#  ' vibrant health',
#  ' quantum health',
#  'завтраки',
#  ' carlson labs',
#  ' kericure',
#  ' lifetime vitamins',
#  'заправка',
#  ' dynamic health',
#  ' honey gardens',
#  ' ener-c',
#  ' emergen-c',
#  ' biosil by natural factors',
#  ' biotivia',
#  " nature's herbs",
#  ' upspring',
#  ' гинкго билоба',
#  ' диетические средства',
#  ' purely elizabeth',
#  ' каму-каму',
#  ' grenade',
#  ' suncoatgirl',
#  ' aura cacia',
#  ' beyond fresh',
#  ' миндаль',
#  ' madre labs',
#  ' macrolife naturals',
#  ' king arthur flour',
#  ' уход за питомцами',
#  'макаронные',
#  ' kolorex',
#  'вегетарианская (new)',
#  ' smartypants',
#  ' natural balance',
#  ' the honest kitchen',
#  ' solaray',
#  ' sunfood',
#  ' сывороточный белок',
#  'rich вишня',
#  ' alter eco',
#  'домашний лимонад',
#  ' art naturals',
#  ' davinci laboratories of vermont',
#  ' зелень и суперпродукты',
#  ' acure',
#  ' ojio',
#  ' neilmed',
#  ' summer infant',
#  ' earnest eats ',
#  ' carrington farms',
#  ' незаменимые жирные кислоты, комбинации омега 3-6-9',
#  ' zand',
#  ' sambucol',
#  ' petal fresh',
#  ' symbiotics',
#  ' amish origins',
#  ' аминокислоты',
#  'джем,',
#  'греческий салат',
#  ' бутылки, шейкеры и вода',
#  ' foods alive',
#  " men's health",
#  ' almondina ',
#  ' селен',
#  ' bioray inc.',
#  ' motherlove',
#  ' омега-7',
#  'натуральная',
#  ' badger company',
#  'суши капеллана масаго',
#  'хлебцы',
#  'сухие',
#  'сет № 2',
#  ' deva',
#  ' starwest botanicals',
#  'печенье',
#  'пюре',
#  ' oakmont labs',
#  ' wholesome sweeteners',
#  ' qunol',
#  'уксус',
#  " earth's best",
#  ' renew life',
#  ' back to nature ',
#  ' etude house',
#  ' ancient secrets, lotus brand inc.',
#  ' real techniques by sam and nic',
#  ' umac-core',
#  ' evolution of smooth',
#  ' scivation',
#  ' puremark naturals ',
#  'сахар',
#  ' orgain',
#  ' owyn',
#  ' life extension',
#  'крупы,',
#  'куриные крылья барбекю',
#  ' california gold nutrition, cgn',
#  'мастика\xa0«домашняя',
#  ' scandinavian formulas',
#  ' пищеварительные ферменты',
#  ' pure indian foods',
#  ' amazon therapeutics',
#  ' lipo naturals',
#  'суши спайс лосось',
#  'ассорти',
#  ' somersaults',
#  ' blistex',
#  'закуска',
#  ' kal',
#  ' vital planet',
#  ' ultima replenisher',
#  ' яблочный уксус',
#  ' san nutrition',
#  ' lily of the desert',
#  ' jarrow formulas',
#  ' kikkoman',
#  ' body gold',
#  ' the saem',
#  ' fifty 50',
#  ' biochem',
#  ' aquaphor',
#  ' бакалейные товары',
#  'therabreath, добавка для воды "свежее дыхание", для собак и кошек, умеренный аромат, 16 жид. унций (473 мл)',
#  ' мультивитамины',
#  ' reaal',
#  ' skratch labs',
#  'компот',
#  ' pronatura',
#  ' pure protein',
#  ' wellesse premium liquid supplements',
#  ' absorbaid',
#  ' johnson & johnson',
#  " nature's bounty",
#  'масла,',
#  ' health and wisdom inc.',
#  'азиатская',
#  'удон со свининой в чесночном соусе',
#  ' body fortress',
#  ' coconut secret',
#  ' thayers',
#  'батончик',
#  ' кондиционер',
#  'четыре сыра',
#  'фруктовые',
#  ' ddrops',
#  'кукуруза',
#  'сет с угрем',
#  'чесночная',
#  ' ooh snap!',
#  ' чеснок, специи',
#  ' eidon mineral supplements',
#  ' bach',
#  ' nutricology',
#  ' fidobiotics',
#  " hyland's",
#  ' mrs. meyers clean day',
#  ' olympian labs inc.',
#  ' sotru',
#  ' prolab',
#  ' north american herb & spice co.',
#  ' universal nutrition',
#  ' designer protein',
#  'огурцы',
#  ' rapidfire',
#  ' alkalife',
#  " doctor's best",
#  'мужская',
#  ' a.c. grace company',
#  ' продукты для выпечки, мука и смеси',
#  ' usn',
#  ' fairhaven health',
#  " charlie's soap, inc.",
#  'шоколад',
#  ' natracare',
#  ' пищеварение',
#  ' prelief',
#  ' bodylogix',
#  ' desert essence',
#  ' naka herbs & vitamins ltd',
#  ' neosporin',
#  ' nunaturals',
#  ' met-rx',
#  'ризотто',
#  ' earth circle organics',
#  'кофе,',
#  'удон с говядиной ньюпай',
#  ' kava king products inc',
#  ' premama',
#  'соки,',
#  ' снотворные',
#  ' sunny green',
#  ' plum organics',
#  ' health plus inc.',
#  ' essential living foods',
#  ' для малышей и детей постарше',
#  ' weleda',
#  ' масла, спреды и пресервы',
#  ' sinol',
#  'суши угорь',
#  ' heimish',
#  ' golden flower',
#  'отруби',
#  " nature's way",
#  ' nutrex hawaii',
#  ' zhou nutrition',
#  ' earth mama',
#  ' mediheal',
#  ' estroven',
#  ' bioglan',
#  'десерт',
#  " otto's naturals",
#  'фантазия',
#  ' формулы с оксидом азота',
#  ' cobra labs',
#  'удон со свининой ньюпай',
#  ' mount hagen',
#  ' tea tree therapy',
#  ' allvia',
#  ' pixi beauty',
#  ' тертое какао',
#  ' jamie eason',
#  ' rsp nutrition',
#  ' petitfee',
#  ' sierra bees',
#  'now foods, жидкое кокосовое масло, чистое ректифицированное, 473 мл',
#  'смузи',
#  ' natierra',
#  ' dragon herbs ( ron teeguarden )',
#  ' lumineux oral essentials',
#  ' traditional medicinals',
#  ' соль',
#  ' metabolic maintenance',
#  " nature's answer",
#  ' bluebonnet nutrition',
#  ' hi tech pharmaceuticals',
#  ' health warrior, inc.',
#  ' popchips',
#  ' smith & vandiver',
#  'гречневый',
#  ' himalania',
#  ' травы и специи',
#  ' zollipops ',
#  'напиток',
#  ' california natural',
#  ' fish-oil, omegas, sports',
#  ' асаи',
#  ' philips avent',
#  ' efx sports',
#  'венецианская',
#  ' рыбий жир и омега (epa dha)',
#  ' frontier natural products',
#  ' aakg (arginine a-ketoglutarate)',
#  ' klamath',
#  ' brainstrong',
#  ' full circle home llc',
#  'разрыхлитель',
#  'сет с лососем',
#  'кетчуп,',
#  ' original sprout inc',
#  'початки',
#  ' bio-kult',
#  ' rhythm superfoods',
#  ' грибные смеси',
#  ' bucked up',
#  ' ancient apothecary',
#  ' растительный белок',
#  " snyder's",
#  ' health support',
#  ' novaforme',
#  ' heritage store',
#  ' sprout living',
#  'злаковый',
#  ' thinkthin',
#  ' rainbow research',
#  'сет',
#  ' бетагидроксибутиратные соли',
#  'яичная',
#  ' organix south',
#  ' endangered species chocolate',
#  'мука',
#  ' витамин b',
#  ' similasan',
#  'цикорий',
#  'для',
#  ' emerita',
#  'морс облепиховый',
#  ' sun chlorella',
#  ' snp',
#  " l'il critters",
#  'том ям',
#  'чизкейк нью-йорк (карамельный)',
#  ' europharma, terry naturally',
#  'рататуй',
#  'чеснок',
#  ' rawfusion',
#  ' nu-pore',
#  ' восстановление после тренировки',
#  'зефир,',
#  'чай,',
#  ' yogourmet',
#  ' visine',
#  " george's aloe vera",
#  ' lakanto',
#  ' biobag',
#  ' nutralife',
#  ' спортивные батончики, печенье, пирожные',
#  ' орви, кашель и грипп',
#  ' bar keepers friend',
#  ' global healthcare',
#  'американская классика',
#  ' sage spirit',
#  ' цинк',
#  ' vet organics',
#  ' celtic sea salt',
#  ' bn labs',
#  ' better life',
#  ' wellgenix',
#  ' herbal answers, inc',
#  ' смеси аминокислот',
#  ' протеин казеиновый',
#  'сайра',
#  ' greenpeach',
#  " annie's homegrown",
#  ' four sigmatic',
#  ' great lakes gelatin co.',
#  ' real aloe inc.',
#  ' best naturals',
#  ' wild planet',
#  ' miracle care',
#  ' sports research',
#  ' fini modena',
#  ' seasnax',
#  ' ark naturals',
#  ' olbas therapeutic',
#  ' attitude',
#  ' смеси зелени и суперпродуктов',
#  'new chapter, bone strength take care, 270 таблеток',
#  ' vitafusion',
#  'конфеты',
#  ' wisdom natural',
#  ' dickinson brands',
#  'вода',
#  ' dream water',
#  ' yogi tea',
#  'аль тоне тунец',
#  ' flintstones',
#  ' mason natural',
#  ' ageless foundation laboratories',
#  'приправа',
#  ' garden of life',
#  ' ovega-3',
#  ' andalou naturals',
#  ' sibu beauty',
#  ' terrasoul superfoods',
#  ' redcon1',
#  ' bnrg',
#  " bob's red mill",
#  ' yum-vs',
#  ' holika holika',
#  ' balanceuticals',
#  ' dietworks',
#  ' bio tech pharmacal, inc',
#  ' gaea',
#  ' протеиновые смеси',
#  ' ягоды годжи',
#  'ассорти острая',
#  ' витамины и минералы для питомцев',
#  ' natural factors',
#  ' mestemacher',
#  ' sunbiotics',
#  ' country life',
#  ' препараты для жкт',
#  ' everyday shea',
#  " christopher's original formulas",
#  'now foods, решения, кокосовое масло, 7 жидк. унц. (207 мл)',
#  ' three lollies',
#  'coca-cola',
#  ' sea tangle noodle company',
#  ' naturanectar',
#  ' metamucil',
#  ' maximum human performance, llc',
#  ' asutra',
#  ' darford',
#  ' superior source',
#  'масла',
#  ' zenwise health',
#  'салат цезарь с креветками',
#  ' shea baby',
#  ' зеленый чай, продукты',
#  ' herbs etc.',
#  ' ecodiscoveries',
#  ' якорцы стелющиеся',
#  'маца',
#  ' the natural dentist',
#  ' mori-nu',
#  ' puppy cake',
#  'красота',
#  'кэроб',
#  ' twinlab',
#  ' препараты с глюкозамином',
#  'acure, brilliantly brightening, скраб для лица, 4 ж. унц. (118 мл)',
#  'coca cola zero',
#  ' jason natural',
#  ' jeffrey james botanicals',
#  ' dr. mercola',
#  'маринара италиано',
#  ' new nordic us inc',
#  ' витамины',
#  ' sonne’s organic foods',
#  ' dr. woods',
#  ' предстательная железа',
#  ' carmex',
#  ' sunshine',
#  'хлопья',
#  ' peakfresh usa',
#  ' женские мультивитамины',
#  ' think',
#  'макароны',
#  ' country archer jerky',
#  ' huy fong foods inc.',
#  'мисо суп классический',
#  ' mustela',
#  ' hydroxycut',
#  'детское',
#  ' ultra enterprises',
#  ' черника',
#  ' стимуляторы',
#  'картофель фри',
#  " schmidt's naturals",
#  ' зелень',
#  'цезарь',
#  ' aroma naturals',
#  ' mild by nature',
#  ' abracadabra, abra therapeutics',
#  'картофель по-деревенски',
#  ' chocolove',
#  'детская',
#  ' st. dalfour',
#  'сет на одного',
#  ' nutiva',
#  ' fire cider',
#  ' nutribiotic',
#  ' arizona natural',
#  ' лососевое масло',
#  ' zma',
#  " o'donnell formulas",
#  ' atkins',
#  'капучино',
#  ' протеин',
#  " michelle's miracle",
#  ' kalaya calandri',
#  ' zarbees',
#  ' primaforce',
#  ' goco',
#  " molly's suds",
#  ' minami nutrition',
#  ' port trading co.',
#  ' allergy research group',
#  ' homeopet',
#  ' ancient harvest',
#  ' бульоны и мясные отвары',
#  ' ast sports science',
#  ' zint',
#  ' tazo teas',
#  'суп',
#  ' almased usa',
#  ' sunwarrior',
#  " garden of eatin'",
#  ' longreen corporation',
#  ' happy family organics',
#  ' l-глютамин',
#  ' natural sources',
#  'миланская',
#  'сырные ломтики',
#  ' iherb goods',
#  ' relacore',
#  ' nature republic',
#  ' quality of life labs',
#  ' дом',
#  'чипсы,',
#  ' sky organics',
#  ' peanut butter & co.',
#  ' neocell',
#  'megafood, детская ежедневная добавка для иммунной системы kids daily immune, без подсластителей, 66 г (2.3 унц.)',
#  ' nordic naturals professional',
#  'паста',
#  ' goorganic',
#  " dr. harvey's",
#  'рис',
#  'соусы,',
#  ' fungiology',
#  ' citracal',
#  ' desitin',
#  ' солнцезащитные средства для малышей',
#  'харусаме с говядиной ньюпай',
#  ' nla for her',
#  ' madegood',
#  ' vita logic',
#  ' world organic',
#  'фасоль',
#  ' reviva labs',
#  ' teras whey',
#  " nairn's inc",
#  ' pioneer nutritional formulas',
#  ' valor',
#  'орехи,',
#  ' кокосовый сахар',
#  ' my magic mud',
#  " earth's bounty ( matrix health ) ",
#  ' пробиотики',
#  ' mizon',
#  ' probulin',
#  ' fit & lean',
#  ' сон',
#  ' nurturme',
#  ' balance bar ',
#  ' secret key',
#  ' cococare',
#  'рыбные',
#  ' living intentions',
#  ' veggie wash',
#  'томаты',
#  ' грибы',
#  ' mri',
#  ' method',
#  'горчица',
#  ' big tree farms',
#  ' rainbow light',
#  ' oregons wild harvest',
#  'харусаме со свининой ньюпай',
#  ' boericke & tafel',
#  ' aerobic life',
#  ' shake it pup',
#  'посыпка',
#  ' the missing link',
#  " nature's secret",
#  ' twinings',
#  ' пренатальные витамины',
#  ' dr. axe / ancient nutrition',
#  ' source naturals',
#  ' vitamin friends',
#  ' montana big sky ',
#  'овсяные',
#  ' the ginger people',
#  ' ricola',
#  ' foodscience',
#  ' greensations',
#  'проверочный',
#  ' organic india',
#  ' musclepharm natural',
#  'куриные крылья баффало',
#  ' meyenberg goat milk',
#  ' чипсы',
#  " honey i'm home",
#  ' sundown naturals',
#  ' тестостерон',
#  ' spectrum essentials',
#  " nature's life",
#  'детям',
#  ' elizavecca',
#  'готовый',
#  ' organic traditions',
#  " dr. ohhira's, essential formulas inc.",
#  ' earthtone foods',
#  ' queen helene',
#  'кабачки',
#  ' harney & sons',
#  ' allimax',
#  ' the seaweed bath co.',
#  ' grab green',
#  " barbara's bakery ",
#  ' advanced clinicals',
#  ' расторопша пятнистая',
#  ' abkit',
#  " uncle lee's tea",
#  ' imperial elixir',
#  ' травы и гомеопатия',
#  'хрен,',
#  ' nutramax',
#  ' gerber',
#  ' ayr',
#  ' e.l.f. cosmetics',
#  'свекла',
#  'маргарита',
#  'оливки',
#  ' caribbean solutions',
#  ' орехи и семена',
#  ' мультиминеральные препараты',
#  ' amazing grass',
#  ' микроэлементы',
#  ' sprout organic',
#  ' garden greens',
#  ' good health natural foods',
#  ' bioadvantex pharma',
#  ' кальций',
#  ' stoneridge orchards',
#  ' rishi tea',
#  ' real salt',
#  ' beco pets',
#  " lucy's",
#  ' goddess garden',
#  'сок',
#  ' weetabix',
#  ' oxylife',
#  'крупа',
#  'харусаме с курицей по-пекински',
#  ' mill creek botanicals',
#  'хумус',
#  ' bcaa',
#  ' margarite cosmetics',
#  ' препараты на основе трав',
#  ' naturade',
#  ' crystal body deodorant',
#  ' sejoyia',
#  'продукты',
#  ' align',
#  ' radius',
#  ' ecobags',
#  ' кешью',
#  ' dandy blend',
#  ' коэнзим q10 (coq10)',
#  ' holistic blend',
#  ' bausch & lomb',
#  ' bergin fruit and nut company',
#  ' indigo wild',
#  ' co - e1',
#  ' vitanica',
#  ' well wisdom',
#  " nature's wild organic ",
#  ' j r watkins',
#  'сладости',
#  'хрустящее',
#  'верона',
#  ' earth balance ',
#  ' мицеллярный казеиновый протеин',
#  ' daiwa health development',
#  'глазурь',
#  'торты,',
#  ' neutrogena',
#  ' apex',
#  ' econugenics',
#  ' лукума',
#  ' shikai',
#  ' veglife',
#  ' frownies',
#  ' la tourangelle',
#  ' houston enzymes',
#  ' zesty paws',
#  'харусаме с курицей в чесночном соусе',
#  ' optimox corporation',
#  " wally's natural",
#  ' rapunzel',
#  ' zahler',
#  ' куркума и куркумин',
#  ' growing naturals',
#  ' bionaturae',
#  ' dr. dunner, usa',
#  ' чага',
#  ' dandies ',
#  ' препараты для беременных и родивших женщин',
#  'растительный',
#  ' пробиотики для детей',
#  ' клюква',
#  ' silicium laboratories llc',
#  ' organic mushroom nutrition',
#  ' mezotrace',
#  ' willard',
#  'кекс',
#  ' savesta',
#  ' neuroscience',
#  ' boiron',
#  ' nuun',
#  ' dukan diet',
#  ' мака',
#  'торт "блэк джин (шоколадный)"',
#  ' i heart keenwah',
#  ' triple leaf tea',
#  ' azo',
#  ' country choice organic ',
#  " mane 'n tail",
#  'зерно',
#  ' мелатонин',
#  ' cat-man-doo',
#  ' суп и бульон',
#  ' 21st century',
#  'чипсы',
#  ' tinkyada',
#  'сет премиум',
#  ' stash tea',
#  'охотничья',
#  ' nootie',
#  ' american health',
#  'горошек«спело-зрело»,',
#  ' ip-6 international',
#  ' kevala',
#  'solgar, celadrin, 525mg, 60 softgels',
#  'грибные',
#  ' cosmedica skincare',
#  ' кости и суставы',
#  ' boogie wipes',
#  ' missha',
#  ' life enhancement',
#  ' protocol for life balance',
#  ' enzymedica',
#  'сет на выходные',
#  ' general mills ',
#  ' terra origin',
#  ' furious formulations',
#  ' coombs family farms',
#  ' viesun',
#  'соль,',
#  'суприм',
#  ' iforce nutrition ',
#  ' giovanni',
#  ' harmonic innerprizes',
#  ' maximum international',
#  ' nuby',
#  ' nature made',
#  'яки-соба ньюпай',
#  ' ulubulu',
#  ' категории',
#  ' all one, nutritech',
#  'now foods, целадрин и msm, 120 капсул',
#  ' уход за телом',
#  ' железо',
#  'питание',
#  ' aztec secret',
#  ' dear, klairs',
#  ' thompson',
#  ' squip',
#  ' go raw',
#  ' toms of maine',
#  ' чай',
#  " annie's naturals",
#  ' the first years',
#  ' fitmiss',
#  'fitness',
#  ' vetri-science',
#  ' julian bakery',
#  ' чай маття',
#  ' thorne research',
#  ' grape seed extract',
#  ' kelapo',
#  ' cerave',
#  ' fungi perfecti ',
#  'burn (бёрн)',
#  ' musclemeds',
#  ' детские мультивитамины',
#  ' futurebiotics',
#  ' diamond herpanacine associates',
#  ' sun potion',
#  ' уход за полостью рта ',
#  'ветчирелла',
#  ' emerald health bioceuticals, inc',
#  ' liddell',
#  'удон с курицей по-пекински',
#  'сет сакура',
#  ' purely inspired ',
#  'грецкие',
#  'кофе',
#  'дрожжи',
#  ' historical remedies',
#  ' made in nature',
#  ' варенье',
#  ' ягоды аристотелии чилийская',
#  ' для мытья посуды',
#  ' paradise herbs',
#  ' ctd sports',
#  ' royal tropics',
#  ' bio-oil',
#  ' жиросжигатели',
#  'харусаме со свининой в чесночном соусе',
#  ' здоровье детей',
#  ' crystal star',
#  ' средства для ухода за детскими домашними вещами',
#  ' кокосовая мука',
#  ' living clay',
#  ' manuka health',
#  'филадельфия',
#  ' st. ives',
#  ' allmax nutrition',
#  ' добавки для питомцев',
#  ' maine coast sea vegetables',
#  'чизкейк нью-йорк (классика)',
#  ' plantfusion',
#  ' canine matrix',
#  ' wiseways herbals, llc',
#  'печенье,',
#  ' finn crisp',
#  ' natrol',
#  ' genceutic naturals',
#  'сет № 3',
#  ' hello',
#  ' ridgecrest herbals',
#  'фундук',
#  ' hobe labs',
#  ' батончики для перекуса',
#  ' pure vegan',
#  ' bionorica',
#  ' equal exchange ',
#  'бакалея',
#  ' purity products',
#  'new chapter, эстротон, 60 вегетарианских капсул',
#  ' planetary herbals',
#  ' musclemaxx',
#  ' phillips',
#  ' champion nutrition',
#  ' maca magic',
#  'пицца',
#  'сет для двоих',
#  ' genexa llc',
#  ' muscletech',
#  ' arm & hammer',
#  ' prince of peace',
#  'вермишель',
#  ' de la cruz',
#  " women's health",
#  ' earth therapeutics',
#  ' earth rated',
#  ' the synergy company',
#  'жевательная',
#  ' chimes',
#  ' buff bake',
#  ' american biosciences',
#  ' edward & sons',
#  ' hot kid',
#  'чикен алоха',
#  ' citrus magic',
#  'такусан сет',
#  ' lansinoh',
#  'мед',
#  ' organic excellence',
#  ' препараты для памяти и когнитивных функций',
#  ' twist',
#  'классика',
#  'томатный',
#  'rich апельсин',
#  ' уход за волосами',
#  ' tony moly',
#  ' gat',
#  ' creative bioscience',
#  'клечатка',
#  ' real health',
#  ' health from the sun',
#  'суши спайс креветка',
#  'ингредиенты',
#  ' какао',
#  " michael's naturopathic",
#  ...}

# %%
slots = [s.strip() for s in slots if len(s.strip()) < 24]

# %%
slots = set(slots)
slots
# Out:
# {'',
#  'humphreys',
#  'general mills',
#  'категории',
#  "otto's naturals",
#  'kind bars',
#  'california natural',
#  "nature's path",
#  'alkazone',
#  "michael's naturopathic",
#  'деревенская',
#  'fifty 50',
#  'health plus inc.',
#  'wilderness poets llc',
#  'детям',
#  'g.h. cretors',
#  'готовый',
#  'фруктоза',
#  'корица',
#  'мисо суп с лососем',
#  'seagate',
#  'novex biotech',
#  'smartypants',
#  'band aid',
#  'torie & howard',
#  'кисель',
#  'a.c. grace company',
#  'nuk',
#  "nature's wild organic",
#  'bio kleen',
#  'organic valley',
#  'health direct',
#  'youtheory',
#  'смузи',
#  'цикорий,',
#  'shikai',
#  'aztec secret',
#  'черника',
#  'сон',
#  'indigo wild',
#  'черный тмин',
#  'кабачки',
#  'сет с горячими роллами',
#  'meyenberg goat milk',
#  'сладая',
#  'dukan diet',
#  'made in nature',
#  'three lollies',
#  'диета и контроль веса',
#  'earth science',
#  'vita logic',
#  "heather's tummy care",
#  'микроэлементы',
#  'cerave',
#  "nature's plus",
#  'xlear',
#  'vital proteins',
#  'ancient harvest',
#  'yogi tea',
#  'world organic',
#  'травы и гомеопатия',
#  'real salt',
#  'terra origin',
#  'cobra labs',
#  'hurraw!',
#  "earth's best",
#  'kal',
#  'mediheal',
#  "george's aloe vera",
#  'sundown naturals',
#  'спортивные добавки',
#  'каши',
#  'teras whey',
#  'earthtone foods',
#  'хрен,',
#  'мака',
#  'чай маття',
#  'pacifica',
#  'женские мультивитамины',
#  'orgain',
#  'pronatura',
#  'e.l.f. cosmetics',
#  'real foods',
#  'jason natural',
#  'femarelle',
#  'blistex',
#  'варенье',
#  'pure indian foods',
#  'гречневый',
#  'протеин казеиновый',
#  'genexa llc',
#  'l-цитруллин',
#  'bionorica',
#  'пропитка',
#  'eclectic institute',
#  'dr. woods',
#  'abkit',
#  'eating evolved',
#  'смесь',
#  'nu-pore',
#  'nla for her',
#  'gonesh',
#  'apex',
#  'quantum health',
#  'harmonic innerprizes',
#  'ultima replenisher',
#  'напиток',
#  'spectrum essentials',
#  'сухари,',
#  'i play inc.',
#  'kericure',
#  'mri',
#  'goco',
#  'babyganics',
#  'свекла',
#  'earth balance',
#  'vitanica',
#  'маргарита',
#  'оливки',
#  'coromega',
#  'nunaturals',
#  'laird superfood',
#  'снотворные',
#  'ecodiscoveries',
#  'seasnax',
#  'кокосовое',
#  'кейс',
#  'carrington farms',
#  'bio tech pharmacal, inc',
#  'кондитерские',
#  'king arthur flour',
#  'стимуляторы',
#  'swisse',
#  'health from the sun',
#  'j r watkins',
#  'предстательная железа',
#  'flapjacked',
#  'венецианская',
#  'блины',
#  'usn',
#  'valor',
#  'badger company',
#  'джем',
#  'weetabix',
#  'met-rx',
#  "dr. brown's",
#  'спортивное питание',
#  'reese',
#  'консервация',
#  'fungiology',
#  'everyday coconut',
#  'biobag',
#  'zhou nutrition',
#  'разрыхлитель',
#  'сет с лососем',
#  'carmex',
#  'кетчуп,',
#  'nutricology',
#  'початки',
#  'ecover',
#  'yeouth',
#  'sprout organic',
#  'аппетитная курочка',
#  'indiumease',
#  'g9skin',
#  'manuka health',
#  'stoneridge orchards',
#  'oakmont labs',
#  'prelief',
#  'desitin',
#  'батончики',
#  'фруктовая',
#  'swerve',
#  'allergy research group',
#  'сок',
#  'vetri-science',
#  'dr. mercola',
#  'minami nutrition',
#  'gerber',
#  'femme',
#  'estroven',
#  'live clean',
#  'ulubulu',
#  'быстрое',
#  'pure bites',
#  'macrolife naturals',
#  'maca magic',
#  'food should taste good',
#  'homeopet',
#  'sunfood',
#  'san nutrition',
#  'designer protein',
#  'queen helene',
#  'the natural dentist',
#  'bionaturae',
#  'ip-6 international',
#  'злаковый',
#  'крупа',
#  'neosporin',
#  'lifetime vitamins',
#  'seventh generation',
#  'bucked up',
#  'mild by nature',
#  'суши лосось',
#  'хумус',
#  'iforce nutrition',
#  'отдельные масла',
#  'сет',
#  'bausch & lomb',
#  'twinlab',
#  "nature's gate",
#  'desert essence',
#  'metabolic maintenance',
#  'brush buddies',
#  'nuco',
#  'яичная',
#  'vital essentials',
#  "earth's care",
#  'essential living foods',
#  'мука',
#  'andalou naturals',
#  'big tree farms',
#  'miracle noodle',
#  'l-карнитин',
#  'deva',
#  'optimox corporation',
#  'продукты',
#  'здоровье детей',
#  'цикорий',
#  'для',
#  'новый',
#  'motherlove',
#  'пробиотики для детей',
#  'sonne’s organic foods',
#  'musclemeds',
#  'sprite',
#  'pure essence',
#  'redd remedies',
#  "o'donnell formulas",
#  'морс облепиховый',
#  'gaia herbs',
#  'naturade',
#  "hyland's",
#  'earth mama',
#  'beco pets',
#  'vitalah',
#  'rishi tea',
#  'куркума и куркумин',
#  'zollipops',
#  'том ям',
#  'баварская',
#  'go raw',
#  'kava king products inc',
#  'alvera',
#  'холодный чай каркаде',
#  'instanatural',
#  'витамин с',
#  'гидроксиметилбутират',
#  "nature's best, isopure",
#  'rawfusion',
#  'health warrior, inc.',
#  'кальций',
#  'гинкго билоба',
#  'flintstones',
#  'terrasoul superfoods',
#  'primal kitchen',
#  'maranatha',
#  "o'keeffe's",
#  "schmidt's naturals",
#  'рататуй',
#  'чеснок',
#  'brothers-all-natural',
#  'umac-core',
#  'lifeseasons',
#  'kabrita',
#  'petitfee',
#  'wellgenix',
#  'organic traditions',
#  'earth rated',
#  'рейши',
#  'салат цезарь с курицей',
#  'irwin naturals',
#  'яблочный уксус',
#  'hot kid',
#  'dynamic health',
#  'зефир,',
#  'миндаль',
#  'gostak',
#  'крекеры',
#  'panda licorice',
#  'чай,',
#  'redcon1',
#  'novaforme',
#  'рыбий жир омега-3',
#  'zahler',
#  'кости и суставы',
#  'дракон',
#  'готовые',
#  'arizona natural',
#  'сет для гурманов',
#  'orajel',
#  'funfresh foods',
#  'natural balance',
#  'organyc',
#  'мясные',
#  'сладости',
#  'хрустящее',
#  'starwest botanicals',
#  'universal nutrition',
#  'peakfresh usa',
#  'grenade',
#  'bioglan',
#  'nurturme',
#  "men's health",
#  'cocomels',
#  'зубная нить',
#  'пренатальные витамины',
#  'leaders',
#  "nature's secret",
#  'organic india',
#  'суп и бульон',
#  'musclemaxx',
#  'aquaphor',
#  'pb2 foods',
#  'верона',
#  'emerita',
#  'американская классика',
#  'мякоть',
#  "charlie's soap, inc.",
#  'аджика',
#  'cosmedica skincare',
#  'глазурь',
#  'derma e',
#  'ooh snap!',
#  'торты,',
#  'пищеварение',
#  'foodscience',
#  'бузина',
#  'гренки чесночные',
#  'коэнзим q10 (coq10)',
#  'hollywood diet',
#  'bioadvantex pharma',
#  'halo',
#  'аминокислоты',
#  'twist',
#  'ancient apothecary',
#  'afterspa',
#  'shea baby',
#  'plum organics',
#  'wobenzym n',
#  'absorbaid',
#  'sotru',
#  'biotta',
#  'препараты для жкт',
#  'cat dancer',
#  'walden farms',
#  'natierra',
#  'fungi perfecti',
#  'enzymatic therapy',
#  'торт "тирамису"',
#  'leven rose',
#  'королева моря',
#  'american health',
#  'homeolab usa',
#  'бутылки, шейкеры и вода',
#  'babo botanicals',
#  "nature's answer",
#  'crystal body deodorant',
#  'yerba prima',
#  'ark naturals',
#  'витамин b',
#  'перец',
#  'сайра',
#  'bcaa',
#  'boogie wipes',
#  'bio nutrition',
#  'шампиньоны',
#  'tpcs',
#  'canine matrix',
#  'vitafusion',
#  'грибы',
#  'zantrex',
#  'ascenta',
#  'здоровый образ жизни',
#  'petaction plus',
#  'гарциния камбоджийская',
#  'mason natural',
#  'уход за полостью рта',
#  'бакалейные товары',
#  'l-глютамин',
#  'жульен',
#  'natural sport',
#  'country choice organic',
#  "barbara's bakery",
#  'adora',
#  'the saem',
#  "nature's bounty",
#  'asutra',
#  'longreen corporation',
#  'креатин, спорт',
#  'прованские',
#  'wisdom natural',
#  'neuroscience',
#  '4th & heart',
#  'olbas therapeutic',
#  'tazo teas',
#  'мед и подсластители',
#  'baby banana',
#  'восточные',
#  "annie's homegrown",
#  'kolorex',
#  'one brands',
#  'xyloburst',
#  'rich яблоко',
#  "michelle's miracle",
#  'зеленый чай, продукты',
#  'thompson',
#  'eden foods',
#  'dapple',
#  'grab green',
#  'four sigmatic',
#  'living intentions',
#  'actipet',
#  'man sports',
#  'i and love and you',
#  'bluebonnet nutrition',
#  'mizon',
#  'fit & lean',
#  'traditional medicinals',
#  'nature made',
#  'home health',
#  't-rq',
#  'healthsmart foods, inc.',
#  'clear products',
#  'healthforce superfoods',
#  'green foods corporation',
#  'конфеты',
#  'greens world',
#  'scivation',
#  'similasan',
#  'aveeno',
#  'alkalife',
#  'holistic blend',
#  "nellie's",
#  'вода',
#  'sunbiotics',
#  'boericke & tafel',
#  'great lakes gelatin co.',
#  'bass brushes',
#  'popchips',
#  'goorganic',
#  'растительный',
#  'салат',
#  'аль тоне тунец',
#  'benfotiamine inc.',
#  'jamie eason',
#  'sunshine',
#  'сахар,',
#  'sinol',
#  'dandies',
#  'nuun',
#  'stridex',
#  'triple leaf tea',
#  'castor & pollux',
#  'seabuckwonders',
#  'cleanwell',
#  'sparta nutrition',
#  'one-a-day',
#  'клетчатка',
#  'oxylife',
#  'kettle & fire',
#  'мелатонин',
#  'childlife',
#  'almondina',
#  'приправа',
#  'source naturals',
#  'relacore',
#  'овощная',
#  'b-fresh inc.',
#  'чеснок, специи',
#  'petalive',
#  'crown prince natural',
#  'elizavecca',
#  'purely inspired',
#  'benton',
#  'plantfusion',
#  'palmers',
#  'beyond fresh',
#  'kashi',
#  'завтраки',
#  'ягоды годжи',
#  'nutrex hawaii',
#  'sibu beauty',
#  'suncoatgirl',
#  'labrada nutrition',
#  'смеси аминокислот',
#  'align',
#  "molly's suds",
#  'rapunzel',
#  'pero',
#  'bar keepers friend',
#  'iherb goods',
#  'кекс',
#  'gaspari nutrition',
#  'протеиновые смеси',
#  'заправка',
#  'kroeger herb co',
#  'пищевые добавки',
#  'bon aqua 0.5л',
#  'thai deodorant stone',
#  'manuka doctor',
#  'innisfree',
#  'pedialyte',
#  'tinkyada',
#  'tooth tissues',
#  'health thru nutrition',
#  'ecotools',
#  'visine',
#  'nasopure',
#  'zma',
#  'art naturals',
#  'i heart keenwah',
#  'giovanni',
#  'nugo nutrition',
#  'osteo bi-flex',
#  'pure protein',
#  'zand',
#  'кордицепс',
#  'carlson labs',
#  'generix laboratories',
#  'muscletech',
#  'жиросжигатели',
#  'морс ягодный',
#  'jarrow formulas',
#  "nature's herbs",
#  'natural sources',
#  'мясная',
#  'real purity',
#  'диетические средства',
#  'gummiking',
#  'суши',
#  'solgar',
#  'life-flo',
#  'fairhaven health',
#  'fini modena',
#  'smith & vandiver',
#  'miracle care',
#  'ассорти острая',
#  'зерно',
#  'balance bar',
#  'пробиотики',
#  'humann',
#  'овощные',
#  'amazing herbs',
#  'reserveage nutrition',
#  'mori-nu',
#  'celestial seasonings',
#  'ener-c',
#  'neilmed',
#  'thorne research',
#  'rhythm superfoods',
#  'fire cider',
#  'oregons wild harvest',
#  'zesty paws',
#  'питомцы',
#  'buried treasure',
#  'чипсы',
#  'физалис',
#  'lansinoh',
#  'kalaya calandri',
#  'уход за волосами',
#  'viesun',
#  'avalon organics',
#  'сет премиум',
#  'the first years',
#  'the dirt',
#  'culturelle',
#  'divine health',
#  'klamath',
#  'alter eco',
#  "jack n' jill",
#  'jovial',
#  'каму-каму',
#  'nutrition now',
#  'ast sports science',
#  'bio-kult',
#  'ojio',
#  'охотничья',
#  'ridgecrest herbals',
#  'azo',
#  'coca-cola',
#  'макаронные',
#  'health and wisdom inc.',
#  'витамин d',
#  'горошек«спело-зрело»,',
#  'riley’s organics',
#  'zarbees',
#  'sejoyia',
#  'c.c. pollen',
#  'уход за питомцами',
#  'champion nutrition',
#  'вегетарианская (new)',
#  'airborne',
#  'детские мультивитамины',
#  'масла',
#  'vitamin friends',
#  'hydroxycut',
#  'dear, klairs',
#  'домашняя утварь',
#  'coral llc',
#  'дом',
#  'соус',
#  'зелень и суперпродукты',
#  'super nutrition',
#  'quest nutrition',
#  'six star',
#  'blender bottle',
#  'диетическое',
#  'new nordic us inc',
#  'secret key',
#  'маца',
#  'rich вишня',
#  'safari',
#  'bach',
#  'country archer jerky',
#  'грибные',
#  'mill creek botanicals',
#  'scandinavian formulas',
#  "lily's sweets",
#  'aura cacia',
#  'домашний лимонад',
#  "dr. harvey's",
#  'liverite',
#  'maxim hygiene products',
#  'здоровье и безопасность',
#  'nutribiotic',
#  'etude house',
#  'naturanectar',
#  'julian bakery',
#  'greens first',
#  'красота',
#  'modern products',
#  'растительный белок',
#  'кэроб',
#  'finn crisp',
#  'herbion',
#  'lily of the desert',
#  'solaray',
#  'seapoint farms',
#  'crystal star',
#  'the missing link',
#  'coca cola zero',
#  'isvara organics',
#  'чай с ромашкой',
#  'emergen-c',
#  'сорбит',
#  'bodylogix',
#  'маринара италиано',
#  'stewart',
#  'сет на выходные',
#  'andean dream',
#  'edward & sons',
#  'la tourangelle',
#  'оладушки',
#  'хлопья',
#  'healthy times',
#  'lakanto',
#  'himalania',
#  'bioray inc.',
#  'bnrg',
#  'vaxa international',
#  'sky organics',
#  'st. ives',
#  'nordic naturals',
#  'макароны',
#  'pines international',
#  'sahale snacks',
#  'earth circle organics',
#  'yogourmet',
#  "uncle lee's tea",
#  'naturally vitamins',
#  'соль,',
#  'суприм',
#  'the face shop',
#  'мисо суп классический',
#  'evolution of smooth',
#  'rapidfire',
#  "wally's natural",
#  'natralia',
#  'бульоны и мясные отвары',
#  'джем,',
#  'sunny green',
#  'genceutic naturals',
#  'греческий салат',
#  'glutino',
#  'better life',
#  'premier one',
#  'life enhancement',
#  'протеиновые батончики',
#  'summer infant',
#  'якорцы стелющиеся',
#  'phion balance',
#  'яки-соба ньюпай',
#  'real health',
#  'детское',
#  'veggie wash',
#  'bio-oil',
#  'травы и специи',
#  'tea tree therapy',
#  'omg! organic meets good',
#  'лосьон',
#  'hyperbiotics',
#  'creative bioscience',
#  'back to nature',
#  'musclepharm natural',
#  'шампунь',
#  'hello',
#  'renew life',
#  'асаи',
#  'картофель фри',
#  'натуральная',
#  'nescafé',
#  'boiron, single remedies',
#  'суши капеллана масаго',
#  'цезарь',
#  'herbs etc.',
#  'фрукты и овощи',
#  'питание',
#  'хлебцы',
#  'сухие',
#  'сет № 2',
#  'yumearth',
#  'weleda',
#  'spectrum culinary',
#  'печенье',
#  'nootie',
#  'vet organics',
#  'furious formulations',
#  'уход за животными',
#  'пюре',
#  "honey i'm home",
#  'evlution nutrition',
#  'sierra bees',
#  'skratch labs',
#  'формулы с оксидом азота',
#  'daily wellness company',
#  'hobe labs',
#  'сывороточный белок',
#  'уксус',
#  'citrus magic',
#  'ryvita',
#  'de la cruz',
#  'if you care',
#  'картофель по-деревенски',
#  'master supplements',
#  'artisana',
#  'kaged muscle',
#  'чай',
#  'arthur andrew medical',
#  'детская',
#  'american biosciences',
#  'fitness',
#  'lundberg',
#  'eucerin',
#  'сет на одного',
#  'pure advantage',
#  'bellybar',
#  'закуски',
#  'rainbow light',
#  'enzymedica',
#  'garden of life',
#  "barlean's",
#  'mamma chia',
#  'zint',
#  'kelapo',
#  'протеин',
#  'vega',
#  'flower essence services',
#  'petal fresh',
#  'икра',
#  'squip',
#  'масло',
#  "nature's one",
#  'mustela',
#  'everyday shea',
#  "garden of eatin'",
#  'foods alive',
#  'radius',
#  'burn (бёрн)',
#  'mrs. dash',
#  'onnit',
#  'кокосовый сахар',
#  'dr. dunner, usa',
#  'wiseways herbals, llc',
#  'сахар',
#  'зелень',
#  'грибные смеси',
#  'enjoy life foods',
#  'amish origins',
#  'now foods',
#  'био',
#  'california olive ranch',
#  'life extension',
#  'капучино',
#  'imperial elixir',
#  'ветчирелла',
#  'кондиционер',
#  'dang foods llc',
#  'крупы,',
#  'coombs family farms',
#  'куриные крылья барбекю',
#  'all one, nutritech',
#  'nuby',
#  'brainstrong',
#  'toms of maine',
#  'железо',
#  "barry's tea",
#  'madegood',
#  'allmax nutrition',
#  'мастика\xa0«домашняя',
#  "bob's red mill",
#  'aerobic life',
#  'пепперони',
#  'metamucil',
#  'для мытья посуды',
#  'physicians formula',
#  'happy family organics',
#  'natrol',
#  'хром',
#  'huy fong foods inc.',
#  'сет сакура',
#  'wedderspoon',
#  'суши спайс угорь',
#  'ola loa',
#  'суши спайс лосось',
#  'nutrabio labs',
#  'ассорти',
#  'chocolove',
#  'greens plus',
#  'out of africa',
#  'himalaya',
#  'premama',
#  'stash tea',
#  'morningstar minerals',
#  'грецкие',
#  'the synergy company',
#  'alta health',
#  'кофе',
#  'семена',
#  'dream water',
#  'grape seed extract',
#  'herb pharm',
#  'закуска',
#  'heritage store',
#  'american biotech labs',
#  'крем-суп',
#  'johnson & johnson',
#  'дрожжи',
#  'mushroom wisdom',
#  'savesta',
#  'sovereign silver',
#  'nutiva',
#  'хрустящие',
#  'clif bar',
#  'clean machine',
#  'суп',
#  'омега-7',
#  '21st century',
#  'natural factors',
#  'zenwise health',
#  'pure vegan',
#  'my magic mud',
#  'kirkman labs',
#  'greensations',
#  "doctor's best",
#  'amazon therapeutics',
#  'willard',
#  'nubian heritage',
#  'probulin',
#  'мультивитамины',
#  'hyalogic llc',
#  'animal essentials',
#  'hi tech pharmaceuticals',
#  'миланская',
#  'allvia',
#  'сырные ломтики',
#  "mane 'n tail",
#  'simple mills',
#  'cococare',
#  'body fortress',
#  'growing naturals',
#  'alba botanica',
#  'rainbow research',
#  'buff bake',
#  'филадельфия',
#  'mount hagen',
#  'ultra enterprises',
#  'controlled labs',
#  'ddrops',
#  'pet naturals of vermont',
#  'res-q',
#  'naturvet',
#  'добавки для питомцев',
#  'appliednutrition',
#  'teeccino',
#  'vegansmart',
#  'interplexus inc.',
#  'чипсы,',
#  'лососевое масло',
#  'naturalcare',
#  'boiron',
#  'medinatura',
#  'global healthcare',
#  'country farms',
#  'компот',
#  'royal tropics',
#  'shake it pup',
#  'olympian labs inc.',
#  'gaea',
#  'well wisdom',
#  'body gold',
#  'fearn natural food',
#  'строители мышц',
#  'cascadian farm',
#  'frownies',
#  'батончики для перекуса',
#  'масла,',
#  'simply organic',
#  'гейнеры',
#  'method',
#  'quality of life labs',
#  'паста',
#  'think',
#  'cosrx',
#  'печенье,',
#  'earnest eats',
#  'wild planet',
#  'cetaphil',
#  'nature republic',
#  "women's health",
#  'reviva labs',
#  "annie's naturals",
#  'herbs for kids',
#  'flora',
#  'twinings',
#  'montana big sky',
#  'garden greens',
#  'almased usa',
#  'рис',
#  'petnc natural care',
#  'complimed',
#  'сет № 3',
#  'absolute nutrition',
#  'attitude',
#  'fidobiotics',
#  'азиатская',
#  'соевое',
#  'greenpeach',
#  "naturally it's clean",
#  'madre labs',
#  'соусы,',
#  'snp',
#  'the seaweed bath co.',
#  'костный бульон',
#  'honey gardens',
#  'everyone',
#  'biotivia',
#  'liddell',
#  'eat cleaner',
#  "wiley's finest",
#  'селен',
#  'фундук',
#  'батончик',
#  'plant therapy',
#  'печень',
#  'sambucol',
#  'holika holika',
#  "ella's kitchen",
#  'четыре сыра',
#  'dietworks',
#  'фруктовые',
#  'rejuvicare',
#  'десертные',
#  'пицца bbq',
#  'paradise herbs',
#  'кукуруза',
#  'healthy origins',
#  'dandy blend',
#  'какао',
#  'sun chlorella',
#  'nutra biogenesis',
#  "nature's life",
#  'бакалея',
#  'сет с угрем',
#  'allimax',
#  'golden flower',
#  'biogaia',
#  'чесночная',
#  'чага',
#  'surf-sweets',
#  ...}

# %%
#abrikos
data = pd.read_excel('./food/abrikos/data.xls')
data.head()
# Out:
#                                             Название  \
# 0  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 1  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 2  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 3  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 4  Мясо охлажденное и свежемороженое~Свинина~Свин...
#
#                                             Описание   Цена
# 0  Шаг заказа 1кг. Итоговый вес и сумма может нез...  445.0
# 1  \nЦена указана за 2кг. Вес может незначительно...  515.0
# 2  \nЦена за упаковку указана с учетом веса фасов...  172.0
# 3  \nШаг заказа указан с учетом вес одного языка ...  630.0
# 4  \nЦена за 1 кг. Итоговый вес и сумма могут нез...  424.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 3 columns):
# Название    4687 non-null object
# Описание    2774 non-null object
# Цена        4687 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 109.9+ KB

# %%
def to_num_abrikos(text):
    return int(text)

# %%
data['Цена'] = data['Цена'].apply(to_num_abrikos)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 3 columns):
# Название    4687 non-null object
# Описание    2774 non-null object
# Цена        4687 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 109.9+ KB

# %%
data.to_excel('./food/abrikos/data_cleaned.xls', index=False)

# %%
data = pd.read_excel('./food/abrikos/data_cleaned.xls')
data.head()
# Out:
#                                             Название  \
# 0  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 1  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 2  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 3  Мясо охлажденное и свежемороженое~Говядина~Гов...
# 4  Мясо охлажденное и свежемороженое~Свинина~Свин...
#
#                                             Описание  Цена
# 0  Шаг заказа 1кг. Итоговый вес и сумма может нез...   445
# 1  \nЦена указана за 2кг. Вес может незначительно...   515
# 2  \nЦена за упаковку указана с учетом веса фасов...   172
# 3  \nШаг заказа указан с учетом вес одного языка ...   630
# 4  \nЦена за 1 кг. Итоговый вес и сумма могут нез...   424

# %%
def process_abrikos(text, ind=0):
    slots.update([s.split(' ')[0] for s in text.strip().lower().split('~')[0:3]])
    return text

data['Название'].apply(process_abrikos)
slots
# Out:
# {'',
#  'humphreys',
#  'general mills',
#  'йогурты',
#  'осетрина',
#  'seagate',
#  'пакеты',
#  'bio kleen',
#  'кисель',
#  'горошек',
#  'health direct',
#  'indigo wild',
#  'three lollies',
#  'сыр',
#  'микроэлементы',
#  "heather's tummy care",
#  'клубника/земляника',
#  'ancient harvest',
#  'травы и гомеопатия',
#  'real salt',
#  'kal',
#  'teras whey',
#  'каши',
#  'мака',
#  'сардина',
#  'jason natural',
#  'blistex',
#  'варенье',
#  'карбонад',
#  'протеин казеиновый',
#  'пропитка',
#  'eclectic institute',
#  'eating evolved',
#  'смесь',
#  'утка',
#  'геркулес',
#  'gonesh',
#  'хлопушка',
#  'mri',
#  'цен',
#  'babyganics',
#  'coromega',
#  'laird superfood',
#  'улучшитель',
#  'снотворные',
#  'санитайзер',
#  'кейс',
#  'сиропы',
#  'swisse',
#  'инжир',
#  'блины',
#  'usn',
#  'шейка',
#  'грудинка',
#  'джем',
#  'weetabix',
#  'спортивное питание',
#  'консервация',
#  'biobag',
#  'пленка,',
#  'аппетитная курочка',
#  'stoneridge orchards',
#  'oakmont labs',
#  'бургеры',
#  'хинкали',
#  'minami nutrition',
#  'femme',
#  'быстрое',
#  'macrolife naturals',
#  'food should taste good',
#  'bionaturae',
#  'queen helene',
#  'seventh generation',
#  'neosporin',
#  'суши лосось',
#  'twinlab',
#  'тоник',
#  'essential living foods',
#  'miracle noodle',
#  'груши',
#  'вафли',
#  'l-карнитин',
#  'deva',
#  'мандарины',
#  'эмульсор',
#  'motherlove',
#  'musclemeds',
#  'мельницы',
#  'gaia herbs',
#  'грим',
#  'рагу',
#  'kava king products inc',
#  'карандаши',
#  'пилинг-гель',
#  'health warrior, inc.',
#  'зубная',
#  'персики',
#  'brothers-all-natural',
#  'тесто',
#  'organic traditions',
#  'рейши',
#  'курага',
#  'dynamic health',
#  'крекеры',
#  'курица',
#  'элементы',
#  'раки',
#  'одноразовая',
#  'funfresh foods',
#  'напитки',
#  'маргарин',
#  'начинка',
#  'peakfresh usa',
#  'туалетный',
#  'грибное',
#  'суп и бульон',
#  'aquaphor',
#  'мякоть',
#  "charlie's soap, inc.",
#  'аджика',
#  'ooh snap!',
#  'бузина',
#  'гренки чесночные',
#  'hollywood diet',
#  'twist',
#  'shea baby',
#  'plum organics',
#  'препараты для жкт',
#  'fungi perfecti',
#  'natierra',
#  'yerba prima',
#  'сушка',
#  "nature's answer",
#  'патиссоны',
#  'растяжка',
#  'перец',
#  'tpcs',
#  'гель',
#  'шампиньоны',
#  'ascenta',
#  'vitafusion',
#  'грибы',
#  'брезаола',
#  'гарциния камбоджийская',
#  'ангус',
#  'уход за полостью рта',
#  'форма',
#  'креатин, спорт',
#  'семя',
#  'wisdom natural',
#  'baby banana',
#  'восточные',
#  'бекон',
#  'rich яблоко',
#  "michelle's miracle",
#  'grab green',
#  'абрикосы',
#  'шпек',
#  'палтус',
#  'i and love and you',
#  'bluebonnet nutrition',
#  'traditional medicinals',
#  'фрикадельки',
#  'какао-порошок',
#  'holistic blend',
#  'bass brushes',
#  'салат',
#  'sunshine',
#  'сахар,',
#  'sparta nutrition',
#  'клетчатка',
#  'almondina',
#  'source naturals',
#  'прокладки',
#  'овощная',
#  'beyond fresh',
#  'завтраки',
#  'sibu beauty',
#  'align',
#  'rapunzel',
#  'cменные',
#  'bar keepers friend',
#  'гели',
#  'творог',
#  'заправка',
#  'пищевые добавки',
#  'хурма',
#  'тархун',
#  'health thru nutrition',
#  'карамель',
#  'nasopure',
#  'nugo nutrition',
#  'art naturals',
#  'pure protein',
#  'zand',
#  "nature's herbs",
#  'real purity',
#  'life-flo',
#  'balance bar',
#  'пробиотики',
#  'reserveage nutrition',
#  'thorne research',
#  'oregons wild harvest',
#  'крабовое',
#  'avalon organics',
#  'the first years',
#  'хрен',
#  'сухофрукты',
#  'каму-каму',
#  'ast sports science',
#  'bio-kult',
#  'ridgecrest herbals',
#  'макаронные',
#  'c.c. pollen',
#  'уход за питомцами',
#  'вегетарианская (new)',
#  'airborne',
#  'актив-скраб',
#  'coral llc',
#  'quest nutrition',
#  'rich вишня',
#  'морской',
#  'мыло',
#  'country archer jerky',
#  'домашний лимонад',
#  'naturanectar',
#  'solaray',
#  'seapoint farms',
#  'crystal star',
#  'здоровые',
#  'зефир',
#  'emergen-c',
#  'косметические',
#  'bodylogix',
#  'healthy times',
#  'лимонный',
#  'bioray inc.',
#  'чистящие',
#  'энергетические',
#  'sky organics',
#  'сыворотка',
#  'the face shop',
#  'джем,',
#  'греческий салат',
#  'summer infant',
#  'мицеллярная',
#  'real health',
#  'veggie wash',
#  'оладьи',
#  'сардельки',
#  'creative bioscience',
#  'musclepharm natural',
#  'добавка',
#  'редис',
#  'творожный',
#  'натуральная',
#  'суши капеллана масаго',
#  'сосиски',
#  'хлебцы',
#  'сухие',
#  'сет № 2',
#  'weleda',
#  'черева',
#  'печенье',
#  'пюре',
#  'формулы с оксидом азота',
#  'куриные',
#  'daily wellness company',
#  'hobe labs',
#  'сывороточный белок',
#  'уксус',
#  'master supplements',
#  'салюты',
#  'свежие',
#  'garden of life',
#  'хлебобулочные',
#  'mamma chia',
#  'flower essence services',
#  'кокосовый сахар',
#  'dr. dunner, usa',
#  'сахар',
#  'зелень',
#  'грибные смеси',
#  'imperial elixir',
#  'крупы,',
#  'куриные крылья барбекю',
#  'пралине',
#  'nuby',
#  "barry's tea",
#  'allmax nutrition',
#  'мастика\xa0«домашняя',
#  'водоросли',
#  'апельсиновые',
#  'natrol',
#  'huy fong foods inc.',
#  'суши спайс лосось',
#  'nutrabio labs',
#  'ассорти',
#  'хотстеры',
#  'ежедневные',
#  'greens plus',
#  'premama',
#  'morningstar minerals',
#  'маслины',
#  'dream water',
#  'закуска',
#  'mushroom wisdom',
#  'johnson & johnson',
#  'sovereign silver',
#  'грейпфрутовые',
#  'natural factors',
#  'подсолнечное',
#  'сервелат',
#  "doctor's best",
#  'изюм',
#  'willard',
#  'белизна',
#  'осьминоги',
#  'кленовый',
#  'детский',
#  'animal essentials',
#  'хлеб,',
#  'growing naturals',
#  'специи',
#  'controlled labs',
#  'ultra enterprises',
#  'мед-суфле',
#  'манка',
#  'лососевое масло',
#  'бытовая',
#  'компот',
#  'olympian labs inc.',
#  'gaea',
#  'сгущенка',
#  'well wisdom',
#  'body gold',
#  'cascadian farm',
#  'ракушки',
#  'масла,',
#  'гейнеры',
#  'quality of life labs',
#  'wild planet',
#  'cetaphil',
#  'nature republic',
#  'twinings',
#  'кулинарные',
#  'джемы,',
#  'азиатская',
#  'the seaweed bath co.',
#  'madre labs',
#  'honey gardens',
#  'сельдь',
#  'батончик',
#  'говядина',
#  'хозяйственные',
#  'оливковое',
#  'четыре сыра',
#  'фруктовые',
#  'кукуруза',
#  'healthy origins',
#  "nature's life",
#  'сет с угрем',
#  'пельмени',
#  'чесночная',
#  'rxbar',
#  'mrs. meyers clean day',
#  'mestemacher',
#  'co - e1',
#  'aurora nutrascience',
#  'aleva naturals',
#  'супер',
#  'phillips',
#  'glorybee',
#  'mrm',
#  'виноградные',
#  'соль',
#  'real aloe inc.',
#  'бумага',
#  'the honest kitchen',
#  'darford',
#  'кешью',
#  'холодный',
#  'огурцы',
#  'ayr',
#  'шоколадные',
#  'мужская',
#  'efx sports',
#  'тарелки',
#  'buckley',
#  'наполнитель',
#  'шоколад',
#  'vital earth minerals',
#  'мыло-уход',
#  'питательный',
#  'coconut secret',
#  'sports research',
#  'ризотто',
#  'wholesome sweeteners',
#  'борщ',
#  'sunwarrior',
#  'тертое какао',
#  'универсальные',
#  'pure planet',
#  'doggie sudz',
#  'кофе,',
#  'ecobags',
#  'решетка',
#  'reaal',
#  'заменители пищи',
#  'the ginger people',
#  'удон с говядиной ньюпай',
#  'owyn',
#  'полутвердые',
#  'антиперспирант',
#  'laneige',
#  'капуста',
#  'соки,',
#  'морковь',
#  'cat-man-doo',
#  'st. dalfour',
#  'kevala',
#  'лампы',
#  'с8',
#  'gat',
#  'sage spirit',
#  'повидло',
#  'natracare',
#  'суши угорь',
#  'margarite cosmetics',
#  'орехи и семена',
#  'уход за телом',
#  'отруби',
#  'kikkoman',
#  'vibrant health',
#  'шелковица',
#  'васаби',
#  "snyder's",
#  'малина',
#  'planetary herbals',
#  'tierra mia organics',
#  'сметана',
#  'country life',
#  'amazing grass',
#  'kettle foods',
#  'десерт',
#  'кетчупы,',
#  'фантазия',
#  'удон со свининой ньюпай',
#  'станок',
#  'almased usa',
#  'нежный',
#  'kind bars',
#  "nature's path",
#  'стакан',
#  'health plus inc.',
#  'ложка',
#  'wilderness poets llc',
#  'корица',
#  'стайлинг-пудра',
#  'novex biotech',
#  'smartypants',
#  'band aid',
#  'a.c. grace company',
#  "nature's wild organic",
#  'organic valley',
#  'фисташки',
#  'смузи',
#  'meyenberg goat milk',
#  'dukan diet',
#  'тунец',
#  'cerave',
#  'коктейль',
#  'крупы',
#  'щавель',
#  'world organic',
#  'hurraw!',
#  'sundown naturals',
#  'earthtone foods',
#  'y.s. eco bee farms',
#  'чай маття',
#  'женские мультивитамины',
#  'pronatura',
#  'гречневый',
#  'genexa llc',
#  'морепродукты',
#  'bionorica',
#  'abkit',
#  'напиток',
#  'цитрусовые',
#  'kericure',
#  'vitanica',
#  'ecodiscoveries',
#  'seasnax',
#  'мюсли',
#  'bio tech pharmacal, inc',
#  'carrington farms',
#  'health from the sun',
#  'венецианская',
#  'азу',
#  'met-rx',
#  "dr. brown's",
#  'everyday coconut',
#  'разрыхлитель',
#  'сет с лососем',
#  'кетчуп,',
#  'nutricology',
#  'початки',
#  'стаканы',
#  'ананасовые',
#  'manuka health',
#  'сыры',
#  'кефир',
#  'allergy research group',
#  'марципан',
#  'циновка',
#  'designer protein',
#  'ip-6 international',
#  'злаковый',
#  'one-a-day',
#  'mild by nature',
#  'сет',
#  "nature's gate",
#  "earth's care",
#  'яичная',
#  'мука',
#  'big tree farms',
#  'здоровье детей',
#  'цикорий',
#  'для',
#  'выпечка',
#  'пробиотики для детей',
#  'sonne’s organic foods',
#  'redd remedies',
#  "o'donnell formulas",
#  'морс облепиховый',
#  'naturade',
#  "hyland's",
#  'earth mama',
#  'beco pets',
#  'rishi tea',
#  'том ям',
#  'go raw',
#  'alvera',
#  'кальмары',
#  'моющее',
#  'кальций',
#  'terrasoul superfoods',
#  "o'keeffe's",
#  'рататуй',
#  'чеснок',
#  'umac-core',
#  'wellgenix',
#  'kabrita',
#  'irwin naturals',
#  'зефир,',
#  'gostak',
#  'птица',
#  'чай,',
#  'спрей',
#  'novaforme',
#  'подвеска',
#  'рыбий жир омега-3',
#  'кости и суставы',
#  'крекер',
#  'гель-скраб-маска',
#  'natural balance',
#  'финики',
#  'bioglan',
#  'гребешок',
#  "men's health",
#  'pb2 foods',
#  'американская классика',
#  'форель',
#  'гречка',
#  'коэнзим q10 (coq10)',
#  'bioadvantex pharma',
#  'аминокислоты',
#  'замороженные',
#  'afterspa',
#  'ягоды',
#  'кока-кола',
#  'wobenzym n',
#  'absorbaid',
#  'cat dancer',
#  'leven rose',
#  'ополаскиватель',
#  'homeolab usa',
#  'бутылки, шейкеры и вода',
#  'ark naturals',
#  'boogie wipes',
#  'сайра',
#  'крыло',
#  'mason natural',
#  'бакалейные товары',
#  'natural sport',
#  'юниклин',
#  'шницель',
#  'полумаска',
#  '4th & heart',
#  'olbas therapeutic',
#  'tazo teas',
#  'набор',
#  "annie's homegrown",
#  'dapple',
#  'торты',
#  'actipet',
#  'ватные',
#  'салфетки',
#  'clear products',
#  'healthforce superfoods',
#  'конфеты',
#  'scivation',
#  'освежители',
#  'квас',
#  'вода',
#  'молочко',
#  'аль тоне тунец',
#  'sinol',
#  'stridex',
#  'triple leaf tea',
#  'castor & pollux',
#  'мелатонин',
#  'приправа',
#  'relacore',
#  'purely inspired',
#  'горбуша',
#  'plantfusion',
#  'валован',
#  'nutrex hawaii',
#  'labrada nutrition',
#  'смеси аминокислот',
#  'фарш',
#  'экзотические',
#  'iherb goods',
#  'зубочистки',
#  'протеиновые смеси',
#  'manuka doctor',
#  'витамин с',
#  'visine',
#  'котлеты',
#  'jarrow formulas',
#  'творожное',
#  'с1',
#  'манго',
#  'smith & vandiver',
#  'ассорти острая',
#  'celestial seasonings',
#  'фольга',
#  'rhythm superfoods',
#  'fire cider',
#  'физалис',
#  'уход за волосами',
#  'the dirt',
#  'culturelle',
#  'divine health',
#  'туалетная',
#  'coca-cola',
#  'топпинги',
#  'sejoyia',
#  'масла',
#  'hydroxycut',
#  'six star',
#  'колбаски',
#  'килька',
#  'маца',
#  'сливки',
#  'safari',
#  'mill creek botanicals',
#  "dr. harvey's",
#  'домашняя утварь',
#  'liverite',
#  'greens first',
#  'красота',
#  'modern products',
#  'кэроб',
#  'finn crisp',
#  'herbion',
#  'орех',
#  'ночной',
#  'coca cola zero',
#  'маринара италиано',
#  'шампуноь',
#  'andean dream',
#  'edward & sons',
#  'la tourangelle',
#  'хлопья',
#  'макароны',
#  'pines international',
#  'sahale snacks',
#  'naturally vitamins',
#  'шалфей',
#  'мисо суп классический',
#  'evolution of smooth',
#  'rapidfire',
#  "wally's natural",
#  'баранина',
#  'better life',
#  'протеиновые батончики',
#  'кордон',
#  'толокно',
#  'детское',
#  'bio-oil',
#  'травы и специи',
#  'tea tree therapy',
#  'hyperbiotics',
#  'back to nature',
#  'hello',
#  'асаи',
#  'картофель фри',
#  'nescafé',
#  'нектар',
#  'boiron, single remedies',
#  'цезарь',
#  'herbs etc.',
#  'свинина',
#  'фрукты и овощи',
#  'средство',
#  'yumearth',
#  'nootie',
#  'furious formulations',
#  "honey i'm home",
#  'шпинат',
#  'специи,',
#  'кокосовая',
#  'citrus magic',
#  'картофель по-деревенски',
#  'kaged muscle',
#  'arthur andrew medical',
#  'детская',
#  'тампоны',
#  'сет на одного',
#  'соевые',
#  'zint',
#  'kelapo',
#  'squip',
#  'бразильский',
#  'диетические',
#  'everyday shea',
#  'севрюга',
#  'radius',
#  'onnit',
#  'ананасы',
#  'enjoy life foods',
#  'now foods',
#  'капучино',
#  'премиальный',
#  'батарея',
#  'all one, nutritech',
#  'лимонад',
#  'brainstrong',
#  "bob's red mill",
#  'для мытья посуды',
#  'happy family organics',
#  'касcеты',
#  'out of africa',
#  'himalaya',
#  'stash tea',
#  'чистящее',
#  'персиковые',
#  'alta health',
#  'grape seed extract',
#  'бумажные',
#  'heritage store',
#  'american biotech labs',
#  'крылышки',
#  'суп',
#  'pure vegan',
#  'яблоки',
#  'greensations',
#  'утиная',
#  'hi tech pharmaceuticals',
#  'миланская',
#  'сырные ломтики',
#  'allvia',
#  'body fortress',
#  'желатин',
#  'диски',
#  'бельмеши',
#  'цветная',
#  'rainbow research',
#  'mount hagen',
#  'pet naturals of vermont',
#  'teeccino',
#  'vegansmart',
#  'жюльен',
#  'чипсы,',
#  'royal tropics',
#  'frownies',
#  'simply organic',
#  'паста',
#  'garden greens',
#  'рис',
#  'complimed',
#  'fidobiotics',
#  'соусы,',
#  "naturally it's clean",
#  'подушечки',
#  'сельдерей',
#  'everyone',
#  'селен',
#  'rejuvicare',
#  'чизбургер',
#  'paradise herbs',
#  'sun chlorella',
#  'biogaia',
#  'гастрономия',
#  'living clay',
#  'honees',
#  'фасоль',
#  'чечевица',
#  'dickinson brands',
#  'пироги',
#  'schiff',
#  'vital planet',
#  'орехи,',
#  'yum-vs',
#  'колбаса',
#  'тестостерон',
#  'tony moly',
#  'лук',
#  'паштет',
#  'futurebiotics',
#  'qunol',
#  'aroma naturals',
#  'мыло-крем',
#  'natrabio',
#  'цинк',
#  'яйцо',
#  'безглютеновые',
#  'neutrogena',
#  'антиоксиданты',
#  'нож',
#  "mommy's bliss",
#  'шапмунь',
#  'эссенция',
#  'equal exchange',
#  'печь-буржуйка',
#  'peanut butter & co.',
#  "nature's way",
#  'puppy cake',
#  'кальмар',
#  'рыбные',
#  'nuk',
#  'магний',
#  'томаты',
#  'витамины',
#  'горчица',
#  'organix south',
#  'maximum international',
#  'celtic sea salt',
#  'missha',
#  'электротовары',
#  'primaforce',
#  'ведро',
#  'prince of peace',
#  'свеча',
#  'посыпка',
#  'kyolic',
#  'мужские мультивитамины',
#  'sprout living',
#  'кусочки',
#  'bragg',
#  'основа',
#  'компотная',
#  'леденцы',
#  'овсяные',
#  'advanced clinicals',
#  'анчоус',
#  'проверочный',
#  'дезодорант-антиперспирант',
#  'nutramax',
#  'куриные крылья баффало',
#  'горох',
#  'фундучная',
#  'homeopet',
#  'увлажняющий',
#  'acure',
#  "l'il critters",
#  "otto's naturals",
#  'california natural',
#  'alkazone',
#  'fifty 50',
#  'детям',
#  'g.h. cretors',
#  'готовый',
#  'torie & howard',
#  'youtheory',
#  'очищающий',
#  'черника',
#  'ежедневный',
#  'черный тмин',
#  'кабачки',
#  'петрушка',
#  'made in nature',
#  'галстук',
#  'диета и контроль веса',
#  "nature's plus",
#  'vital proteins',
#  'картофельное',
#  "earth's best",
#  'mediheal',
#  'хрен,',
#  'orgain',
#  'e.l.f. cosmetics',
#  'консервы',
#  'стеклоомывающая',
#  'арахис',
#  'l-цитруллин',
#  'dr. woods',
#  'сетевой',
#  'nu-pore',
#  'apex',
#  'батареи',
#  'свекла',
#  'earth balance',
#  'индейка',
#  'маргарита',
#  'оливки',
#  'nunaturals',
#  'креветки',
#  'мята',
#  'бастурма',
#  'семга',
#  'king arthur flour',
#  'стимуляторы',
#  'предстательная железа',
#  'flapjacked',
#  'маска',
#  'valor',
#  'badger company',
#  'твердые',
#  'пена',
#  'пряник',
#  'сода',
#  'ecover',
#  'yeouth',
#  'sprout organic',
#  'indiumease',
#  'пряники',
#  'g9skin',
#  'prelief',
#  'desitin',
#  'перепел',
#  'батончики',
#  'swerve',
#  'сок',
#  'vetri-science',
#  'appliednutrition',
#  'estroven',
#  'маршмеллоу',
#  'sunfood',
#  'san nutrition',
#  'derma e',
#  'the natural dentist',
#  'крупа',
#  'lifetime vitamins',
#  'хумус',
#  'отдельные масла',
#  'metabolic maintenance',
#  'andalou naturals',
#  'пшено',
#  'окорок',
#  'чабрец',
#  'optimox corporation',
#  'продукты',
#  'крахмал-спрей',
#  'булочка',
#  'куркума и куркумин',
#  'zollipops',
#  "nature's best, isopure",
#  'улитки',
#  'rawfusion',
#  'ряженка',
#  'черешня',
#  'гинкго билоба',
#  'flintstones',
#  'питомцы',
#  'lifeseasons',
#  'earth rated',
#  'крем-гель',
#  'яблочный уксус',
#  'redcon1',
#  'вишня',
#  'аксессуары',
#  'organyc',
#  'сладости',
#  'cмесь',
#  'хрустящее',
#  'universal nutrition',
#  'grenade',
#  'nurturme',
#  'cocomels',
#  'пренатальные витамины',
#  'leaders',
#  'отбеливатель',
#  'каперсы',
#  'верона',
#  'скраб',
#  'глазурь',
#  'торты,',
#  ...}

# %%
end_slots = set()
end_slots = [slot.replace('"','').replace(',','') for slot in slots]

# %%
end_slots
# Out:
# ['',
#  'humphreys',
#  'general mills',
#  'йогурты',
#  'осетрина',
#  'seagate',
#  'пакеты',
#  'bio kleen',
#  'кисель',
#  'горошек',
#  'health direct',
#  'indigo wild',
#  'three lollies',
#  'сыр',
#  'микроэлементы',
#  "heather's tummy care",
#  'клубника/земляника',
#  'ancient harvest',
#  'травы и гомеопатия',
#  'real salt',
#  'kal',
#  'teras whey',
#  'каши',
#  'мака',
#  'сардина',
#  'jason natural',
#  'blistex',
#  'варенье',
#  'карбонад',
#  'протеин казеиновый',
#  'пропитка',
#  'eclectic institute',
#  'eating evolved',
#  'смесь',
#  'утка',
#  'геркулес',
#  'gonesh',
#  'хлопушка',
#  'mri',
#  'цен',
#  'babyganics',
#  'coromega',
#  'laird superfood',
#  'улучшитель',
#  'снотворные',
#  'санитайзер',
#  'кейс',
#  'сиропы',
#  'swisse',
#  'инжир',
#  'блины',
#  'usn',
#  'шейка',
#  'грудинка',
#  'джем',
#  'weetabix',
#  'спортивное питание',
#  'консервация',
#  'biobag',
#  'пленка',
#  'аппетитная курочка',
#  'stoneridge orchards',
#  'oakmont labs',
#  'бургеры',
#  'хинкали',
#  'minami nutrition',
#  'femme',
#  'быстрое',
#  'macrolife naturals',
#  'food should taste good',
#  'bionaturae',
#  'queen helene',
#  'seventh generation',
#  'neosporin',
#  'суши лосось',
#  'twinlab',
#  'тоник',
#  'essential living foods',
#  'miracle noodle',
#  'груши',
#  'вафли',
#  'l-карнитин',
#  'deva',
#  'мандарины',
#  'эмульсор',
#  'motherlove',
#  'musclemeds',
#  'мельницы',
#  'gaia herbs',
#  'грим',
#  'рагу',
#  'kava king products inc',
#  'карандаши',
#  'пилинг-гель',
#  'health warrior inc.',
#  'зубная',
#  'персики',
#  'brothers-all-natural',
#  'тесто',
#  'organic traditions',
#  'рейши',
#  'курага',
#  'dynamic health',
#  'крекеры',
#  'курица',
#  'элементы',
#  'раки',
#  'одноразовая',
#  'funfresh foods',
#  'напитки',
#  'маргарин',
#  'начинка',
#  'peakfresh usa',
#  'туалетный',
#  'грибное',
#  'суп и бульон',
#  'aquaphor',
#  'мякоть',
#  "charlie's soap inc.",
#  'аджика',
#  'ooh snap!',
#  'бузина',
#  'гренки чесночные',
#  'hollywood diet',
#  'twist',
#  'shea baby',
#  'plum organics',
#  'препараты для жкт',
#  'fungi perfecti',
#  'natierra',
#  'yerba prima',
#  'сушка',
#  "nature's answer",
#  'патиссоны',
#  'растяжка',
#  'перец',
#  'tpcs',
#  'гель',
#  'шампиньоны',
#  'ascenta',
#  'vitafusion',
#  'грибы',
#  'брезаола',
#  'гарциния камбоджийская',
#  'ангус',
#  'уход за полостью рта',
#  'форма',
#  'креатин спорт',
#  'семя',
#  'wisdom natural',
#  'baby banana',
#  'восточные',
#  'бекон',
#  'rich яблоко',
#  "michelle's miracle",
#  'grab green',
#  'абрикосы',
#  'шпек',
#  'палтус',
#  'i and love and you',
#  'bluebonnet nutrition',
#  'traditional medicinals',
#  'фрикадельки',
#  'какао-порошок',
#  'holistic blend',
#  'bass brushes',
#  'салат',
#  'sunshine',
#  'сахар',
#  'sparta nutrition',
#  'клетчатка',
#  'almondina',
#  'source naturals',
#  'прокладки',
#  'овощная',
#  'beyond fresh',
#  'завтраки',
#  'sibu beauty',
#  'align',
#  'rapunzel',
#  'cменные',
#  'bar keepers friend',
#  'гели',
#  'творог',
#  'заправка',
#  'пищевые добавки',
#  'хурма',
#  'тархун',
#  'health thru nutrition',
#  'карамель',
#  'nasopure',
#  'nugo nutrition',
#  'art naturals',
#  'pure protein',
#  'zand',
#  "nature's herbs",
#  'real purity',
#  'life-flo',
#  'balance bar',
#  'пробиотики',
#  'reserveage nutrition',
#  'thorne research',
#  'oregons wild harvest',
#  'крабовое',
#  'avalon organics',
#  'the first years',
#  'хрен',
#  'сухофрукты',
#  'каму-каму',
#  'ast sports science',
#  'bio-kult',
#  'ridgecrest herbals',
#  'макаронные',
#  'c.c. pollen',
#  'уход за питомцами',
#  'вегетарианская (new)',
#  'airborne',
#  'актив-скраб',
#  'coral llc',
#  'quest nutrition',
#  'rich вишня',
#  'морской',
#  'мыло',
#  'country archer jerky',
#  'домашний лимонад',
#  'naturanectar',
#  'solaray',
#  'seapoint farms',
#  'crystal star',
#  'здоровые',
#  'зефир',
#  'emergen-c',
#  'косметические',
#  'bodylogix',
#  'healthy times',
#  'лимонный',
#  'bioray inc.',
#  'чистящие',
#  'энергетические',
#  'sky organics',
#  'сыворотка',
#  'the face shop',
#  'джем',
#  'греческий салат',
#  'summer infant',
#  'мицеллярная',
#  'real health',
#  'veggie wash',
#  'оладьи',
#  'сардельки',
#  'creative bioscience',
#  'musclepharm natural',
#  'добавка',
#  'редис',
#  'творожный',
#  'натуральная',
#  'суши капеллана масаго',
#  'сосиски',
#  'хлебцы',
#  'сухие',
#  'сет № 2',
#  'weleda',
#  'черева',
#  'печенье',
#  'пюре',
#  'формулы с оксидом азота',
#  'куриные',
#  'daily wellness company',
#  'hobe labs',
#  'сывороточный белок',
#  'уксус',
#  'master supplements',
#  'салюты',
#  'свежие',
#  'garden of life',
#  'хлебобулочные',
#  'mamma chia',
#  'flower essence services',
#  'кокосовый сахар',
#  'dr. dunner usa',
#  'сахар',
#  'зелень',
#  'грибные смеси',
#  'imperial elixir',
#  'крупы',
#  'куриные крылья барбекю',
#  'пралине',
#  'nuby',
#  "barry's tea",
#  'allmax nutrition',
#  'мастика\xa0«домашняя',
#  'водоросли',
#  'апельсиновые',
#  'natrol',
#  'huy fong foods inc.',
#  'суши спайс лосось',
#  'nutrabio labs',
#  'ассорти',
#  'хотстеры',
#  'ежедневные',
#  'greens plus',
#  'premama',
#  'morningstar minerals',
#  'маслины',
#  'dream water',
#  'закуска',
#  'mushroom wisdom',
#  'johnson & johnson',
#  'sovereign silver',
#  'грейпфрутовые',
#  'natural factors',
#  'подсолнечное',
#  'сервелат',
#  "doctor's best",
#  'изюм',
#  'willard',
#  'белизна',
#  'осьминоги',
#  'кленовый',
#  'детский',
#  'animal essentials',
#  'хлеб',
#  'growing naturals',
#  'специи',
#  'controlled labs',
#  'ultra enterprises',
#  'мед-суфле',
#  'манка',
#  'лососевое масло',
#  'бытовая',
#  'компот',
#  'olympian labs inc.',
#  'gaea',
#  'сгущенка',
#  'well wisdom',
#  'body gold',
#  'cascadian farm',
#  'ракушки',
#  'масла',
#  'гейнеры',
#  'quality of life labs',
#  'wild planet',
#  'cetaphil',
#  'nature republic',
#  'twinings',
#  'кулинарные',
#  'джемы',
#  'азиатская',
#  'the seaweed bath co.',
#  'madre labs',
#  'honey gardens',
#  'сельдь',
#  'батончик',
#  'говядина',
#  'хозяйственные',
#  'оливковое',
#  'четыре сыра',
#  'фруктовые',
#  'кукуруза',
#  'healthy origins',
#  "nature's life",
#  'сет с угрем',
#  'пельмени',
#  'чесночная',
#  'rxbar',
#  'mrs. meyers clean day',
#  'mestemacher',
#  'co - e1',
#  'aurora nutrascience',
#  'aleva naturals',
#  'супер',
#  'phillips',
#  'glorybee',
#  'mrm',
#  'виноградные',
#  'соль',
#  'real aloe inc.',
#  'бумага',
#  'the honest kitchen',
#  'darford',
#  'кешью',
#  'холодный',
#  'огурцы',
#  'ayr',
#  'шоколадные',
#  'мужская',
#  'efx sports',
#  'тарелки',
#  'buckley',
#  'наполнитель',
#  'шоколад',
#  'vital earth minerals',
#  'мыло-уход',
#  'питательный',
#  'coconut secret',
#  'sports research',
#  'ризотто',
#  'wholesome sweeteners',
#  'борщ',
#  'sunwarrior',
#  'тертое какао',
#  'универсальные',
#  'pure planet',
#  'doggie sudz',
#  'кофе',
#  'ecobags',
#  'решетка',
#  'reaal',
#  'заменители пищи',
#  'the ginger people',
#  'удон с говядиной ньюпай',
#  'owyn',
#  'полутвердые',
#  'антиперспирант',
#  'laneige',
#  'капуста',
#  'соки',
#  'морковь',
#  'cat-man-doo',
#  'st. dalfour',
#  'kevala',
#  'лампы',
#  'с8',
#  'gat',
#  'sage spirit',
#  'повидло',
#  'natracare',
#  'суши угорь',
#  'margarite cosmetics',
#  'орехи и семена',
#  'уход за телом',
#  'отруби',
#  'kikkoman',
#  'vibrant health',
#  'шелковица',
#  'васаби',
#  "snyder's",
#  'малина',
#  'planetary herbals',
#  'tierra mia organics',
#  'сметана',
#  'country life',
#  'amazing grass',
#  'kettle foods',
#  'десерт',
#  'кетчупы',
#  'фантазия',
#  'удон со свининой ньюпай',
#  'станок',
#  'almased usa',
#  'нежный',
#  'kind bars',
#  "nature's path",
#  'стакан',
#  'health plus inc.',
#  'ложка',
#  'wilderness poets llc',
#  'корица',
#  'стайлинг-пудра',
#  'novex biotech',
#  'smartypants',
#  'band aid',
#  'a.c. grace company',
#  "nature's wild organic",
#  'organic valley',
#  'фисташки',
#  'смузи',
#  'meyenberg goat milk',
#  'dukan diet',
#  'тунец',
#  'cerave',
#  'коктейль',
#  'крупы',
#  'щавель',
#  'world organic',
#  'hurraw!',
#  'sundown naturals',
#  'earthtone foods',
#  'y.s. eco bee farms',
#  'чай маття',
#  'женские мультивитамины',
#  'pronatura',
#  'гречневый',
#  'genexa llc',
#  'морепродукты',
#  'bionorica',
#  'abkit',
#  'напиток',
#  'цитрусовые',
#  'kericure',
#  'vitanica',
#  'ecodiscoveries',
#  'seasnax',
#  'мюсли',
#  'bio tech pharmacal inc',
#  'carrington farms',
#  'health from the sun',
#  'венецианская',
#  'азу',
#  'met-rx',
#  "dr. brown's",
#  'everyday coconut',
#  'разрыхлитель',
#  'сет с лососем',
#  'кетчуп',
#  'nutricology',
#  'початки',
#  'стаканы',
#  'ананасовые',
#  'manuka health',
#  'сыры',
#  'кефир',
#  'allergy research group',
#  'марципан',
#  'циновка',
#  'designer protein',
#  'ip-6 international',
#  'злаковый',
#  'one-a-day',
#  'mild by nature',
#  'сет',
#  "nature's gate",
#  "earth's care",
#  'яичная',
#  'мука',
#  'big tree farms',
#  'здоровье детей',
#  'цикорий',
#  'для',
#  'выпечка',
#  'пробиотики для детей',
#  'sonne’s organic foods',
#  'redd remedies',
#  "o'donnell formulas",
#  'морс облепиховый',
#  'naturade',
#  "hyland's",
#  'earth mama',
#  'beco pets',
#  'rishi tea',
#  'том ям',
#  'go raw',
#  'alvera',
#  'кальмары',
#  'моющее',
#  'кальций',
#  'terrasoul superfoods',
#  "o'keeffe's",
#  'рататуй',
#  'чеснок',
#  'umac-core',
#  'wellgenix',
#  'kabrita',
#  'irwin naturals',
#  'зефир',
#  'gostak',
#  'птица',
#  'чай',
#  'спрей',
#  'novaforme',
#  'подвеска',
#  'рыбий жир омега-3',
#  'кости и суставы',
#  'крекер',
#  'гель-скраб-маска',
#  'natural balance',
#  'финики',
#  'bioglan',
#  'гребешок',
#  "men's health",
#  'pb2 foods',
#  'американская классика',
#  'форель',
#  'гречка',
#  'коэнзим q10 (coq10)',
#  'bioadvantex pharma',
#  'аминокислоты',
#  'замороженные',
#  'afterspa',
#  'ягоды',
#  'кока-кола',
#  'wobenzym n',
#  'absorbaid',
#  'cat dancer',
#  'leven rose',
#  'ополаскиватель',
#  'homeolab usa',
#  'бутылки шейкеры и вода',
#  'ark naturals',
#  'boogie wipes',
#  'сайра',
#  'крыло',
#  'mason natural',
#  'бакалейные товары',
#  'natural sport',
#  'юниклин',
#  'шницель',
#  'полумаска',
#  '4th & heart',
#  'olbas therapeutic',
#  'tazo teas',
#  'набор',
#  "annie's homegrown",
#  'dapple',
#  'торты',
#  'actipet',
#  'ватные',
#  'салфетки',
#  'clear products',
#  'healthforce superfoods',
#  'конфеты',
#  'scivation',
#  'освежители',
#  'квас',
#  'вода',
#  'молочко',
#  'аль тоне тунец',
#  'sinol',
#  'stridex',
#  'triple leaf tea',
#  'castor & pollux',
#  'мелатонин',
#  'приправа',
#  'relacore',
#  'purely inspired',
#  'горбуша',
#  'plantfusion',
#  'валован',
#  'nutrex hawaii',
#  'labrada nutrition',
#  'смеси аминокислот',
#  'фарш',
#  'экзотические',
#  'iherb goods',
#  'зубочистки',
#  'протеиновые смеси',
#  'manuka doctor',
#  'витамин с',
#  'visine',
#  'котлеты',
#  'jarrow formulas',
#  'творожное',
#  'с1',
#  'манго',
#  'smith & vandiver',
#  'ассорти острая',
#  'celestial seasonings',
#  'фольга',
#  'rhythm superfoods',
#  'fire cider',
#  'физалис',
#  'уход за волосами',
#  'the dirt',
#  'culturelle',
#  'divine health',
#  'туалетная',
#  'coca-cola',
#  'топпинги',
#  'sejoyia',
#  'масла',
#  'hydroxycut',
#  'six star',
#  'колбаски',
#  'килька',
#  'маца',
#  'сливки',
#  'safari',
#  'mill creek botanicals',
#  "dr. harvey's",
#  'домашняя утварь',
#  'liverite',
#  'greens first',
#  'красота',
#  'modern products',
#  'кэроб',
#  'finn crisp',
#  'herbion',
#  'орех',
#  'ночной',
#  'coca cola zero',
#  'маринара италиано',
#  'шампуноь',
#  'andean dream',
#  'edward & sons',
#  'la tourangelle',
#  'хлопья',
#  'макароны',
#  'pines international',
#  'sahale snacks',
#  'naturally vitamins',
#  'шалфей',
#  'мисо суп классический',
#  'evolution of smooth',
#  'rapidfire',
#  "wally's natural",
#  'баранина',
#  'better life',
#  'протеиновые батончики',
#  'кордон',
#  'толокно',
#  'детское',
#  'bio-oil',
#  'травы и специи',
#  'tea tree therapy',
#  'hyperbiotics',
#  'back to nature',
#  'hello',
#  'асаи',
#  'картофель фри',
#  'nescafé',
#  'нектар',
#  'boiron single remedies',
#  'цезарь',
#  'herbs etc.',
#  'свинина',
#  'фрукты и овощи',
#  'средство',
#  'yumearth',
#  'nootie',
#  'furious formulations',
#  "honey i'm home",
#  'шпинат',
#  'специи',
#  'кокосовая',
#  'citrus magic',
#  'картофель по-деревенски',
#  'kaged muscle',
#  'arthur andrew medical',
#  'детская',
#  'тампоны',
#  'сет на одного',
#  'соевые',
#  'zint',
#  'kelapo',
#  'squip',
#  'бразильский',
#  'диетические',
#  'everyday shea',
#  'севрюга',
#  'radius',
#  'onnit',
#  'ананасы',
#  'enjoy life foods',
#  'now foods',
#  'капучино',
#  'премиальный',
#  'батарея',
#  'all one nutritech',
#  'лимонад',
#  'brainstrong',
#  "bob's red mill",
#  'для мытья посуды',
#  'happy family organics',
#  'касcеты',
#  'out of africa',
#  'himalaya',
#  'stash tea',
#  'чистящее',
#  'персиковые',
#  'alta health',
#  'grape seed extract',
#  'бумажные',
#  'heritage store',
#  'american biotech labs',
#  'крылышки',
#  'суп',
#  'pure vegan',
#  'яблоки',
#  'greensations',
#  'утиная',
#  'hi tech pharmaceuticals',
#  'миланская',
#  'сырные ломтики',
#  'allvia',
#  'body fortress',
#  'желатин',
#  'диски',
#  'бельмеши',
#  'цветная',
#  'rainbow research',
#  'mount hagen',
#  'pet naturals of vermont',
#  'teeccino',
#  'vegansmart',
#  'жюльен',
#  'чипсы',
#  'royal tropics',
#  'frownies',
#  'simply organic',
#  'паста',
#  'garden greens',
#  'рис',
#  'complimed',
#  'fidobiotics',
#  'соусы',
#  "naturally it's clean",
#  'подушечки',
#  'сельдерей',
#  'everyone',
#  'селен',
#  'rejuvicare',
#  'чизбургер',
#  'paradise herbs',
#  'sun chlorella',
#  'biogaia',
#  'гастрономия',
#  'living clay',
#  'honees',
#  'фасоль',
#  'чечевица',
#  'dickinson brands',
#  'пироги',
#  'schiff',
#  'vital planet',
#  'орехи',
#  'yum-vs',
#  'колбаса',
#  'тестостерон',
#  'tony moly',
#  'лук',
#  'паштет',
#  'futurebiotics',
#  'qunol',
#  'aroma naturals',
#  'мыло-крем',
#  'natrabio',
#  'цинк',
#  'яйцо',
#  'безглютеновые',
#  'neutrogena',
#  'антиоксиданты',
#  'нож',
#  "mommy's bliss",
#  'шапмунь',
#  'эссенция',
#  'equal exchange',
#  'печь-буржуйка',
#  'peanut butter & co.',
#  "nature's way",
#  'puppy cake',
#  'кальмар',
#  'рыбные',
#  'nuk',
#  'магний',
#  'томаты',
#  'витамины',
#  'горчица',
#  'organix south',
#  'maximum international',
#  'celtic sea salt',
#  'missha',
#  'электротовары',
#  'primaforce',
#  'ведро',
#  'prince of peace',
#  'свеча',
#  'посыпка',
#  'kyolic',
#  'мужские мультивитамины',
#  'sprout living',
#  'кусочки',
#  'bragg',
#  'основа',
#  'компотная',
#  'леденцы',
#  'овсяные',
#  'advanced clinicals',
#  'анчоус',
#  'проверочный',
#  'дезодорант-антиперспирант',
#  'nutramax',
#  'куриные крылья баффало',
#  'горох',
#  'фундучная',
#  'homeopet',
#  'увлажняющий',
#  'acure',
#  "l'il critters",
#  "otto's naturals",
#  'california natural',
#  'alkazone',
#  'fifty 50',
#  'детям',
#  'g.h. cretors',
#  'готовый',
#  'torie & howard',
#  'youtheory',
#  'очищающий',
#  'черника',
#  'ежедневный',
#  'черный тмин',
#  'кабачки',
#  'петрушка',
#  'made in nature',
#  'галстук',
#  'диета и контроль веса',
#  "nature's plus",
#  'vital proteins',
#  'картофельное',
#  "earth's best",
#  'mediheal',
#  'хрен',
#  'orgain',
#  'e.l.f. cosmetics',
#  'консервы',
#  'стеклоомывающая',
#  'арахис',
#  'l-цитруллин',
#  'dr. woods',
#  'сетевой',
#  'nu-pore',
#  'apex',
#  'батареи',
#  'свекла',
#  'earth balance',
#  'индейка',
#  'маргарита',
#  'оливки',
#  'nunaturals',
#  'креветки',
#  'мята',
#  'бастурма',
#  'семга',
#  'king arthur flour',
#  'стимуляторы',
#  'предстательная железа',
#  'flapjacked',
#  'маска',
#  'valor',
#  'badger company',
#  'твердые',
#  'пена',
#  'пряник',
#  'сода',
#  'ecover',
#  'yeouth',
#  'sprout organic',
#  'indiumease',
#  'пряники',
#  'g9skin',
#  'prelief',
#  'desitin',
#  'перепел',
#  'батончики',
#  'swerve',
#  'сок',
#  'vetri-science',
#  'appliednutrition',
#  'estroven',
#  'маршмеллоу',
#  'sunfood',
#  'san nutrition',
#  'derma e',
#  'the natural dentist',
#  'крупа',
#  'lifetime vitamins',
#  'хумус',
#  'отдельные масла',
#  'metabolic maintenance',
#  'andalou naturals',
#  'пшено',
#  'окорок',
#  'чабрец',
#  'optimox corporation',
#  'продукты',
#  'крахмал-спрей',
#  'булочка',
#  'куркума и куркумин',
#  'zollipops',
#  "nature's best isopure",
#  'улитки',
#  'rawfusion',
#  'ряженка',
#  'черешня',
#  'гинкго билоба',
#  'flintstones',
#  'питомцы',
#  'lifeseasons',
#  'earth rated',
#  'крем-гель',
#  'яблочный уксус',
#  'redcon1',
#  'вишня',
#  'аксессуары',
#  'organyc',
#  'сладости',
#  'cмесь',
#  'хрустящее',
#  'universal nutrition',
#  'grenade',
#  'nurturme',
#  'cocomels',
#  'пренатальные витамины',
#  'leaders',
#  'отбеливатель',
#  'каперсы',
#  'верона',
#  'скраб',
#  'глазурь',
#  'торты',
#  ...]

# %%
save_slots = pd.Series(list(end_slots))

# %%
save_slots.to_csv('./food/slots.csv', index=False)

# %%
len(end_slots)
# Out:
# 1739
